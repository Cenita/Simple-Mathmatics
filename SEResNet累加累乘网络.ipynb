# %%
import paddle as paddle
import paddle.fluid as fluid
import numpy as np
import matplotlib.pyplot as plt
import sys
import cv2
import os
import random
import math
import PIL.Image as Image
from paddle.fluid.initializer import MSRA
from paddle.fluid.param_attr import ParamAttr
from visualdl import LogWriter

# %%
def produce_path_label(path):
    train_list = np.load(path)
    return train_list

def produce_test(path):
    train_list = []
    train_data = open(path).readlines()
    for i in train_data:
        items = i.split(',')
        class_index = int(items[0])
        img = np.array(items[1:]).astype('uint8')
        train_list.append([class_index,img])
    return train_list

train_list = produce_path_label('data/Acc_train_list.npy')
test_list = produce_path_label('data/Acc_test_list.npy')
class_number = len(train_list)
print(class_number)
# Out:
# 19

# %%
data_shape = [64,64]
class SE_ResNeXt():
    def __init__(self, layers=50):
        self.layers = layers

    def net(self, input, class_dim=1000):
        layers = self.layers
        supported_layers = [50, 101, 152]
        assert layers in supported_layers, \
            "supported layers are {} but input layer is {}".format(supported_layers, layers)
        if layers == 50:
            cardinality = 32
            reduction_ratio = 16
            depth = [3, 4, 6, 3]
            num_filters = [128, 256, 512, 1024]

            conv = self.conv_bn_layer(
                input=input,
                num_filters=64,
                filter_size=7,
                stride=2,
                act='relu',
                name='conv1', )
            conv = fluid.layers.pool2d(
                input=conv,
                pool_size=3,
                pool_stride=2,
                pool_padding=1,
                pool_type='max',
                use_cudnn=False)
        elif layers == 101:
            cardinality = 32
            reduction_ratio = 16
            depth = [3, 4, 23, 3]
            num_filters = [128, 256, 512, 1024]

            conv = self.conv_bn_layer(
                input=input,
                num_filters=64,
                filter_size=7,
                stride=2,
                act='relu',
                name="conv1", )
            conv = fluid.layers.pool2d(
                input=conv,
                pool_size=3,
                pool_stride=2,
                pool_padding=1,
                pool_type='max',
                use_cudnn=False)
        elif layers == 152:
            cardinality = 64
            reduction_ratio = 16
            depth = [3, 8, 36, 3]
            num_filters = [128, 256, 512, 1024]

            conv = self.conv_bn_layer(
                input=input,
                num_filters=64,
                filter_size=3,
                stride=2,
                act='relu',
                name='conv1')
            conv = self.conv_bn_layer(
                input=conv,
                num_filters=64,
                filter_size=3,
                stride=1,
                act='relu',
                name='conv2')
            conv = self.conv_bn_layer(
                input=conv,
                num_filters=128,
                filter_size=3,
                stride=1,
                act='relu',
                name='conv3')
            conv = fluid.layers.pool2d(
                input=conv, pool_size=3, pool_stride=2, pool_padding=1, \
                pool_type='max', use_cudnn=False)
        n = 1 if layers == 50 or layers == 101 else 3
        for block in range(len(depth)):
            n += 1
            for i in range(depth[block]):
                conv = self.bottleneck_block(
                    input=conv,
                    num_filters=num_filters[block],
                    stride=2 if i == 0 and block != 0 else 1,
                    cardinality=cardinality,
                    reduction_ratio=reduction_ratio,
                    name=str(n) + '_' + str(i + 1))

        pool = fluid.layers.pool2d(
            input=conv,
            pool_size=7,
            pool_type='avg',
            global_pooling=True,
            use_cudnn=False)
        drop = fluid.layers.dropout(
            x=pool, dropout_prob=0.5, seed=None)
        stdv = 1.0 / math.sqrt(drop.shape[1] * 1.0)
        out = fluid.layers.fc(
            input=drop,
            size=class_dim,
            act='softmax',
            param_attr=ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv),
                name='fc6_weights'),
            bias_attr=ParamAttr(name='fc6_offset'))
        return out

    def shortcut(self, input, ch_out, stride, name):
        ch_in = input.shape[1]
        if ch_in != ch_out or stride != 1:
            filter_size = 1
            return self.conv_bn_layer(
                input, ch_out, filter_size, stride, name='conv' + name + '_prj')
        else:
            return input

    def bottleneck_block(self,
                         input,
                         num_filters,
                         stride,
                         cardinality,
                         reduction_ratio,
                         name=None):
        conv0 = self.conv_bn_layer(
            input=input,
            num_filters=num_filters,
            filter_size=1,
            act='relu',
            name='conv' + name + '_x1')
        conv1 = self.conv_bn_layer(
            input=conv0,
            num_filters=num_filters,
            filter_size=3,
            stride=stride,
            groups=cardinality,
            act='relu',
            name='conv' + name + '_x2')
        conv2 = self.conv_bn_layer(
            input=conv1,
            num_filters=num_filters * 2,
            filter_size=1,
            act=None,
            name='conv' + name + '_x3')
        scale = self.squeeze_excitation(
            input=conv2,
            num_channels=num_filters * 2,
            reduction_ratio=reduction_ratio,
            name='fc' + name)

        short = self.shortcut(input, num_filters * 2, stride, name=name)

        return fluid.layers.elementwise_add(x=short, y=scale, act='relu')

    def conv_bn_layer(self,
                      input,
                      num_filters,
                      filter_size,
                      stride=1,
                      groups=1,
                      act=None,
                      name=None):
        conv = fluid.layers.conv2d(
            input=input,
            num_filters=num_filters,
            filter_size=filter_size,
            stride=stride,
            padding=(filter_size - 1) // 2,
            groups=groups,
            act=None,
            bias_attr=False,
            param_attr=ParamAttr(name=name + '_weights'), )
        bn_name = name + "_bn"
        return fluid.layers.batch_norm(
            input=conv,
            act=act,
            param_attr=ParamAttr(name=bn_name + '_scale'),
            bias_attr=ParamAttr(bn_name + '_offset'),
            moving_mean_name=bn_name + '_mean',
            moving_variance_name=bn_name + '_variance')

    def squeeze_excitation(self,
                           input,
                           num_channels,
                           reduction_ratio,
                           name=None):
        pool = fluid.layers.pool2d(
            input=input,
            pool_size=0,
            pool_type='avg',
            global_pooling=True,
            use_cudnn=False)
        stdv = 1.0 / math.sqrt(pool.shape[1] * 1.0)
        squeeze = fluid.layers.fc(
            input=pool,
            size=num_channels // reduction_ratio,
            act='relu',
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv),
                name=name + '_sqz_weights'),
            bias_attr=ParamAttr(name=name + '_sqz_offset'))
        stdv = 1.0 / math.sqrt(squeeze.shape[1] * 1.0)
        excitation = fluid.layers.fc(
            input=squeeze,
            size=num_channels,
            act='sigmoid',
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv),
                name=name + '_exc_weights'),
            bias_attr=ParamAttr(name=name + '_exc_offset'))
        scale = fluid.layers.elementwise_mul(x=input, y=excitation, axis=0)
        return scale


def SE_ResNeXt50_32x4d():
    model = SE_ResNeXt(layers=50)
    return model

# %%
yuzhi = 1
def addGaussianNoise(image): 
    G_Noiseimg = np.array(image)
    G_NoiseNum=random.randint(1,5)
    for i in range(G_NoiseNum): 
        temp_x = np.random.randint(0,image.shape[0])
        temp_y = np.random.randint(0,image.shape[0])
        temp_x_size = np.random.randint(1,5)
        temp_y_size = np.random.randint(1,5)
        temp_x_end = min(image.shape[0],temp_x+temp_x_size)
        temp_y_end = min(image.shape[0],temp_y+temp_y_size)
        for x in range(temp_x,temp_x_end):
            for y in range(temp_y,temp_y_end):
                G_Noiseimg[x][y] = 255
    return G_Noiseimg
def for_iterater_reader(t_list):
    def reader():
        for i in range(0,4000):
            for label in range(0,class_number):
              #  try:
                    #img = cv2.resize(img,(data_shape[0],data_shape[1]))
                    #img = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
                    #img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
                    tmp_ran = train_list[label]
                    ran_int = random.randint(0,len(tmp_ran)-1)#取随机的一个数
                    img = np.array(tmp_ran[ran_int]).reshape(64,64)
                    r_sofang = random.randint(6,12)/10
                    shape = int(r_sofang*data_shape[0])
                    img = np.array(img)
                    _, img = cv2.threshold(img, 10, 255,cv2.THRESH_BINARY)
                    h,w = np.array(img).shape
                    r_x = random.randint(-5,5)
                    r_y = random.randint(-4,4)
                    r_rota = random.randint(-5,5)
                    r_yh = random.randint(1,3)
                    img = Image.fromarray(img)
                    img = img.rotate(r_rota)
                    tmpimg = Image.new('L',(data_shape[0],data_shape[0]))
                    tmpimg.paste(img,(r_x,r_y))
                    element1 = cv2.getStructuringElement(cv2.MORPH_RECT, (r_yh, r_yh))
                    tmpimg = cv2.dilate(np.array(tmpimg), element1, iterations = 1)
                    tmpimg = addGaussianNoise(tmpimg)
                    #img = cv2.blur(img,(20,20))#羽化
                    #ret, binary = cv2.threshold(img, 50, 255,cv2.THRESH_BINARY)
                    #element1 = cv2.getStructuringElement(cv2.MORPH_RECT, (10,10))#拓展
                    #img = cv2.erode(binary, element1, iterations = 1)
                    img = np.array(tmpimg)
                    ######################################################
                    img = img.reshape(1,data_shape[0],data_shape[1]).astype('float32')
                    img = (img)/255 
                    yield label,img
            #    except Exception:
             #       print(label)
    return reader

def for_test_reader(t_list):
    def reader():
        for class_index in t_list:
            image = np.array(class_index[1]).reshape(64,64)
            image = Image.fromarray(image).resize((data_shape[0],data_shape[0]))
            image = np.array(image).reshape(1,data_shape[0],data_shape[0]).astype('float32')
            image = (image) / 255.0
            yield class_index[0],image
    return reader

# %%
#1.设置地方
place = fluid.CUDAPlace(0)
#2.设置数据和设置标签
label = fluid.layers.data(name = 'label',shape=[1],dtype='int64')
image = fluid.layers.data(name = 'image',shape=[1,data_shape[0],data_shape[1]],dtype='float32')
#3.设置网络和Feeder
feeder = fluid.DataFeeder(place = place , feed_list = [label,image])
net = SE_ResNeXt50_32x4d().net(image,class_number)
#4.设置损失函数和正确率
cost = fluid.layers.cross_entropy(input = net , label = label)
avg_cost = fluid.layers.mean(cost)
acc = fluid.layers.accuracy(input = net , label =label)
#.定义测试程序
test_program = fluid.default_main_program().clone(for_test=True)
#5.设置优化
LR = 0.001
piecewise_decay = fluid.layers.piecewise_decay([1000,5000,10000], [LR, LR * 0.01,LR * 0.001,LR * 0.0001])
optimizer = fluid.optimizer.AdamOptimizer(learning_rate=piecewise_decay)
optimizer.minimize(avg_cost)
#6.定义Executor
exe = fluid.Executor(place = place)
exe.run(fluid.default_startup_program())
# Out:
# []

# %%
import shutil
import os
def save_inference(pass_id):
     # 保存预测模型
    save_path = 'models/infer_model/'+str(pass_id)+"/"
    # 删除旧的模型文件
    shutil.rmtree(save_path, ignore_errors=True)
    # 创建保持模型文件目录
    os.makedirs(save_path)
    # 保存预测模型
    fluid.io.save_inference_model(save_path, feeded_var_names=[image.name], target_vars=[net], executor=exe)

def save_model(pass_id):
    # 保存参数模型
    save_path = 'models/params_model/'+str(pass_id)+"/"
    # 删除旧的模型文件
    shutil.rmtree(save_path, ignore_errors=True)
    # 创建保持模型文件目录
    os.makedirs(save_path)
    # 保存参数模型
    fluid.io.save_params(executor=exe, dirname=save_path)

def load_model(pass_id):
    # 加载之前训练过的参数模型
    save_path = 'models/params_model/'+str(pass_id)
    if os.path.exists(save_path):
        print('使用参数模型作为预训练模型')
        fluid.io.load_params(executor=exe, dirname=save_path)

# %%
#8.数据分批
train_Reader = paddle.batch(reader=paddle.reader.shuffle(for_iterater_reader(train_list),buf_size = 128*128),batch_size=64)
test_Reader = paddle.batch(reader=paddle.reader.shuffle(for_iterater_reader(test_list),buf_size = 128*128),batch_size=64)

# %%
print("加载完毕")
# Out:
# 加载完毕

# %%
#9.训练
step = 0
best_model_precent = 0
error_cout = 20
save_model_name = 101

# %%
load_model(save_model_name)

# %%
 def train():
    for pass_id in range(20000):
        sum_cost=0
        sum_acc=0
        global best_model_precent
        for batch_id , data in enumerate(train_Reader()):
            train_cost, train_acc = exe.run(program = fluid.default_main_program(),
                                           feed = feeder.feed(data),
                                            fetch_list = [avg_cost,acc]
                                           )
            sum_cost = sum_cost + train_cost[0]
            sum_acc = sum_acc + train_acc[0]
            if batch_id % 50 == 0 and batch_id != 0:
                print('Pass：%d, Batch：%d, Cost：%f, Accuracy：%f' % (pass_id , batch_id , sum_cost/51, sum_acc/51))
                sum_cost = 0
                sum_acc = 0
        test_sum_cost=0
        test_sum_acc=0
        test_cout = 0
        for batch_id , data in enumerate(test_Reader()):
            train_cost, train_acc = exe.run(program = test_program,
                                           feed = feeder.feed(data),
                                            fetch_list = [avg_cost,acc]
                                           )
            test_sum_cost = test_sum_cost + train_cost[0]
            test_sum_acc = test_sum_acc + train_acc[0]
            test_cout+=1
        print("test - Pass:",pass_id,"Cost:",test_sum_cost/test_cout,"Acc:",test_sum_acc/test_cout)
        total_model_precent = (test_sum_acc/test_cout)
        print("new BestPrecent:",best_model_precent,"thie Precent:",total_model_precent)
        if total_model_precent > best_model_precent:
            best_model_precent = total_model_precent
            save_model(save_model_name)
            print("Save...model...Best_precent:",best_model_precent)
        print()
train()
# Out:
# Pass：0, Batch：50, Cost：1.443848, Accuracy：0.552390
# Pass：0, Batch：100, Cost：0.426284, Accuracy：0.847120
# Pass：0, Batch：150, Cost：0.311900, Accuracy：0.886642
# Pass：0, Batch：200, Cost：0.247139, Accuracy：0.905025
# Pass：0, Batch：250, Cost：0.204262, Accuracy：0.917279
# Pass：0, Batch：300, Cost：0.149113, Accuracy：0.934743
# Pass：0, Batch：350, Cost：0.163506, Accuracy：0.936275
# Pass：0, Batch：400, Cost：0.154408, Accuracy：0.934130
# Pass：0, Batch：450, Cost：0.104339, Accuracy：0.946998
# Pass：0, Batch：500, Cost：0.144891, Accuracy：0.935355
# Pass：0, Batch：550, Cost：0.128781, Accuracy：0.939951
# Pass：0, Batch：600, Cost：0.110289, Accuracy：0.944547
# Pass：0, Batch：650, Cost：0.117434, Accuracy：0.946385
# Pass：0, Batch：700, Cost：0.106049, Accuracy：0.948836
# Pass：0, Batch：750, Cost：0.084579, Accuracy：0.952819
# Pass：0, Batch：800, Cost：0.084136, Accuracy：0.953431
# Pass：0, Batch：850, Cost：0.078001, Accuracy：0.958027
# Pass：0, Batch：900, Cost：0.075219, Accuracy：0.958027
# Pass：0, Batch：950, Cost：0.098605, Accuracy：0.951900
# Pass：0, Batch：1000, Cost：0.089918, Accuracy：0.956801
# Pass：0, Batch：1050, Cost：0.077548, Accuracy：0.957108
# Pass：0, Batch：1100, Cost：0.072131, Accuracy：0.958640
# Pass：0, Batch：1150, Cost：0.058942, Accuracy：0.966299
# test - Pass: 0 Cost: 0.04816911262269947 Acc: 0.9856376262626263
# new BestPrecent: 0 thie Precent: 0.9856376262626263
# Save...model...Best_precent: 0.9856376262626263
#
# Pass：1, Batch：50, Cost：0.045611, Accuracy：0.985294
# Pass：1, Batch：100, Cost：0.065334, Accuracy：0.961091
# Pass：1, Batch：150, Cost：0.062771, Accuracy：0.964154
# Pass：1, Batch：200, Cost：0.046270, Accuracy：0.965380
# Pass：1, Batch：250, Cost：0.045680, Accuracy：0.968750
# Pass：1, Batch：300, Cost：0.043536, Accuracy：0.965074
# Pass：1, Batch：350, Cost：0.050740, Accuracy：0.966912
# Pass：1, Batch：400, Cost：0.046277, Accuracy：0.963542
# Pass：1, Batch：450, Cost：0.042047, Accuracy：0.969056
# Pass：1, Batch：500, Cost：0.051080, Accuracy：0.965993
# Pass：1, Batch：550, Cost：0.035732, Accuracy：0.970282
# Pass：1, Batch：600, Cost：0.033884, Accuracy：0.969363
# Pass：1, Batch：650, Cost：0.044204, Accuracy：0.968137
# Pass：1, Batch：700, Cost：0.050213, Accuracy：0.965686
# Pass：1, Batch：750, Cost：0.034200, Accuracy：0.969975
# Pass：1, Batch：800, Cost：0.035540, Accuracy：0.969975
# Pass：1, Batch：850, Cost：0.039387, Accuracy：0.969669
# Pass：1, Batch：900, Cost：0.050179, Accuracy：0.965380
# Pass：1, Batch：950, Cost：0.050424, Accuracy：0.967831
# Pass：1, Batch：1000, Cost：0.033813, Accuracy：0.969056
# Pass：1, Batch：1050, Cost：0.038031, Accuracy：0.970895
# Pass：1, Batch：1100, Cost：0.035083, Accuracy：0.969363
# Pass：1, Batch：1150, Cost：0.033448, Accuracy：0.971201
# test - Pass: 1 Cost: 0.03136640268520343 Acc: 0.9906618265993266
# new BestPrecent: 0.9856376262626263 thie Precent: 0.9906618265993266
# Save...model...Best_precent: 0.9906618265993266
#
# Pass：2, Batch：50, Cost：0.037296, Accuracy：0.988971
# Pass：2, Batch：100, Cost：0.029772, Accuracy：0.970282
# Pass：2, Batch：150, Cost：0.033713, Accuracy：0.968137
# Pass：2, Batch：200, Cost：0.025247, Accuracy：0.973039
# Pass：2, Batch：250, Cost：0.028998, Accuracy：0.970895
# Pass：2, Batch：300, Cost：0.038298, Accuracy：0.969669
# Pass：2, Batch：350, Cost：0.034345, Accuracy：0.967525
# Pass：2, Batch：400, Cost：0.030819, Accuracy：0.969975
# Pass：2, Batch：450, Cost：0.029667, Accuracy：0.971201
# Pass：2, Batch：500, Cost：0.042444, Accuracy：0.968137
# Pass：2, Batch：550, Cost：0.030754, Accuracy：0.973958
# Pass：2, Batch：600, Cost：0.027682, Accuracy：0.971814
# Pass：2, Batch：650, Cost：0.051046, Accuracy：0.968444
# Pass：2, Batch：700, Cost：0.035808, Accuracy：0.967831
# Pass：2, Batch：750, Cost：0.028823, Accuracy：0.972120
# Pass：2, Batch：800, Cost：0.028088, Accuracy：0.972120
# Pass：2, Batch：850, Cost：0.026532, Accuracy：0.973039
# Pass：2, Batch：900, Cost：0.032962, Accuracy：0.969056
# Pass：2, Batch：950, Cost：0.033334, Accuracy：0.969669
# Pass：2, Batch：1000, Cost：0.026840, Accuracy：0.972120
# Pass：2, Batch：1050, Cost：0.031253, Accuracy：0.971201
# Pass：2, Batch：1100, Cost：0.034486, Accuracy：0.969975
# Pass：2, Batch：1150, Cost：0.032875, Accuracy：0.969975
# test - Pass: 2 Cost: 0.024936050714134916 Acc: 0.9924636994949495
# new BestPrecent: 0.9906618265993266 thie Precent: 0.9924636994949495
# Save...model...Best_precent: 0.9924636994949495
#
# Pass：3, Batch：50, Cost：0.027595, Accuracy：0.991115
# Pass：3, Batch：100, Cost：0.032085, Accuracy：0.970588
# Pass：3, Batch：150, Cost：0.029646, Accuracy：0.971814
# Pass：3, Batch：200, Cost：0.030484, Accuracy：0.970282
# Pass：3, Batch：250, Cost：0.022762, Accuracy：0.974265
# Pass：3, Batch：300, Cost：0.035219, Accuracy：0.967831
# Pass：3, Batch：350, Cost：0.034264, Accuracy：0.968444
# Pass：3, Batch：400, Cost：0.023399, Accuracy：0.973958
# Pass：3, Batch：450, Cost：0.023438, Accuracy：0.972426
# Pass：3, Batch：500, Cost：0.031989, Accuracy：0.970282
# Pass：3, Batch：550, Cost：0.026750, Accuracy：0.973652
# Pass：3, Batch：600, Cost：0.017165, Accuracy：0.976103
# Pass：3, Batch：650, Cost：0.024926, Accuracy：0.973346
# Pass：3, Batch：700, Cost：0.029728, Accuracy：0.971814
# Pass：3, Batch：750, Cost：0.026413, Accuracy：0.972120
# Pass：3, Batch：800, Cost：0.026406, Accuracy：0.971201
# Pass：3, Batch：850, Cost：0.025947, Accuracy：0.972120
# Pass：3, Batch：900, Cost：0.037568, Accuracy：0.971507
# Pass：3, Batch：950, Cost：0.020973, Accuracy：0.972733
# Pass：3, Batch：1000, Cost：0.018772, Accuracy：0.975490
# Pass：3, Batch：1050, Cost：0.034209, Accuracy：0.970895
# Pass：3, Batch：1100, Cost：0.028810, Accuracy：0.972426
# Pass：3, Batch：1150, Cost：0.028488, Accuracy：0.973652
# test - Pass: 3 Cost: 0.02266769441760544 Acc: 0.9930950126262627
# new BestPrecent: 0.9924636994949495 thie Precent: 0.9930950126262627
# Save...model...Best_precent: 0.9930950126262627
#
# Pass：4, Batch：50, Cost：0.030173, Accuracy：0.993260
# Pass：4, Batch：100, Cost：0.015925, Accuracy：0.976103
# Pass：4, Batch：150, Cost：0.030298, Accuracy：0.972426
# Pass：4, Batch：200, Cost：0.033210, Accuracy：0.971814
# Pass：4, Batch：250, Cost：0.027250, Accuracy：0.972426
# Pass：4, Batch：300, Cost：0.028376, Accuracy：0.973346
# Pass：4, Batch：350, Cost：0.026013, Accuracy：0.972733
# Pass：4, Batch：400, Cost：0.023185, Accuracy：0.972733
# Pass：4, Batch：450, Cost：0.020778, Accuracy：0.974877
# Pass：4, Batch：500, Cost：0.024224, Accuracy：0.972120
# Pass：4, Batch：550, Cost：0.030430, Accuracy：0.971201
# Pass：4, Batch：600, Cost：0.026760, Accuracy：0.973346
# Pass：4, Batch：650, Cost：0.026420, Accuracy：0.973346
# Pass：4, Batch：700, Cost：0.025272, Accuracy：0.971201
# Pass：4, Batch：750, Cost：0.020758, Accuracy：0.975184
# Pass：4, Batch：800, Cost：0.023637, Accuracy：0.972733
# Pass：4, Batch：850, Cost：0.026679, Accuracy：0.972733
# Pass：4, Batch：900, Cost：0.031322, Accuracy：0.970282
# Pass：4, Batch：950, Cost：0.018844, Accuracy：0.973958
# Pass：4, Batch：1000, Cost：0.033272, Accuracy：0.970282
# Pass：4, Batch：1050, Cost：0.013268, Accuracy：0.976103
# Pass：4, Batch：1100, Cost：0.019790, Accuracy：0.973958
# Pass：4, Batch：1150, Cost：0.026595, Accuracy：0.971507
# test - Pass: 4 Cost: 0.021695991470042898 Acc: 0.9933186026936027
# new BestPrecent: 0.9930950126262627 thie Precent: 0.9933186026936027
# Save...model...Best_precent: 0.9933186026936027
#
# Pass：5, Batch：50, Cost：0.018522, Accuracy：0.994179
# Pass：5, Batch：100, Cost：0.025637, Accuracy：0.971201
# Pass：5, Batch：150, Cost：0.033992, Accuracy：0.970895
# Pass：5, Batch：200, Cost：0.030850, Accuracy：0.971201
# Pass：5, Batch：250, Cost：0.024876, Accuracy：0.972426
# Pass：5, Batch：300, Cost：0.026817, Accuracy：0.972733
# Pass：5, Batch：350, Cost：0.025400, Accuracy：0.973346
# Pass：5, Batch：400, Cost：0.025489, Accuracy：0.973958
# Pass：5, Batch：450, Cost：0.027378, Accuracy：0.972426
# Pass：5, Batch：500, Cost：0.023393, Accuracy：0.975184
# Pass：5, Batch：550, Cost：0.029184, Accuracy：0.972120
# Pass：5, Batch：600, Cost：0.019891, Accuracy：0.975797
# Pass：5, Batch：650, Cost：0.021271, Accuracy：0.973652
# Pass：5, Batch：700, Cost：0.029592, Accuracy：0.969975
# Pass：5, Batch：750, Cost：0.024574, Accuracy：0.973958
# Pass：5, Batch：800, Cost：0.023724, Accuracy：0.973346
# Pass：5, Batch：850, Cost：0.019752, Accuracy：0.974877
# Pass：5, Batch：900, Cost：0.027036, Accuracy：0.971507
# Pass：5, Batch：950, Cost：0.024153, Accuracy：0.972120
# Pass：5, Batch：1000, Cost：0.032106, Accuracy：0.972120
# Pass：5, Batch：1050, Cost：0.022915, Accuracy：0.973346
# Pass：5, Batch：1100, Cost：0.016829, Accuracy：0.976103
# Pass：5, Batch：1150, Cost：0.026470, Accuracy：0.973652
# test - Pass: 5 Cost: 0.019711730423406345 Acc: 0.9941208964646465
# new BestPrecent: 0.9933186026936027 thie Precent: 0.9941208964646465
# Save...model...Best_precent: 0.9941208964646465
#
# Pass：6, Batch：50, Cost：0.024455, Accuracy：0.992953
# Pass：6, Batch：100, Cost：0.023974, Accuracy：0.973652
# Pass：6, Batch：150, Cost：0.021846, Accuracy：0.973652

# %%
save_model(save_model_name)

# %%
load_model(save_model_name)

# %%
save_inference(save_model_name)

# %%
test_image = test_list[19][20]
plt.figure()
plt.imshow(test_image)
test_image = np.array(test_image).astype('float32').reshape(1,1,64,64)/255
result = exe.run(program = test_program,feed = {'image':test_image,'label':np.array([[1]]).astype('int64')},fetch_list = [net])
print(np.argmax(result))
