# %%
import paddle as paddle
import paddle.fluid as fluid
import numpy as np
import matplotlib.pyplot as plt
import sys
import cv2
import os
import random
import math
import PIL.Image as Image
from paddle.fluid.initializer import MSRA
from paddle.fluid.param_attr import ParamAttr
from visualdl import LogWriter

# %%
def produce_path_label(path):
    train_list = np.load(path)
    return train_list

def produce_test(path):
    train_list = []
    train_data = open(path).readlines()
    for i in train_data:
        items = i.split(',')
        class_index = int(items[0])
        img = np.array(items[1:]).astype('uint8')
        train_list.append([class_index,img])
    return train_list

train_list = produce_path_label('data/Acc_train_list.npy')
test_list = produce_path_label('data/Acc_test_list.npy')
class_number = len(train_list)
print(class_number)
# Out:
# 19

# %%
data_shape = [64,64]

# %%
class ResNet():
    def __init__(self, layers=50):
        self.layers = layers

    def net(self, input, class_dim=1000):
        layers = self.layers
        if layers == 18:
            depth = [2, 2, 2, 2]
        if layers == 50:
            depth = [3, 4, 6, 3]
        elif layers == 101:
            depth = [3, 4, 23, 3]
        elif layers == 152:
            depth = [3, 8, 36, 3]
        num_filters = [64, 128, 256, 512]
        conv = self.conv_bn_layer(
            input=input, num_filters=64, filter_size=7, stride=2, act='relu')
        conv = fluid.layers.pool2d(
            input=conv,
            pool_size=3,
            pool_stride=2,
            pool_padding=1,
            pool_type='max')
        for block in range(len(depth)):
            for i in range(depth[block]):
                conv = self.bottleneck_block(
                    input=conv,
                    num_filters=num_filters[block],
                    stride=2 if i == 0 and block != 0 else 1)
        pool = fluid.layers.pool2d(
            input=conv, pool_size=7, pool_type='avg', global_pooling=True)
        stdv = 1.0 / math.sqrt(pool.shape[1] * 1.0)
        out = fluid.layers.fc(input=pool,
                              act = 'softmax',
                              size=class_dim,
                              param_attr=fluid.param_attr.ParamAttr(
                                  initializer=fluid.initializer.Uniform(-stdv,
                                                                        stdv)))
        return out
    def conv_bn_layer(self,
                      input,
                      num_filters,
                      filter_size,
                      stride=1,
                      groups=1,
                      act=None):
        conv = fluid.layers.conv2d(
            input=input,
            num_filters=num_filters,
            filter_size=filter_size,
            stride=stride,
            padding=(filter_size - 1) // 2,
            groups=groups,
            act=None,
            bias_attr=False)
        return fluid.layers.batch_norm(input=conv, act=act)

    def shortcut(self, input, ch_out, stride):
        ch_in = input.shape[1]
        if ch_in != ch_out or stride != 1:
            return self.conv_bn_layer(input, ch_out, 1, stride)
        else:
            return input

    def bottleneck_block(self, input, num_filters, stride):
        conv0 = self.conv_bn_layer(
            input=input, num_filters=num_filters, filter_size=1, act='relu')
        conv1 = self.conv_bn_layer(
            input=conv0,
            num_filters=num_filters,
            filter_size=3,
            stride=stride,
            act='relu')
        conv2 = self.conv_bn_layer(
            input=conv1, num_filters=num_filters * 4, filter_size=1, act=None)
        short = self.shortcut(input, num_filters * 4, stride)
        return fluid.layers.elementwise_add(x=short, y=conv2, act='relu')


def ResNet50():
    model = ResNet(layers=18)
    return model

# %%
yuzhi = 1
def addGaussianNoise(image): 
    G_Noiseimg = np.array(image)
    G_NoiseNum=random.randint(1,5)
    for i in range(G_NoiseNum): 
        temp_x = np.random.randint(0,image.shape[0])
        temp_y = np.random.randint(0,image.shape[0])
        temp_x_size = np.random.randint(1,5)
        temp_y_size = np.random.randint(1,5)
        temp_x_end = min(image.shape[0],temp_x+temp_x_size)
        temp_y_end = min(image.shape[0],temp_y+temp_y_size)
        for x in range(temp_x,temp_x_end):
            for y in range(temp_y,temp_y_end):
                G_Noiseimg[x][y] = 255
    return G_Noiseimg
def for_iterater_reader(t_list):
    def reader():
        for i in range(0,4000):
            for label in range(0,class_number):
              #  try:
                    #img = cv2.resize(img,(data_shape[0],data_shape[1]))
                    #img = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
                    #img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
                    tmp_ran = train_list[label]
                    ran_int = random.randint(0,len(tmp_ran)-1)#取随机的一个数
                    img = np.array(tmp_ran[ran_int]).reshape(64,64)
                    r_sofang = random.randint(6,12)/10
                    shape = int(r_sofang*data_shape[0])
                    img = Image.fromarray(img).resize((shape,shape))
                    img = np.array(img)
                    _, img = cv2.threshold(img, 10, 255,cv2.THRESH_BINARY)
                    r_x = random.randint(-5,5)
                    r_y = random.randint(-5,5)
                    r_rota = random.randint(-5,5)
                    r_yh = random.randint(1,3)
                    img = Image.fromarray(img)
                    img = img.rotate(r_rota)
                    tmpimg = Image.new('L',(data_shape[0],data_shape[0]))
                    tmpimg.paste(img,(r_x,r_y))
                    element1 = cv2.getStructuringElement(cv2.MORPH_RECT, (r_yh, r_yh))
                    tmpimg = cv2.dilate(np.array(tmpimg), element1, iterations = 1)
                    tmpimg = addGaussianNoise(tmpimg)
                    #img = cv2.blur(img,(20,20))#羽化
                    #ret, binary = cv2.threshold(img, 50, 255,cv2.THRESH_BINARY)
                    #element1 = cv2.getStructuringElement(cv2.MORPH_RECT, (10,10))#拓展
                    #img = cv2.erode(binary, element1, iterations = 1)
                    img = np.array(tmpimg)
                    ######################################################
                    img = img.reshape(1,data_shape[0],data_shape[1]).astype('float32')
                    img = (img)/255 
                    yield label,img
            #    except Exception:
             #       print(label)
    return reader

def for_test_reader(t_list):
    def reader():
        for class_index in t_list:
            image = np.array(class_index[1]).reshape(64,64)
            image = Image.fromarray(image).resize((data_shape[0],data_shape[0]))
            image = np.array(image).reshape(1,data_shape[0],data_shape[0]).astype('float32')
            image = (image) / 255.0
            yield class_index[0],image
    return reader

# %%
#1.设置地方
place = fluid.CUDAPlace(0)
#2.设置数据和设置标签
label = fluid.layers.data(name = 'label',shape=[1],dtype='int64')
image = fluid.layers.data(name = 'image',shape=[1,data_shape[0],data_shape[1]],dtype='float32')
#3.设置网络和Feeder
feeder = fluid.DataFeeder(place = place , feed_list = [label,image])
net = ResNet50().net(image,class_number)
#4.设置损失函数和正确率
cost = fluid.layers.cross_entropy(input = net , label = label)
avg_cost = fluid.layers.mean(cost)
acc = fluid.layers.accuracy(input = net , label =label)
#.定义测试程序
test_program = fluid.default_main_program().clone(for_test=True)
#5.设置优化
LR = 0.001
piecewise_decay = fluid.layers.piecewise_decay([5000,10000,15000], [LR, LR * 0.01,LR * 0.001,LR * 0.0001])
optimizer = fluid.optimizer.Adam(learning_rate=piecewise_decay)
optimizer.minimize(avg_cost)
#6.定义Executor
exe = fluid.Executor(place = place)
exe.run(fluid.default_startup_program())
# Out:
# []

# %%
import shutil
import os
def save_inference(pass_id):
     # 保存预测模型
    save_path = 'models/infer_model/'+str(pass_id)+"/"
    # 删除旧的模型文件
    shutil.rmtree(save_path, ignore_errors=True)
    # 创建保持模型文件目录
    os.makedirs(save_path)
    # 保存预测模型
    fluid.io.save_inference_model(save_path, feeded_var_names=[image.name], target_vars=[net], executor=exe)

def save_model(pass_id):
    # 保存参数模型
    save_path = 'models/params_model/'+str(pass_id)+"/"
    # 删除旧的模型文件
    shutil.rmtree(save_path, ignore_errors=True)
    # 创建保持模型文件目录
    os.makedirs(save_path)
    # 保存参数模型
    fluid.io.save_params(executor=exe, dirname=save_path)

def load_model(pass_id):
    # 加载之前训练过的参数模型
    save_path = 'models/params_model/'+str(pass_id)
    if os.path.exists(save_path):
        print('使用参数模型作为预训练模型')
        fluid.io.load_params(executor=exe, dirname=save_path)

# %%
#8.数据分批
train_Reader = paddle.batch(reader=paddle.reader.shuffle(for_iterater_reader(train_list),buf_size = 128*128),batch_size=64)
test_Reader = paddle.batch(reader=paddle.reader.shuffle(for_iterater_reader(test_list),buf_size = 128*128),batch_size=64)

# %%
print("加载完毕")
# Out:
# 加载完毕

# %%
#9.训练
step = 0
best_model_precent = 0
error_cout = 20
save_model_name = 100

# %%
load_model(save_model_name)

# %%
 def train():
    for pass_id in range(20000):
        sum_cost=0
        sum_acc=0
        global best_model_precent
        for batch_id , data in enumerate(train_Reader()):
            train_cost, train_acc = exe.run(program = fluid.default_main_program(),
                                           feed = feeder.feed(data),
                                            fetch_list = [avg_cost,acc]
                                           )
            sum_cost = sum_cost + train_cost[0]
            sum_acc = sum_acc + train_acc[0]
            if batch_id % 50 == 0 and batch_id != 0:
                print('Pass：%d, Batch：%d, Cost：%f, Accuracy：%f' % (pass_id , batch_id , sum_cost/51, sum_acc/51))
                sum_cost = 0
                sum_acc = 0
        test_sum_cost=0
        test_sum_acc=0
        test_cout = 0
        for batch_id , data in enumerate(test_Reader()):
            train_cost, train_acc = exe.run(program = test_program,
                                           feed = feeder.feed(data),
                                            fetch_list = [avg_cost,acc]
                                           )
            test_sum_cost = test_sum_cost + train_cost[0]
            test_sum_acc = test_sum_acc + train_acc[0]
            test_cout+=1
        print("test - Pass:",pass_id,"Cost:",test_sum_cost/test_cout,"Acc:",test_sum_acc/test_cout)
        total_model_precent = (test_sum_acc/test_cout)
        print("new BestPrecent:",best_model_precent,"thie Precent:",total_model_precent)
        if total_model_precent > best_model_precent:
            best_model_precent = total_model_precent
            save_model(save_model_name)
            print("Save...model...Best_precent:",best_model_precent)
        print()
train()
# Out:
# Pass：0, Batch：50, Cost：0.031826, Accuracy：0.990809
# Pass：0, Batch：100, Cost：0.041394, Accuracy：0.967831
# Pass：0, Batch：150, Cost：0.034660, Accuracy：0.969056
# Pass：0, Batch：200, Cost：0.029096, Accuracy：0.971814
# Pass：0, Batch：250, Cost：0.033196, Accuracy：0.968444
# Pass：0, Batch：300, Cost：0.036746, Accuracy：0.969056
# Pass：0, Batch：350, Cost：0.030863, Accuracy：0.971507
# Pass：0, Batch：400, Cost：0.034640, Accuracy：0.970588
# Pass：0, Batch：450, Cost：0.053924, Accuracy：0.965380
# Pass：0, Batch：500, Cost：0.034295, Accuracy：0.971201
# Pass：0, Batch：550, Cost：0.027537, Accuracy：0.972426
# Pass：0, Batch：600, Cost：0.033572, Accuracy：0.971814
# Pass：0, Batch：650, Cost：0.036554, Accuracy：0.970282
# Pass：0, Batch：700, Cost：0.025136, Accuracy：0.970588
# Pass：0, Batch：750, Cost：0.030545, Accuracy：0.971201
# Pass：0, Batch：800, Cost：0.038703, Accuracy：0.969669
# Pass：0, Batch：850, Cost：0.035631, Accuracy：0.968750
# Pass：0, Batch：900, Cost：0.030464, Accuracy：0.970895
# Pass：0, Batch：950, Cost：0.041506, Accuracy：0.969975
# Pass：0, Batch：1000, Cost：0.033398, Accuracy：0.970588
# Pass：0, Batch：1050, Cost：0.035672, Accuracy：0.969975
# Pass：0, Batch：1100, Cost：0.031974, Accuracy：0.971814
# Pass：0, Batch：1150, Cost：0.029224, Accuracy：0.970895
# test - Pass: 0 Cost: 0.028641247553181533 Acc: 0.9909906355218855
# new BestPrecent: 0.9899515993265994 thie Precent: 0.9909906355218855
# Save...model...Best_precent: 0.9909906355218855
#
# Pass：1, Batch：50, Cost：0.022725, Accuracy：0.993260
# Pass：1, Batch：100, Cost：0.040038, Accuracy：0.969056
# Pass：1, Batch：150, Cost：0.032547, Accuracy：0.970282
# Pass：1, Batch：200, Cost：0.032499, Accuracy：0.972733
# Pass：1, Batch：250, Cost：0.027989, Accuracy：0.971507
# Pass：1, Batch：300, Cost：0.029242, Accuracy：0.973039
# Pass：1, Batch：350, Cost：0.027725, Accuracy：0.971814
# Pass：1, Batch：400, Cost：0.031492, Accuracy：0.969056
# Pass：1, Batch：450, Cost：0.034250, Accuracy：0.971814
# Pass：1, Batch：500, Cost：0.031856, Accuracy：0.971507
# Pass：1, Batch：550, Cost：0.030526, Accuracy：0.971507
# Pass：1, Batch：600, Cost：0.032250, Accuracy：0.970895
# Pass：1, Batch：650, Cost：0.028559, Accuracy：0.971814
# Pass：1, Batch：700, Cost：0.028737, Accuracy：0.969363
# Pass：1, Batch：750, Cost：0.031921, Accuracy：0.971507
# Pass：1, Batch：800, Cost：0.030769, Accuracy：0.970282
# Pass：1, Batch：850, Cost：0.038349, Accuracy：0.968750
# Pass：1, Batch：900, Cost：0.036773, Accuracy：0.969669
# Pass：1, Batch：950, Cost：0.028722, Accuracy：0.971201
# Pass：1, Batch：1000, Cost：0.025241, Accuracy：0.971507
# Pass：1, Batch：1050, Cost：0.029616, Accuracy：0.971814
# Pass：1, Batch：1100, Cost：0.034771, Accuracy：0.971507
# Pass：1, Batch：1150, Cost：0.028920, Accuracy：0.972120
# test - Pass: 1 Cost: 0.026496198501643 Acc: 0.9915824915824916
# new BestPrecent: 0.9909906355218855 thie Precent: 0.9915824915824916
# Save...model...Best_precent: 0.9915824915824916
#
# Pass：2, Batch：50, Cost：0.023691, Accuracy：0.992953
# Pass：2, Batch：100, Cost：0.032234, Accuracy：0.970282
# Pass：2, Batch：150, Cost：0.025960, Accuracy：0.971814
# Pass：2, Batch：200, Cost：0.027086, Accuracy：0.970588
# Pass：2, Batch：250, Cost：0.029090, Accuracy：0.972733
# Pass：2, Batch：300, Cost：0.029876, Accuracy：0.971814
# Pass：2, Batch：350, Cost：0.029344, Accuracy：0.971201
# Pass：2, Batch：400, Cost：0.047408, Accuracy：0.967218
# Pass：2, Batch：450, Cost：0.024861, Accuracy：0.973039
# Pass：2, Batch：500, Cost：0.035962, Accuracy：0.969975
# Pass：2, Batch：550, Cost：0.025026, Accuracy：0.972120
# Pass：2, Batch：600, Cost：0.031715, Accuracy：0.969363
# Pass：2, Batch：650, Cost：0.028478, Accuracy：0.973346
# Pass：2, Batch：700, Cost：0.032314, Accuracy：0.972120
# Pass：2, Batch：750, Cost：0.025952, Accuracy：0.973039
# Pass：2, Batch：800, Cost：0.028389, Accuracy：0.970588
# Pass：2, Batch：850, Cost：0.031155, Accuracy：0.970588
# Pass：2, Batch：900, Cost：0.032151, Accuracy：0.971814
# Pass：2, Batch：950, Cost：0.029749, Accuracy：0.970282
# Pass：2, Batch：1000, Cost：0.024069, Accuracy：0.973039
# Pass：2, Batch：1050, Cost：0.030846, Accuracy：0.971201
# Pass：2, Batch：1100, Cost：0.023965, Accuracy：0.973039
# Pass：2, Batch：1150, Cost：0.029395, Accuracy：0.972426
# test - Pass: 2 Cost: 0.025160303880526803 Acc: 0.9922795664983165
# new BestPrecent: 0.9915824915824916 thie Precent: 0.9922795664983165
# Save...model...Best_precent: 0.9922795664983165
#
# Pass：3, Batch：50, Cost：0.023292, Accuracy：0.991728
# Pass：3, Batch：100, Cost：0.033537, Accuracy：0.969975
# Pass：3, Batch：150, Cost：0.034458, Accuracy：0.970588
# Pass：3, Batch：200, Cost：0.021939, Accuracy：0.974265
# Pass：3, Batch：250, Cost：0.025716, Accuracy：0.971201
# Pass：3, Batch：300, Cost：0.031799, Accuracy：0.969056
# Pass：3, Batch：350, Cost：0.039614, Accuracy：0.967218
# Pass：3, Batch：400, Cost：0.039255, Accuracy：0.968444
# Pass：3, Batch：450, Cost：0.030292, Accuracy：0.969975
# Pass：3, Batch：500, Cost：0.019235, Accuracy：0.974877
# Pass：3, Batch：550, Cost：0.025244, Accuracy：0.972733
# Pass：3, Batch：600, Cost：0.035754, Accuracy：0.969975
# Pass：3, Batch：650, Cost：0.020632, Accuracy：0.973346
# Pass：3, Batch：700, Cost：0.029252, Accuracy：0.971201
# Pass：3, Batch：750, Cost：0.029984, Accuracy：0.969975
# Pass：3, Batch：800, Cost：0.025476, Accuracy：0.973346
# Pass：3, Batch：850, Cost：0.031310, Accuracy：0.971201
# Pass：3, Batch：900, Cost：0.035111, Accuracy：0.968444
# Pass：3, Batch：950, Cost：0.024225, Accuracy：0.973652
# Pass：3, Batch：1000, Cost：0.027287, Accuracy：0.971814
# Pass：3, Batch：1050, Cost：0.031432, Accuracy：0.971507
# Pass：3, Batch：1100, Cost：0.035500, Accuracy：0.971814
# Pass：3, Batch：1150, Cost：0.023074, Accuracy：0.973039
# test - Pass: 3 Cost: 0.02485281721436133 Acc: 0.9927530513468014
# new BestPrecent: 0.9922795664983165 thie Precent: 0.9927530513468014
# Save...model...Best_precent: 0.9927530513468014
#
# Pass：4, Batch：50, Cost：0.027485, Accuracy：0.991422
# Pass：4, Batch：100, Cost：0.025463, Accuracy：0.972733
# Pass：4, Batch：150, Cost：0.032417, Accuracy：0.971201
# Pass：4, Batch：200, Cost：0.027724, Accuracy：0.970282
# Pass：4, Batch：250, Cost：0.029275, Accuracy：0.971507
# Pass：4, Batch：300, Cost：0.021070, Accuracy：0.973958
# Pass：4, Batch：350, Cost：0.026440, Accuracy：0.971201
# Pass：4, Batch：400, Cost：0.031233, Accuracy：0.971507
# Pass：4, Batch：450, Cost：0.028259, Accuracy：0.971201
# Pass：4, Batch：500, Cost：0.035085, Accuracy：0.968444
# Pass：4, Batch：550, Cost：0.031076, Accuracy：0.970588
# Pass：4, Batch：600, Cost：0.036307, Accuracy：0.970895
# Pass：4, Batch：650, Cost：0.029420, Accuracy：0.971507
# Pass：4, Batch：700, Cost：0.030540, Accuracy：0.970282
# Pass：4, Batch：750, Cost：0.019408, Accuracy：0.974265
# Pass：4, Batch：800, Cost：0.032312, Accuracy：0.969975
# Pass：4, Batch：850, Cost：0.024790, Accuracy：0.973958
# Pass：4, Batch：900, Cost：0.037043, Accuracy：0.968137
# Pass：4, Batch：950, Cost：0.028779, Accuracy：0.971201
# Pass：4, Batch：1000, Cost：0.033476, Accuracy：0.969975
# Pass：4, Batch：1050, Cost：0.034240, Accuracy：0.970282
# Pass：4, Batch：1100, Cost：0.031116, Accuracy：0.970282
# Pass：4, Batch：1150, Cost：0.029154, Accuracy：0.972426
# test - Pass: 4 Cost: 0.024221652650398003 Acc: 0.992371632996633
# new BestPrecent: 0.9927530513468014 thie Precent: 0.992371632996633
#
# Pass：5, Batch：50, Cost：0.029192, Accuracy：0.988971
# Pass：5, Batch：100, Cost：0.035719, Accuracy：0.969056
# Pass：5, Batch：150, Cost：0.024559, Accuracy：0.973958
# Pass：5, Batch：200, Cost：0.021311, Accuracy：0.973652
# Pass：5, Batch：250, Cost：0.026213, Accuracy：0.969669
# Pass：5, Batch：300, Cost：0.033787, Accuracy：0.968444
# Pass：5, Batch：350, Cost：0.029783, Accuracy：0.973039
# Pass：5, Batch：400, Cost：0.028761, Accuracy：0.971201
# Pass：5, Batch：450, Cost：0.016633, Accuracy：0.975490
# Pass：5, Batch：500, Cost：0.028066, Accuracy：0.972733
# Pass：5, Batch：550, Cost：0.036781, Accuracy：0.970282
# Pass：5, Batch：600, Cost：0.023398, Accuracy：0.971814
# Pass：5, Batch：650, Cost：0.022192, Accuracy：0.973958
# Pass：5, Batch：700, Cost：0.020506, Accuracy：0.973652
# Pass：5, Batch：750, Cost：0.025039, Accuracy：0.972120
# Pass：5, Batch：800, Cost：0.034897, Accuracy：0.968750
# Pass：5, Batch：850, Cost：0.033417, Accuracy：0.969056
# Pass：5, Batch：900, Cost：0.028326, Accuracy：0.971201
# Pass：5, Batch：950, Cost：0.026926, Accuracy：0.972120
# Pass：5, Batch：1000, Cost：0.037114, Accuracy：0.968750
# Pass：5, Batch：1050, Cost：0.020959, Accuracy：0.973958
# Pass：5, Batch：1100, Cost：0.019898, Accuracy：0.974571
# Pass：5, Batch：1150, Cost：0.024247, Accuracy：0.973958
# test - Pass: 5 Cost: 0.023031079501881494 Acc: 0.9931476220538721
# new BestPrecent: 0.9927530513468014 thie Precent: 0.9931476220538721
# Save...model...Best_precent: 0.9931476220538721
#
# Pass：6, Batch：50, Cost：0.036186, Accuracy：0.988971
# Pass：6, Batch：100, Cost：0.026046, Accuracy：0.973958
# Pass：6, Batch：150, Cost：0.023266, Accuracy：0.971507
# Pass：6, Batch：200, Cost：0.021534, Accuracy：0.974265
# Pass：6, Batch：250, Cost：0.034150, Accuracy：0.970282
# Pass：6, Batch：300, Cost：0.025082, Accuracy：0.971814
# Pass：6, Batch：350, Cost：0.023506, Accuracy：0.972426
# Pass：6, Batch：400, Cost：0.031686, Accuracy：0.970895
# Pass：6, Batch：450, Cost：0.020106, Accuracy：0.974571
# Pass：6, Batch：500, Cost：0.029906, Accuracy：0.971507
# Pass：6, Batch：550, Cost：0.033312, Accuracy：0.969056
# Pass：6, Batch：600, Cost：0.025774, Accuracy：0.972120
# Pass：6, Batch：650, Cost：0.024067, Accuracy：0.972120
# Pass：6, Batch：700, Cost：0.026996, Accuracy：0.973958
# Pass：6, Batch：750, Cost：0.018075, Accuracy：0.974877
# Pass：6, Batch：800, Cost：0.020963, Accuracy：0.975184
# Pass：6, Batch：850, Cost：0.025025, Accuracy：0.972426
# Pass：6, Batch：900, Cost：0.019512, Accuracy：0.974265
# Pass：6, Batch：950, Cost：0.026267, Accuracy：0.973039
# Pass：6, Batch：1000, Cost：0.024333, Accuracy：0.972733
# Pass：6, Batch：1050, Cost：0.034633, Accuracy：0.969669
# Pass：6, Batch：1100, Cost：0.030183, Accuracy：0.971201
# Pass：6, Batch：1150, Cost：0.028680, Accuracy：0.970282
# test - Pass: 6 Cost: 0.02326009400800985 Acc: 0.9929897937710438
# new BestPrecent: 0.9931476220538721 thie Precent: 0.9929897937710438
#
# Pass：7, Batch：50, Cost：0.022678, Accuracy：0.992953
# Pass：7, Batch：100, Cost：0.027555, Accuracy：0.971201
# Pass：7, Batch：150, Cost：0.023867, Accuracy：0.972426
# Pass：7, Batch：200, Cost：0.031871, Accuracy：0.971507
# Pass：7, Batch：250, Cost：0.029756, Accuracy：0.971201
# Pass：7, Batch：300, Cost：0.032478, Accuracy：0.971814
# Pass：7, Batch：350, Cost：0.026017, Accuracy：0.972426
# Pass：7, Batch：400, Cost：0.022000, Accuracy：0.974571
# Pass：7, Batch：450, Cost：0.026606, Accuracy：0.969975
# Pass：7, Batch：500, Cost：0.028923, Accuracy：0.970282
# Pass：7, Batch：550, Cost：0.030243, Accuracy：0.971201
# Pass：7, Batch：600, Cost：0.028064, Accuracy：0.971507
# Pass：7, Batch：650, Cost：0.024176, Accuracy：0.971507
# Pass：7, Batch：700, Cost：0.028198, Accuracy：0.971507
# Pass：7, Batch：750, Cost：0.033622, Accuracy：0.969975
# Pass：7, Batch：800, Cost：0.030418, Accuracy：0.970588
# Pass：7, Batch：850, Cost：0.022342, Accuracy：0.973039
# Pass：7, Batch：900, Cost：0.030251, Accuracy：0.970282
# Pass：7, Batch：950, Cost：0.023020, Accuracy：0.972733
# Pass：7, Batch：1000, Cost：0.034849, Accuracy：0.969669
# Pass：7, Batch：1050, Cost：0.037187, Accuracy：0.969363
# Pass：7, Batch：1100, Cost：0.027765, Accuracy：0.972733
# Pass：7, Batch：1150, Cost：0.035622, Accuracy：0.970282
# test - Pass: 7 Cost: 0.023370912291774147 Acc: 0.9923847853535354
# new BestPrecent: 0.9931476220538721 thie Precent: 0.9923847853535354
#
# Pass：8, Batch：50, Cost：0.024733, Accuracy：0.993566
# Pass：8, Batch：100, Cost：0.026044, Accuracy：0.970588
# Pass：8, Batch：150, Cost：0.026208, Accuracy：0.973039
# Pass：8, Batch：200, Cost：0.034735, Accuracy：0.969669
# Pass：8, Batch：250, Cost：0.025097, Accuracy：0.972426
# Pass：8, Batch：300, Cost：0.027386, Accuracy：0.972120
# Pass：8, Batch：350, Cost：0.022177, Accuracy：0.973652
# Pass：8, Batch：400, Cost：0.027682, Accuracy：0.972426
# Pass：8, Batch：450, Cost：0.035907, Accuracy：0.971507
# Pass：8, Batch：500, Cost：0.029066, Accuracy：0.971814
# Pass：8, Batch：550, Cost：0.030148, Accuracy：0.969669
# Pass：8, Batch：600, Cost：0.034557, Accuracy：0.971507
# Pass：8, Batch：650, Cost：0.032903, Accuracy：0.971507
# Pass：8, Batch：700, Cost：0.016950, Accuracy：0.974877
# Pass：8, Batch：750, Cost：0.023015, Accuracy：0.973039
# Pass：8, Batch：800, Cost：0.026581, Accuracy：0.971507
# Pass：8, Batch：850, Cost：0.022654, Accuracy：0.973346
# Pass：8, Batch：900, Cost：0.026106, Accuracy：0.971201
# Pass：8, Batch：950, Cost：0.028069, Accuracy：0.971507
# Pass：8, Batch：1000, Cost：0.022549, Accuracy：0.973958
# Pass：8, Batch：1050, Cost：0.027935, Accuracy：0.973346
# Pass：8, Batch：1100, Cost：0.029924, Accuracy：0.970588
# Pass：8, Batch：1150, Cost：0.024334, Accuracy：0.973652
# test - Pass: 8 Cost: 0.02298891876087736 Acc: 0.992739898989899
# new BestPrecent: 0.9931476220538721 thie Precent: 0.992739898989899
#
# Pass：9, Batch：50, Cost：0.019958, Accuracy：0.994792
# Pass：9, Batch：100, Cost：0.027286, Accuracy：0.971201
# Pass：9, Batch：150, Cost：0.033037, Accuracy：0.970895
# Pass：9, Batch：200, Cost：0.024243, Accuracy：0.972733
# Pass：9, Batch：250, Cost：0.024743, Accuracy：0.972120
# Pass：9, Batch：300, Cost：0.023034, Accuracy：0.972733
# Pass：9, Batch：350, Cost：0.025510, Accuracy：0.972733
# Pass：9, Batch：400, Cost：0.032081, Accuracy：0.971201
# Pass：9, Batch：450, Cost：0.022756, Accuracy：0.973652
# Pass：9, Batch：500, Cost：0.024294, Accuracy：0.971201
# Pass：9, Batch：550, Cost：0.026388, Accuracy：0.971507
# Pass：9, Batch：600, Cost：0.026959, Accuracy：0.971507
# Pass：9, Batch：650, Cost：0.033385, Accuracy：0.969363
# Pass：9, Batch：700, Cost：0.027910, Accuracy：0.972426
# Pass：9, Batch：750, Cost：0.017210, Accuracy：0.973652
# Pass：9, Batch：800, Cost：0.028539, Accuracy：0.972120
# Pass：9, Batch：850, Cost：0.024154, Accuracy：0.972120
# Pass：9, Batch：900, Cost：0.029579, Accuracy：0.970895
# Pass：9, Batch：950, Cost：0.022791, Accuracy：0.973652
# Pass：9, Batch：1000, Cost：0.020012, Accuracy：0.972733
# Pass：9, Batch：1050, Cost：0.033427, Accuracy：0.970588
# Pass：9, Batch：1100, Cost：0.026866, Accuracy：0.970895

# %%
save_model(save_model_name)

# %%
load_model(save_model_name)

# %%
save_inference(save_model_name)

# %%
test_image = test_list[19][20]
plt.figure()
plt.imshow(test_image)
test_image = np.array(test_image).astype('float32').reshape(1,1,64,64)/255
result = exe.run(program = test_program,feed = {'image':test_image,'label':np.array([[1]]).astype('int64')},fetch_list = [net])
print(np.argmax(result))
