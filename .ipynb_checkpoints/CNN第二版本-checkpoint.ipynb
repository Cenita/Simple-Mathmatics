# %%
import paddle as paddle
import paddle.fluid as fluid
import numpy as np
import matplotlib.pyplot as plt
import sys
import cv2
import os
import random
import math
import PIL.Image as Image
from paddle.fluid.initializer import MSRA
from paddle.fluid.param_attr import ParamAttr
from visualdl import LogWriter

# %%
data_shape = [28,28]


class AlexNet():
    def __init__(self):
        pass

    def net(self, input, class_dim=1000):
        stdv = 1.0 / math.sqrt(input.shape[1] * 5* 5)
        conv1 = fluid.layers.conv2d(
            input=input,
            num_filters=128,
            filter_size=5,
            stride=1,
            padding=2,
            groups=1,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))
        pool1 = fluid.layers.pool2d(
            input=conv1,
            pool_size=3,
            pool_stride=2,
            pool_padding=0,
            pool_type='max')

        stdv = 1.0 / math.sqrt(pool1.shape[1] * 5 * 5)
        conv2 = fluid.layers.conv2d(
            input=pool1,
            num_filters=192,
            filter_size=5,
            stride=1,
            padding=2,
            groups=1,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))
        pool2 = fluid.layers.pool2d(
            input=conv2,
            pool_size=3,
            pool_stride=2,
            pool_padding=0,
            pool_type='max')

        stdv = 1.0 / math.sqrt(pool2.shape[1] * 3 * 3)
        conv3 = fluid.layers.conv2d(
            input=pool2,
            num_filters=384,
            filter_size=3,
            stride=1,
            padding=1,
            groups=1,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))

        stdv = 1.0 / math.sqrt(conv3.shape[1] * 3 * 3)
        conv4 = fluid.layers.conv2d(
            input=conv3,
            num_filters=256,
            filter_size=3,
            stride=1,
            padding=1,
            groups=1,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))

        stdv = 1.0 / math.sqrt(conv4.shape[1] * 3 * 3)
        conv5 = fluid.layers.conv2d(
            input=conv4,
            num_filters=256,
            filter_size=3,
            stride=1,
            padding=1,
            groups=1,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))
        pool5 = fluid.layers.pool2d(
            input=conv5,
            pool_size=3,
            pool_stride=1,
            pool_padding=0,
            pool_type='max')
        print(pool5)
        drop6 = fluid.layers.dropout(x=pool5, dropout_prob=0.5)

        stdv = 1.0 / math.sqrt(drop6.shape[1] * drop6.shape[2] *
                               drop6.shape[3] * 1.0)
        fc6 = fluid.layers.fc(
            input=drop6,
            size=256,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))

        drop7 = fluid.layers.dropout(x=fc6, dropout_prob=0.5)

        stdv = 1.0 / math.sqrt(drop7.shape[1] * 1.0)
        fc7 = fluid.layers.fc(
            input=drop7,
            size=64,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))

        stdv = 1.0 / math.sqrt(fc7.shape[1] * 1.0)
        out = fluid.layers.fc(
            input=fc7,
            size=class_dim,
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),act='softmax')
        return out

# %%
yuzhi = 1
def addGaussianNoise(image,percetage): 
    G_Noiseimg = image 
    G_NoiseNum=int(percetage*image.shape[0]*image.shape[1]) 
    for i in range(G_NoiseNum): 
        temp_x = np.random.randint(0,image.shape[0]) 
        temp_y = np.random.randint(0,image.shape[0])
        G_Noiseimg[temp_x][temp_y] = 255
    return G_Noiseimg
def for_iterater_reader(t_list):
    def reader():
        for i in range(0,3000):
            for label in range(0,21):
              #  try:
                    #img = cv2.resize(img,(data_shape[0],data_shape[1]))
                    #img = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
                    #img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
                    if label == 10:#没有10这个数
                        continue
                    tmp_ran = train_list[label]
                    ran_int = random.randint(0,len(tmp_ran)-1)#取随机的一个数
                    img = np.array(tmp_ran[ran_int]).reshape(28,28)
                    img = np.array(img)
                    _, img = cv2.threshold(img, 10, 255,cv2.THRESH_BINARY)
                    if random.randint(0,1)==1:
                        img = addGaussianNoise(img,random.randint(0,300)/1000)
                    r_x = random.randint(-5,5)
                    r_y = random.randint(-5,5)
                    r_rota = random.randint(-2,2)
                    r_yh = random.randint(1,3)
                    img = Image.fromarray(img)
                    img = img.rotate(r_rota)
                    tmpimg = Image.new('L',(28,28))
                    tmpimg.paste(img,(r_x,r_y))
                    element1 = cv2.getStructuringElement(cv2.MORPH_RECT, (r_yh, r_yh))
                    tmpimg = cv2.dilate(np.array(tmpimg), element1, iterations = 1)
                    #img = cv2.blur(img,(20,20))#羽化
                    #ret, binary = cv2.threshold(img, 50, 255,cv2.THRESH_BINARY)
                    #element1 = cv2.getStructuringElement(cv2.MORPH_RECT, (10,10))#拓展
                    #img = cv2.erode(binary, element1, iterations = 1)
                    img = np.array(tmpimg)
                    ######################################################
                    img = img.reshape(1,data_shape[0],data_shape[1]).astype('float32')
                    img = (img)/255 
                    yield label,img
            #    except Exception:
             #       print(label)
    return reader

def for_test_reader(t_list):
    def reader():
        for class_index in t_list:
            image = np.array(class_index[1]).reshape(28,28)
            image = np.array(image).reshape(1,28,28).astype('float32')
            image = (image) / 255.0
            yield class_index[0],image
    return reader

# %%
#1.设置地方
place = fluid.CUDAPlace(0)
#2.设置数据和设置标签
label = fluid.layers.data(name = 'label',shape=[1],dtype='int64')
image = fluid.layers.data(name = 'image',shape=[1,data_shape[0],data_shape[1]],dtype='float32')
#3.设置网络和Feeder
feeder = fluid.DataFeeder(place = place , feed_list = [label,image])
net = AlexNet().net(image,21)
#4.设置损失函数和正确率
cost = fluid.layers.cross_entropy(input = net , label = label)
avg_cost = fluid.layers.mean(cost)
acc = fluid.layers.accuracy(input = net , label =label)
#.定义测试程序
test_program = fluid.default_main_program().clone(for_test=True)
#5.设置优化
optimizer = fluid.optimizer.Adam(learning_rate=0.001)
optimizer.minimize(avg_cost)
#6.定义Executor
exe = fluid.Executor(place = place)
exe.run(fluid.default_startup_program())
# Out:
# name: "pool2d_2.tmp_0"
# type {
#   type: LOD_TENSOR
#   lod_tensor {
#     tensor {
#       data_type: FP32
#       dims: -1
#       dims: 256
#       dims: 4
#       dims: 4
#     }
#     lod_level: 0
#   }
# }
# persistable: false
# []

# %%
def produce_path_label(path):
    train_list = [[] * 1 for i in range(0,21)]
    train_data = open(path).readlines()
    for i in train_data:
        items = i.split(',')
        class_index = int(items[0])
        img = np.array(items[1:]).astype('uint8')
        train_list[class_index].append([img])
    return train_list

def produce_test(path):
    train_list = []
    train_data = open(path).readlines()
    for i in train_data:
        items = i.split(',')
        class_index = int(items[0])
        img = np.array(items[1:]).astype('uint8')
        train_list.append([class_index,img])
    return train_list
train_list = produce_path_label('train_list.txt')
test_list = produce_path_label('test_list.txt')
true_test_list = produce_test('true_test_list.txt')

# %%
import shutil
import os
def save_inference(pass_id):
     # 保存预测模型
    save_path = 'models/infer_model/'+str(pass_id)+"/"
    # 删除旧的模型文件
    shutil.rmtree(save_path, ignore_errors=True)
    # 创建保持模型文件目录
    os.makedirs(save_path)
    # 保存预测模型
    fluid.io.save_inference_model(save_path, feeded_var_names=[image.name], target_vars=[net], executor=exe)

def save_model(pass_id):
    # 保存参数模型
    save_path = 'models/params_model/'+str(pass_id)+"/"
    # 删除旧的模型文件
    shutil.rmtree(save_path, ignore_errors=True)
    # 创建保持模型文件目录
    os.makedirs(save_path)
    # 保存参数模型
    fluid.io.save_params(executor=exe, dirname=save_path)

def load_model(pass_id):
    # 加载之前训练过的参数模型
    save_path = 'models/params_model/'+str(pass_id)
    if os.path.exists(save_path):
        print('使用参数模型作为预训练模型')
        fluid.io.load_params(executor=exe, dirname=save_path)

# %%
#8.数据分批
train_Reader = paddle.batch(reader=paddle.reader.shuffle(for_iterater_reader(train_list),buf_size = 128*128),batch_size=128)
test_Reader = paddle.batch(reader=paddle.reader.shuffle(for_iterater_reader(test_list),buf_size = 128*128),batch_size=128)
true_test_Reader = paddle.batch(reader=paddle.reader.shuffle(for_test_reader(true_test_list),buf_size = 128*128),batch_size=128)

# %%
#load_model(26)

# %%
#9.训练
step = 0
best_model_precent = 1.98
error_cout = 20
save_model_name = 35
optimizer = fluid.optimizer.Adam(learning_rate=0.001)

# %%
 def train():
    for pass_id in range(20000):
        sum_cost=0
        sum_acc=0
        global best_model_precent
        for batch_id , data in enumerate(train_Reader()):
            train_cost, train_acc = exe.run(program = fluid.default_main_program(),
                                           feed = feeder.feed(data),
                                            fetch_list = [avg_cost,acc]
                                           )
            sum_cost = sum_cost + train_cost[0]
            sum_acc = sum_acc + train_acc[0]
            if batch_id % 50 == 0 and batch_id != 0:
                print('Pass：%d, Batch：%d, Cost：%f, Accuracy：%f' % (pass_id , batch_id , sum_cost/51, sum_acc/51))
                sum_cost = 0
                sum_acc = 0
        
        test_sum_cost=0
        test_sum_acc=0
        test_cout = 0
        for batch_id , data in enumerate(test_Reader()):
            train_cost, train_acc = exe.run(program = test_program,
                                           feed = feeder.feed(data),
                                            fetch_list = [avg_cost,acc]
                                           )
            test_sum_cost = test_sum_cost + train_cost[0]
            test_sum_acc = test_sum_acc + train_acc[0]
            test_cout+=1
        print("test - Pass:",pass_id,"Cost:",test_sum_cost/test_cout,"Acc:",test_sum_acc/test_cout)
        true_sum_cost=0
        true_sum_acc=0
        true_cout = 0
        for batch_id , data in enumerate(true_test_Reader()):
            train_cost, train_acc = exe.run(program = test_program,
                                           feed = feeder.feed(data),
                                            fetch_list = [avg_cost,acc]
                                           )
            true_sum_cost = true_sum_cost + train_cost[0]
            true_sum_acc = true_sum_acc + train_acc[0]
            true_cout+=1
        print("true test - Pass:",pass_id,"Cost:",true_sum_cost/true_cout,"Acc:",true_sum_acc/true_cout)
        total_model_precent = (test_sum_acc/test_cout)+(true_sum_acc/true_cout)
        print("new BestPrecent:",best_model_precent,"thie Precent:",total_model_precent)
        if total_model_precent > best_model_precent:
            best_model_precent = total_model_precent
            save_model(save_model_name)
            print("Save...model...Best_precent:",best_model_precent)
        print()
train()
# Out:
# Pass：0, Batch：50, Cost：3.010464, Accuracy：0.056219
# Pass：0, Batch：100, Cost：2.780121, Accuracy：0.076440
# Pass：0, Batch：150, Cost：2.515183, Accuracy：0.116422
# Pass：0, Batch：200, Cost：2.243087, Accuracy：0.191330
# Pass：0, Batch：250, Cost：1.945617, Accuracy：0.273284
# Pass：0, Batch：300, Cost：1.640023, Accuracy：0.390472
# Pass：0, Batch：350, Cost：1.287579, Accuracy：0.532629
# Pass：0, Batch：400, Cost：1.030458, Accuracy：0.637408
# Pass：0, Batch：450, Cost：0.788185, Accuracy：0.721814
# test - Pass: 0 Cost: 0.6637091731974311 Acc: 0.7924828980523132
# true test - Pass: 0 Cost: 0.5561838448047638 Acc: 0.8477044800917307
# new BestPrecent: 1.98 thie Precent: 1.640187378144044
#
# Pass：1, Batch：50, Cost：0.644323, Accuracy：0.790135
# Pass：1, Batch：100, Cost：0.538031, Accuracy：0.817402
# Pass：1, Batch：150, Cost：0.449869, Accuracy：0.844822
# Pass：1, Batch：200, Cost：0.421810, Accuracy：0.859375
# Pass：1, Batch：250, Cost：0.383147, Accuracy：0.868413
# Pass：1, Batch：300, Cost：0.367520, Accuracy：0.872702
# Pass：1, Batch：350, Cost：0.290877, Accuracy：0.891391
# Pass：1, Batch：400, Cost：0.324088, Accuracy：0.882966
# Pass：1, Batch：450, Cost：0.284358, Accuracy：0.895374
# test - Pass: 1 Cost: 0.23423262480606657 Acc: 0.9272277008241682
# true test - Pass: 1 Cost: 0.2734059194723765 Acc: 0.9153163631757101
# new BestPrecent: 1.98 thie Precent: 1.8425440639998782
#
# Pass：2, Batch：50, Cost：0.290962, Accuracy：0.914522
# Pass：2, Batch：100, Cost：0.271961, Accuracy：0.903952
# Pass：2, Batch：150, Cost：0.274508, Accuracy：0.903493
# Pass：2, Batch：200, Cost：0.267476, Accuracy：0.905484
# Pass：2, Batch：250, Cost：0.250082, Accuracy：0.910692
# Pass：2, Batch：300, Cost：0.223856, Accuracy：0.916360
# Pass：2, Batch：350, Cost：0.219378, Accuracy：0.914828
# Pass：2, Batch：400, Cost：0.225970, Accuracy：0.916513
# Pass：2, Batch：450, Cost：0.234309, Accuracy：0.914982
# test - Pass: 2 Cost: 0.17265658589727334 Acc: 0.9475057747826647
# true test - Pass: 2 Cost: 0.1642112284898758 Acc: 0.941840281089147
# new BestPrecent: 1.98 thie Precent: 1.8893460558718118
#
# Pass：3, Batch：50, Cost：0.215486, Accuracy：0.938572
# Pass：3, Batch：100, Cost：0.216212, Accuracy：0.918199
# Pass：3, Batch：150, Cost：0.204174, Accuracy：0.919271
# Pass：3, Batch：200, Cost：0.195377, Accuracy：0.925858
# Pass：3, Batch：250, Cost：0.202739, Accuracy：0.924786
# Pass：3, Batch：300, Cost：0.212910, Accuracy：0.918658
# Pass：3, Batch：350, Cost：0.179265, Accuracy：0.929381
# Pass：3, Batch：400, Cost：0.182818, Accuracy：0.927083
# Pass：3, Batch：450, Cost：0.182712, Accuracy：0.929994
# test - Pass: 3 Cost: 0.17718061426682258 Acc: 0.94725035540839
# true test - Pass: 3 Cost: 0.1097660722831885 Acc: 0.9677854975064596
# new BestPrecent: 1.98 thie Precent: 1.9150358529148495
#
# Pass：4, Batch：50, Cost：0.189327, Accuracy：0.947763
# Pass：4, Batch：100, Cost：0.160064, Accuracy：0.932598
# Pass：4, Batch：150, Cost：0.178091, Accuracy：0.928615
# Pass：4, Batch：200, Cost：0.173779, Accuracy：0.931066
# Pass：4, Batch：250, Cost：0.145461, Accuracy：0.935509
# Pass：4, Batch：300, Cost：0.192435, Accuracy：0.926164
# Pass：4, Batch：350, Cost：0.173731, Accuracy：0.932292
# Pass：4, Batch：400, Cost：0.161370, Accuracy：0.937347
# Pass：4, Batch：450, Cost：0.156497, Accuracy：0.935815
# test - Pass: 4 Cost: 0.1286350070778876 Acc: 0.9621979389617692
# true test - Pass: 4 Cost: 0.16278282925486565 Acc: 0.9495563308397929
# new BestPrecent: 1.98 thie Precent: 1.9117542698015622
#
# Pass：5, Batch：50, Cost：0.176897, Accuracy：0.948683
# Pass：5, Batch：100, Cost：0.167988, Accuracy：0.934896
# Pass：5, Batch：150, Cost：0.156105, Accuracy：0.937653
# Pass：5, Batch：200, Cost：0.170110, Accuracy：0.930913
# Pass：5, Batch：250, Cost：0.154021, Accuracy：0.937347
# Pass：5, Batch：300, Cost：0.137614, Accuracy：0.938113
# Pass：5, Batch：350, Cost：0.151976, Accuracy：0.934896
# Pass：5, Batch：400, Cost：0.165887, Accuracy：0.935355
# Pass：5, Batch：450, Cost：0.137570, Accuracy：0.939798
# test - Pass: 5 Cost: 0.1365662463096731 Acc: 0.958749777980959
# true test - Pass: 5 Cost: 0.10170309990644455 Acc: 0.9745370348294576
# new BestPrecent: 1.98 thie Precent: 1.9332868128104166
#
# Pass：6, Batch：50, Cost：0.166816, Accuracy：0.952819
# Pass：6, Batch：100, Cost：0.142115, Accuracy：0.940717
# Pass：6, Batch：150, Cost：0.153671, Accuracy：0.937960
# Pass：6, Batch：200, Cost：0.151229, Accuracy：0.936428
# Pass：6, Batch：250, Cost：0.132515, Accuracy：0.943474
# Pass：6, Batch：300, Cost：0.146832, Accuracy：0.939032
# Pass：6, Batch：350, Cost：0.134002, Accuracy：0.942096
# Pass：6, Batch：400, Cost：0.145219, Accuracy：0.939951
# Pass：6, Batch：450, Cost：0.143832, Accuracy：0.939798
# test - Pass: 6 Cost: 0.11636071316580147 Acc: 0.9648076581802449
# true test - Pass: 6 Cost: 0.23550882190465927 Acc: 0.934124231338501
# new BestPrecent: 1.98 thie Precent: 1.898931889518746
#
# Pass：7, Batch：50, Cost：0.134500, Accuracy：0.961091
# Pass：7, Batch：100, Cost：0.133520, Accuracy：0.944087
# Pass：7, Batch：150, Cost：0.135417, Accuracy：0.943474
# Pass：7, Batch：200, Cost：0.129443, Accuracy：0.943015
# Pass：7, Batch：250, Cost：0.131197, Accuracy：0.942402
# Pass：7, Batch：300, Cost：0.123018, Accuracy：0.942096
# Pass：7, Batch：350, Cost：0.128833, Accuracy：0.941942
# Pass：7, Batch：400, Cost：0.143681, Accuracy：0.941942
# Pass：7, Batch：450, Cost：0.146923, Accuracy：0.942096
# test - Pass: 7 Cost: 0.13158203647938618 Acc: 0.9617537313432836
# true test - Pass: 7 Cost: 0.09507969145973523 Acc: 0.9786844154198965
# new BestPrecent: 1.98 thie Precent: 1.9404381467631802
#
# Pass：8, Batch：50, Cost：0.132626, Accuracy：0.961091
# Pass：8, Batch：100, Cost：0.127888, Accuracy：0.943015
# Pass：8, Batch：150, Cost：0.125849, Accuracy：0.945006
# Pass：8, Batch：200, Cost：0.115382, Accuracy：0.948070
# Pass：8, Batch：250, Cost：0.137879, Accuracy：0.941942
# Pass：8, Batch：300, Cost：0.122657, Accuracy：0.946385
# Pass：8, Batch：350, Cost：0.146242, Accuracy：0.942555
# Pass：8, Batch：400, Cost：0.127553, Accuracy：0.946844
# Pass：8, Batch：450, Cost：0.108202, Accuracy：0.949449
# test - Pass: 8 Cost: 0.09097961028183955 Acc: 0.9720482409381663
# true test - Pass: 8 Cost: 0.1782826123138269 Acc: 0.9506172835826874
# new BestPrecent: 1.98 thie Precent: 1.9226655245208537
#
# Pass：9, Batch：50, Cost：0.121819, Accuracy：0.962929
# Pass：9, Batch：100, Cost：0.131142, Accuracy：0.944087
# Pass：9, Batch：150, Cost：0.124427, Accuracy：0.941176
# Pass：9, Batch：200, Cost：0.126303, Accuracy：0.945006
# Pass：9, Batch：250, Cost：0.128532, Accuracy：0.945925
# Pass：9, Batch：300, Cost：0.121949, Accuracy：0.946538
# Pass：9, Batch：350, Cost：0.127915, Accuracy：0.944700
# Pass：9, Batch：400, Cost：0.130609, Accuracy：0.943168
# Pass：9, Batch：450, Cost：0.125001, Accuracy：0.945925
# test - Pass: 9 Cost: 0.09616352463149026 Acc: 0.9711154051172708
# true test - Pass: 9 Cost: 0.19331614300608635 Acc: 0.9521604975064596
# new BestPrecent: 1.98 thie Precent: 1.9232759026237303
#
# Pass：10, Batch：50, Cost：0.147047, Accuracy：0.960478
# Pass：10, Batch：100, Cost：0.113262, Accuracy：0.949295
# Pass：10, Batch：150, Cost：0.116960, Accuracy：0.943627
# Pass：10, Batch：200, Cost：0.115286, Accuracy：0.948376
# Pass：10, Batch：250, Cost：0.112903, Accuracy：0.948376
# Pass：10, Batch：300, Cost：0.119944, Accuracy：0.945925
# Pass：10, Batch：350, Cost：0.142913, Accuracy：0.937653
# Pass：10, Batch：400, Cost：0.105139, Accuracy：0.948376
# Pass：10, Batch：450, Cost：0.109274, Accuracy：0.946538
# test - Pass: 10 Cost: 0.09877049835768145 Acc: 0.9713152985074627
# true test - Pass: 10 Cost: 0.12088385907312234 Acc: 0.9693287014961243
# new BestPrecent: 1.98 thie Precent: 1.940644000003587
#
# Pass：11, Batch：50, Cost：0.126125, Accuracy：0.965533
# Pass：11, Batch：100, Cost：0.116263, Accuracy：0.947151
# Pass：11, Batch：150, Cost：0.125227, Accuracy：0.945159
# Pass：11, Batch：200, Cost：0.112499, Accuracy：0.948836
# Pass：11, Batch：250, Cost：0.119472, Accuracy：0.944547
# Pass：11, Batch：300, Cost：0.132297, Accuracy：0.942862
# Pass：11, Batch：350, Cost：0.111671, Accuracy：0.947457
# Pass：11, Batch：400, Cost：0.112546, Accuracy：0.946232
# Pass：11, Batch：450, Cost：0.109268, Accuracy：0.948989
# test - Pass: 11 Cost: 0.09027855060716618 Acc: 0.9717150852878464
# true test - Pass: 11 Cost: 0.13402648270130157 Acc: 0.9778645833333334
# new BestPrecent: 1.98 thie Precent: 1.9495796686211797
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d83769da6282> in <module>
#      47            print("Save...model...Best_precent:",best_model_precent)
#      48        print()
# ---> 49 train()
#
# <ipython-input-10-d83769da6282> in train()
#       4        sum_acc=0
#       5        global best_model_precent
# ----> 6        for batch_id , data in enumerate(train_Reader()):
#       7            train_cost, train_acc = exe.run(program = fluid.default_main_program(),
#       8                                           feed = feeder.feed(data),
#
# d:\python3.6\lib\site-packages\paddle\batch.py in batch_reader()
#      33         r = reader()
#      34         b = []
# ---> 35         for instance in r:
#      36             b.append(instance)
#      37             if len(b) == batch_size:
#
# d:\python3.6\lib\site-packages\paddle\reader\decorator.py in data_reader()
#      75     def data_reader():
#      76         buf = []
# ---> 77         for e in reader():
#      78             buf.append(e)
#      79             if len(buf) >= buf_size:
#
# <ipython-input-3-00c6e3975c8f> in reader()
#      32                     tmpimg = Image.new('L',(28,28))
#      33                     tmpimg.paste(img,(r_x,r_y))
# ---> 34                     element1 = cv2.getStructuringElement(cv2.MORPH_RECT, (r_yh, r_yh))
#      35                     tmpimg = cv2.dilate(np.array(tmpimg), element1, iterations = 1)
#      36                     #img = cv2.blur(img,(20,20))#羽化
#
# KeyboardInterrupt:

# %%
save_inference(save_model_name)
