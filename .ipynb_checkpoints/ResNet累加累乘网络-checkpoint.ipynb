# %%
import paddle as paddle
import paddle.fluid as fluid
import numpy as np
import matplotlib.pyplot as plt
import sys
import cv2
import os
import random
import math
import PIL.Image as Image
from paddle.fluid.initializer import MSRA
from paddle.fluid.param_attr import ParamAttr
from visualdl import LogWriter

# %%
def produce_path_label(path):
    train_list = np.load(path)
    return train_list

def produce_test(path):
    train_list = []
    train_data = open(path).readlines()
    for i in train_data:
        items = i.split(',')
        class_index = int(items[0])
        img = np.array(items[1:]).astype('uint8')
        train_list.append([class_index,img])
    return train_list

train_list = produce_path_label('data/Acc_train_list.npy')
test_list = produce_path_label('data/Acc_test_list.npy')
class_number = len(train_list)
print(class_number)
# Out:
# 24

# %%
data_shape = [64,64]

# %%
class ResNet():
    def __init__(self, layers=50):
        self.layers = layers

    def net(self, input, class_dim=1000):
        layers = self.layers
        if layers == 18:
            depth = [2, 2, 2, 2]
        if layers == 50:
            depth = [3, 4, 6, 3]
        elif layers == 101:
            depth = [3, 4, 23, 3]
        elif layers == 152:
            depth = [3, 8, 36, 3]
        num_filters = [64, 128, 256, 512]
        conv = self.conv_bn_layer(
            input=input, num_filters=64, filter_size=7, stride=2, act='relu')
        conv = fluid.layers.pool2d(
            input=conv,
            pool_size=3,
            pool_stride=2,
            pool_padding=1,
            pool_type='max')
        for block in range(len(depth)):
            for i in range(depth[block]):
                conv = self.bottleneck_block(
                    input=conv,
                    num_filters=num_filters[block],
                    stride=2 if i == 0 and block != 0 else 1)
        pool = fluid.layers.pool2d(
            input=conv, pool_size=7, pool_type='avg', global_pooling=True)
        stdv = 1.0 / math.sqrt(pool.shape[1] * 1.0)
        out = fluid.layers.fc(input=pool,
                              act = 'softmax',
                              size=class_dim,
                              param_attr=fluid.param_attr.ParamAttr(
                                  initializer=fluid.initializer.Uniform(-stdv,
                                                                        stdv)))
        return out
    def conv_bn_layer(self,
                      input,
                      num_filters,
                      filter_size,
                      stride=1,
                      groups=1,
                      act=None):
        conv = fluid.layers.conv2d(
            input=input,
            num_filters=num_filters,
            filter_size=filter_size,
            stride=stride,
            padding=(filter_size - 1) // 2,
            groups=groups,
            act=None,
            bias_attr=False)
        return fluid.layers.batch_norm(input=conv, act=act)

    def shortcut(self, input, ch_out, stride):
        ch_in = input.shape[1]
        if ch_in != ch_out or stride != 1:
            return self.conv_bn_layer(input, ch_out, 1, stride)
        else:
            return input

    def bottleneck_block(self, input, num_filters, stride):
        conv0 = self.conv_bn_layer(
            input=input, num_filters=num_filters, filter_size=1, act='relu')
        conv1 = self.conv_bn_layer(
            input=conv0,
            num_filters=num_filters,
            filter_size=3,
            stride=stride,
            act='relu')
        conv2 = self.conv_bn_layer(
            input=conv1, num_filters=num_filters * 4, filter_size=1, act=None)
        short = self.shortcut(input, num_filters * 4, stride)
        return fluid.layers.elementwise_add(x=short, y=conv2, act='relu')


def ResNet50():
    model = ResNet(layers=18)
    return model

# %%
yuzhi = 1
def addGaussianNoise(image): 
    G_Noiseimg = np.array(image)
    G_NoiseNum=random.randint(1,5)
    for i in range(G_NoiseNum): 
        temp_x = np.random.randint(0,image.shape[0])
        temp_y = np.random.randint(0,image.shape[0])
        temp_x_size = np.random.randint(1,5)
        temp_y_size = np.random.randint(1,5)
        temp_x_end = min(image.shape[0],temp_x+temp_x_size)
        temp_y_end = min(image.shape[0],temp_y+temp_y_size)
        for x in range(temp_x,temp_x_end):
            for y in range(temp_y,temp_y_end):
                G_Noiseimg[x][y] = 255
    return G_Noiseimg
def for_iterater_reader(t_list):
    def reader():
        for i in range(0,4000):
            for label in range(0,class_number):
              #  try:
                    #img = cv2.resize(img,(data_shape[0],data_shape[1]))
                    #img = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
                    #img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
                    tmp_ran = train_list[label]
                    ran_int = random.randint(0,len(tmp_ran)-1)#取随机的一个数
                    img = np.array(tmp_ran[ran_int]).reshape(64,64)
                    r_sofang = random.randint(6,12)/10
                    shape = int(r_sofang*data_shape[0])
                    img = Image.fromarray(img).resize((shape,shape))
                    img = np.array(img)
                    _, img = cv2.threshold(img, 10, 255,cv2.THRESH_BINARY)
                    r_x = random.randint(-5,5)
                    r_y = random.randint(-5,5)
                    r_rota = random.randint(-5,5)
                    r_yh = random.randint(1,3)
                    img = Image.fromarray(img)
                    img = img.rotate(r_rota)
                    tmpimg = Image.new('L',(data_shape[0],data_shape[0]))
                    tmpimg.paste(img,(r_x,r_y))
                    element1 = cv2.getStructuringElement(cv2.MORPH_RECT, (r_yh, r_yh))
                    tmpimg = cv2.dilate(np.array(tmpimg), element1, iterations = 1)
                    tmpimg = addGaussianNoise(tmpimg)
                    #img = cv2.blur(img,(20,20))#羽化
                    #ret, binary = cv2.threshold(img, 50, 255,cv2.THRESH_BINARY)
                    #element1 = cv2.getStructuringElement(cv2.MORPH_RECT, (10,10))#拓展
                    #img = cv2.erode(binary, element1, iterations = 1)
                    img = np.array(tmpimg)
                    ######################################################
                    img = img.reshape(1,data_shape[0],data_shape[1]).astype('float32')
                    img = (img)/255 
                    yield label,img
            #    except Exception:
             #       print(label)
    return reader

def for_test_reader(t_list):
    def reader():
        for class_index in t_list:
            image = np.array(class_index[1]).reshape(64,64)
            image = Image.fromarray(image).resize((data_shape[0],data_shape[0]))
            image = np.array(image).reshape(1,data_shape[0],data_shape[0]).astype('float32')
            image = (image) / 255.0
            yield class_index[0],image
    return reader

# %%
#1.设置地方
place = fluid.CUDAPlace(0)
#2.设置数据和设置标签
label = fluid.layers.data(name = 'label',shape=[1],dtype='int64')
image = fluid.layers.data(name = 'image',shape=[1,data_shape[0],data_shape[1]],dtype='float32')
#3.设置网络和Feeder
feeder = fluid.DataFeeder(place = place , feed_list = [label,image])
net = ResNet50().net(image,class_number)
#4.设置损失函数和正确率
cost = fluid.layers.cross_entropy(input = net , label = label)
avg_cost = fluid.layers.mean(cost)
acc = fluid.layers.accuracy(input = net , label =label)
#.定义测试程序
test_program = fluid.default_main_program().clone(for_test=True)
#5.设置优化
LR = 0.001
piecewise_decay = fluid.layers.piecewise_decay([5000,10000,15000], [LR, LR * 0.01,LR * 0.001,LR * 0.0001])
optimizer = fluid.optimizer.Adam(learning_rate=piecewise_decay)
optimizer.minimize(avg_cost)
#6.定义Executor
exe = fluid.Executor(place = place)
exe.run(fluid.default_startup_program())
# Out:
# []

# %%
import shutil
import os
def save_inference(pass_id):
     # 保存预测模型
    save_path = 'models/infer_model/'+str(pass_id)+"/"
    # 删除旧的模型文件
    shutil.rmtree(save_path, ignore_errors=True)
    # 创建保持模型文件目录
    os.makedirs(save_path)
    # 保存预测模型
    fluid.io.save_inference_model(save_path, feeded_var_names=[image.name], target_vars=[net], executor=exe)

def save_model(pass_id):
    # 保存参数模型
    save_path = 'models/params_model/'+str(pass_id)+"/"
    # 删除旧的模型文件
    shutil.rmtree(save_path, ignore_errors=True)
    # 创建保持模型文件目录
    os.makedirs(save_path)
    # 保存参数模型
    fluid.io.save_params(executor=exe, dirname=save_path)

def load_model(pass_id):
    # 加载之前训练过的参数模型
    save_path = 'models/params_model/'+str(pass_id)
    if os.path.exists(save_path):
        print('使用参数模型作为预训练模型')
        fluid.io.load_params(executor=exe, dirname=save_path)

# %%
#8.数据分批
train_Reader = paddle.batch(reader=paddle.reader.shuffle(for_iterater_reader(train_list),buf_size = 128*128),batch_size=64)
test_Reader = paddle.batch(reader=paddle.reader.shuffle(for_iterater_reader(test_list),buf_size = 128*128),batch_size=64)

# %%
print("加载完毕")
# Out:
# 加载完毕

# %%
#9.训练
step = 0
best_model_precent = 0
error_cout = 20
save_model_name = 100

# %%
load_model(save_model_name)
# Out:
# 使用参数模型作为预训练模型

# %%
 def train():
    for pass_id in range(20000):
        sum_cost=0
        sum_acc=0
        global best_model_precent
        for batch_id , data in enumerate(train_Reader()):
            train_cost, train_acc = exe.run(program = fluid.default_main_program(),
                                           feed = feeder.feed(data),
                                            fetch_list = [avg_cost,acc]
                                           )
            sum_cost = sum_cost + train_cost[0]
            sum_acc = sum_acc + train_acc[0]
            if batch_id % 50 == 0 and batch_id != 0:
                print('Pass：%d, Batch：%d, Cost：%f, Accuracy：%f' % (pass_id , batch_id , sum_cost/51, sum_acc/51))
                sum_cost = 0
                sum_acc = 0
        test_sum_cost=0
        test_sum_acc=0
        test_cout = 0
        for batch_id , data in enumerate(test_Reader()):
            train_cost, train_acc = exe.run(program = test_program,
                                           feed = feeder.feed(data),
                                            fetch_list = [avg_cost,acc]
                                           )
            test_sum_cost = test_sum_cost + train_cost[0]
            test_sum_acc = test_sum_acc + train_acc[0]
            test_cout+=1
        print("test - Pass:",pass_id,"Cost:",test_sum_cost/test_cout,"Acc:",test_sum_acc/test_cout)
        total_model_precent = (test_sum_acc/test_cout)
        print("new BestPrecent:",best_model_precent,"thie Precent:",total_model_precent)
        if total_model_precent > best_model_precent:
            best_model_precent = total_model_precent
            save_model(save_model_name)
            print("Save...model...Best_precent:",best_model_precent)
        print()
train()
# Out:
# Pass：0, Batch：50, Cost：0.037423, Accuracy：0.989277
# Pass：0, Batch：100, Cost：0.028530, Accuracy：0.970282
# Pass：0, Batch：150, Cost：0.027718, Accuracy：0.971507
# Pass：0, Batch：200, Cost：0.025023, Accuracy：0.972426
# Pass：0, Batch：250, Cost：0.018894, Accuracy：0.972733
# Pass：0, Batch：300, Cost：0.015130, Accuracy：0.974571
# Pass：0, Batch：350, Cost：0.023593, Accuracy：0.973039
# Pass：0, Batch：400, Cost：0.025312, Accuracy：0.972733
# Pass：0, Batch：450, Cost：0.027491, Accuracy：0.968444
# Pass：0, Batch：500, Cost：0.019316, Accuracy：0.972426
# Pass：0, Batch：550, Cost：0.021738, Accuracy：0.974571
# Pass：0, Batch：600, Cost：0.016394, Accuracy：0.974571
# Pass：0, Batch：650, Cost：0.022594, Accuracy：0.973652
# Pass：0, Batch：700, Cost：0.026244, Accuracy：0.972733
# Pass：0, Batch：750, Cost：0.019482, Accuracy：0.973039
# Pass：0, Batch：800, Cost：0.022096, Accuracy：0.973652
# Pass：0, Batch：850, Cost：0.017691, Accuracy：0.975797
# Pass：0, Batch：900, Cost：0.014995, Accuracy：0.975184
# Pass：0, Batch：950, Cost：0.013509, Accuracy：0.976716
# Pass：0, Batch：1000, Cost：0.017965, Accuracy：0.973652
# Pass：0, Batch：1050, Cost：0.018354, Accuracy：0.974571
# Pass：0, Batch：1100, Cost：0.021960, Accuracy：0.973346
# Pass：0, Batch：1150, Cost：0.028184, Accuracy：0.971201
# Pass：0, Batch：1200, Cost：0.015679, Accuracy：0.974877
# Pass：0, Batch：1250, Cost：0.022661, Accuracy：0.973958
# Pass：0, Batch：1300, Cost：0.016370, Accuracy：0.974571
# Pass：0, Batch：1350, Cost：0.014622, Accuracy：0.975184
# Pass：0, Batch：1400, Cost：0.023576, Accuracy：0.974265
# Pass：0, Batch：1450, Cost：0.018721, Accuracy：0.975797
# test - Pass: 0 Cost: 0.016374689078858258 Acc: 0.9947916666666666
# new BestPrecent: 0 thie Precent: 0.9947916666666666
# Save...model...Best_precent: 0.9947916666666666
#
# Pass：1, Batch：50, Cost：0.023012, Accuracy：0.992647
# Pass：1, Batch：100, Cost：0.017228, Accuracy：0.973346
# Pass：1, Batch：150, Cost：0.016930, Accuracy：0.975797
# Pass：1, Batch：200, Cost：0.011544, Accuracy：0.976103
# Pass：1, Batch：250, Cost：0.025603, Accuracy：0.971814
# Pass：1, Batch：300, Cost：0.016494, Accuracy：0.974265
# Pass：1, Batch：350, Cost：0.013670, Accuracy：0.974265
# Pass：1, Batch：400, Cost：0.011803, Accuracy：0.976103
# Pass：1, Batch：450, Cost：0.019142, Accuracy：0.975184
# Pass：1, Batch：500, Cost：0.021062, Accuracy：0.973958
# Pass：1, Batch：550, Cost：0.016858, Accuracy：0.974571
# Pass：1, Batch：600, Cost：0.016818, Accuracy：0.973039
# Pass：1, Batch：650, Cost：0.024593, Accuracy：0.973039
# Pass：1, Batch：700, Cost：0.016621, Accuracy：0.974877
# Pass：1, Batch：750, Cost：0.023110, Accuracy：0.973346
# Pass：1, Batch：800, Cost：0.013477, Accuracy：0.976716
# Pass：1, Batch：850, Cost：0.010959, Accuracy：0.977022
# Pass：1, Batch：900, Cost：0.025039, Accuracy：0.973652
# Pass：1, Batch：950, Cost：0.019462, Accuracy：0.975184
# Pass：1, Batch：1000, Cost：0.016582, Accuracy：0.975184
# Pass：1, Batch：1050, Cost：0.012805, Accuracy：0.977328
# Pass：1, Batch：1100, Cost：0.015001, Accuracy：0.975490
# Pass：1, Batch：1150, Cost：0.019497, Accuracy：0.971814
# Pass：1, Batch：1200, Cost：0.020431, Accuracy：0.973039
# Pass：1, Batch：1250, Cost：0.018107, Accuracy：0.975797
# Pass：1, Batch：1300, Cost：0.019231, Accuracy：0.974265
# Pass：1, Batch：1350, Cost：0.017229, Accuracy：0.974265
# Pass：1, Batch：1400, Cost：0.017940, Accuracy：0.974571
# Pass：1, Batch：1450, Cost：0.015673, Accuracy：0.976409
# test - Pass: 1 Cost: 0.014736197886743563 Acc: 0.9955104166666666
# new BestPrecent: 0.9947916666666666 thie Precent: 0.9955104166666666
# Save...model...Best_precent: 0.9955104166666666
#
# Pass：2, Batch：50, Cost：0.024694, Accuracy：0.992647
# Pass：2, Batch：100, Cost：0.019425, Accuracy：0.973652
# Pass：2, Batch：150, Cost：0.018425, Accuracy：0.974877
# Pass：2, Batch：200, Cost：0.013503, Accuracy：0.977328
# Pass：2, Batch：250, Cost：0.018205, Accuracy：0.974877
# Pass：2, Batch：300, Cost：0.011954, Accuracy：0.976103
# Pass：2, Batch：350, Cost：0.010539, Accuracy：0.976716
# Pass：2, Batch：400, Cost：0.010424, Accuracy：0.976716
# Pass：2, Batch：450, Cost：0.017994, Accuracy：0.972733
# Pass：2, Batch：500, Cost：0.012958, Accuracy：0.975797
# Pass：2, Batch：550, Cost：0.018041, Accuracy：0.975184
# Pass：2, Batch：600, Cost：0.009934, Accuracy：0.977941
# Pass：2, Batch：650, Cost：0.020500, Accuracy：0.973652
# Pass：2, Batch：700, Cost：0.018676, Accuracy：0.973958
# Pass：2, Batch：750, Cost：0.014932, Accuracy：0.977022
# Pass：2, Batch：800, Cost：0.008287, Accuracy：0.978860
# Pass：2, Batch：850, Cost：0.020343, Accuracy：0.973652
# Pass：2, Batch：900, Cost：0.023717, Accuracy：0.973652
# Pass：2, Batch：950, Cost：0.015887, Accuracy：0.974571
# Pass：2, Batch：1000, Cost：0.012419, Accuracy：0.975490
# Pass：2, Batch：1050, Cost：0.016254, Accuracy：0.976103
# Pass：2, Batch：1100, Cost：0.012696, Accuracy：0.976409
# Pass：2, Batch：1150, Cost：0.015814, Accuracy：0.975490
# Pass：2, Batch：1200, Cost：0.016043, Accuracy：0.974877
# Pass：2, Batch：1250, Cost：0.012776, Accuracy：0.977022
# Pass：2, Batch：1300, Cost：0.016234, Accuracy：0.975184
# Pass：2, Batch：1350, Cost：0.016560, Accuracy：0.975490
# Pass：2, Batch：1400, Cost：0.016053, Accuracy：0.975490
# Pass：2, Batch：1450, Cost：0.011836, Accuracy：0.977941
# test - Pass: 2 Cost: 0.013183244383593168 Acc: 0.9958229166666667
# new BestPrecent: 0.9955104166666666 thie Precent: 0.9958229166666667
# Save...model...Best_precent: 0.9958229166666667
#
# Pass：3, Batch：50, Cost：0.011925, Accuracy：0.996630
# Pass：3, Batch：100, Cost：0.011844, Accuracy：0.976409
# Pass：3, Batch：150, Cost：0.012530, Accuracy：0.976716
# Pass：3, Batch：200, Cost：0.021031, Accuracy：0.974877
# Pass：3, Batch：250, Cost：0.011882, Accuracy：0.976409
# Pass：3, Batch：300, Cost：0.011967, Accuracy：0.976409
# Pass：3, Batch：350, Cost：0.013488, Accuracy：0.976103
# Pass：3, Batch：400, Cost：0.013510, Accuracy：0.977635
# Pass：3, Batch：450, Cost：0.017049, Accuracy：0.976103
# Pass：3, Batch：500, Cost：0.018079, Accuracy：0.973039
# Pass：3, Batch：550, Cost：0.010415, Accuracy：0.976716
# Pass：3, Batch：600, Cost：0.012916, Accuracy：0.977328
# Pass：3, Batch：650, Cost：0.015629, Accuracy：0.974877
# Pass：3, Batch：700, Cost：0.016637, Accuracy：0.974877
# Pass：3, Batch：750, Cost：0.015616, Accuracy：0.976103
# Pass：3, Batch：800, Cost：0.019470, Accuracy：0.975490
# Pass：3, Batch：850, Cost：0.015584, Accuracy：0.975490
# Pass：3, Batch：900, Cost：0.014615, Accuracy：0.975797
# Pass：3, Batch：950, Cost：0.009475, Accuracy：0.977328
# Pass：3, Batch：1000, Cost：0.010633, Accuracy：0.976103
# Pass：3, Batch：1050, Cost：0.015502, Accuracy：0.975490
# Pass：3, Batch：1100, Cost：0.012507, Accuracy：0.977328
# Pass：3, Batch：1150, Cost：0.011253, Accuracy：0.976716
# Pass：3, Batch：1200, Cost：0.019346, Accuracy：0.974571
# Pass：3, Batch：1250, Cost：0.018879, Accuracy：0.974571
# Pass：3, Batch：1300, Cost：0.013240, Accuracy：0.977328
# Pass：3, Batch：1350, Cost：0.011067, Accuracy：0.975797
# Pass：3, Batch：1400, Cost：0.017004, Accuracy：0.974571
# Pass：3, Batch：1450, Cost：0.016653, Accuracy：0.976103
# test - Pass: 3 Cost: 0.01230607402726552 Acc: 0.99621875
# new BestPrecent: 0.9958229166666667 thie Precent: 0.99621875
# Save...model...Best_precent: 0.99621875
#
# Pass：4, Batch：50, Cost：0.013894, Accuracy：0.995711
# Pass：4, Batch：100, Cost：0.011468, Accuracy：0.975797
# Pass：4, Batch：150, Cost：0.012742, Accuracy：0.975797
# Pass：4, Batch：200, Cost：0.018032, Accuracy：0.974877
# Pass：4, Batch：250, Cost：0.012504, Accuracy：0.976103
# Pass：4, Batch：300, Cost：0.015932, Accuracy：0.974571
# Pass：4, Batch：350, Cost：0.015292, Accuracy：0.977022
# Pass：4, Batch：400, Cost：0.014436, Accuracy：0.975184
# Pass：4, Batch：450, Cost：0.013497, Accuracy：0.976716
# Pass：4, Batch：500, Cost：0.008851, Accuracy：0.977328
# Pass：4, Batch：550, Cost：0.015420, Accuracy：0.975797
# Pass：4, Batch：600, Cost：0.014402, Accuracy：0.975184
# Pass：4, Batch：650, Cost：0.010175, Accuracy：0.977328
# Pass：4, Batch：700, Cost：0.015317, Accuracy：0.976103
# Pass：4, Batch：750, Cost：0.012440, Accuracy：0.977328
# Pass：4, Batch：800, Cost：0.011430, Accuracy：0.976409
# Pass：4, Batch：850, Cost：0.011419, Accuracy：0.977022
# Pass：4, Batch：900, Cost：0.012926, Accuracy：0.975797
# Pass：4, Batch：950, Cost：0.017482, Accuracy：0.974571
# Pass：4, Batch：1000, Cost：0.011360, Accuracy：0.976409
# Pass：4, Batch：1050, Cost：0.011409, Accuracy：0.975490
# Pass：4, Batch：1100, Cost：0.018154, Accuracy：0.974877
# Pass：4, Batch：1150, Cost：0.013050, Accuracy：0.976103
# Pass：4, Batch：1200, Cost：0.012310, Accuracy：0.976716
# Pass：4, Batch：1250, Cost：0.017824, Accuracy：0.975184
# Pass：4, Batch：1300, Cost：0.011768, Accuracy：0.975490
# Pass：4, Batch：1350, Cost：0.012264, Accuracy：0.975490
# Pass：4, Batch：1400, Cost：0.020777, Accuracy：0.974877
# Pass：4, Batch：1450, Cost：0.018957, Accuracy：0.974571
# test - Pass: 4 Cost: 0.01250840682960552 Acc: 0.9961979166666667
# new BestPrecent: 0.99621875 thie Precent: 0.9961979166666667
#
# Pass：5, Batch：50, Cost：0.016439, Accuracy：0.994792
# Pass：5, Batch：100, Cost：0.012771, Accuracy：0.975184
# Pass：5, Batch：150, Cost：0.016857, Accuracy：0.975797
# Pass：5, Batch：200, Cost：0.007274, Accuracy：0.978248
# Pass：5, Batch：250, Cost：0.010034, Accuracy：0.977941
# Pass：5, Batch：300, Cost：0.010033, Accuracy：0.977022
# Pass：5, Batch：350, Cost：0.013308, Accuracy：0.976103
# Pass：5, Batch：400, Cost：0.011790, Accuracy：0.976716
# Pass：5, Batch：450, Cost：0.011943, Accuracy：0.978248
# Pass：5, Batch：500, Cost：0.014625, Accuracy：0.976103
# Pass：5, Batch：550, Cost：0.011788, Accuracy：0.975797
# Pass：5, Batch：600, Cost：0.015043, Accuracy：0.976409
# Pass：5, Batch：650, Cost：0.007942, Accuracy：0.977328
# Pass：5, Batch：700, Cost：0.017754, Accuracy：0.976409
# Pass：5, Batch：750, Cost：0.018113, Accuracy：0.974571
# Pass：5, Batch：800, Cost：0.024707, Accuracy：0.972733
# Pass：5, Batch：850, Cost：0.011552, Accuracy：0.977022
# Pass：5, Batch：900, Cost：0.012598, Accuracy：0.977635
# Pass：5, Batch：950, Cost：0.010455, Accuracy：0.977328
# Pass：5, Batch：1000, Cost：0.008225, Accuracy：0.977635
# Pass：5, Batch：1050, Cost：0.013067, Accuracy：0.975797
# Pass：5, Batch：1100, Cost：0.015866, Accuracy：0.975797
# Pass：5, Batch：1150, Cost：0.012081, Accuracy：0.976716
# Pass：5, Batch：1200, Cost：0.010803, Accuracy：0.977941
# Pass：5, Batch：1250, Cost：0.010969, Accuracy：0.977022
# Pass：5, Batch：1300, Cost：0.012583, Accuracy：0.977022
# Pass：5, Batch：1350, Cost：0.012740, Accuracy：0.976716
# Pass：5, Batch：1400, Cost：0.014486, Accuracy：0.975490
# Pass：5, Batch：1450, Cost：0.013091, Accuracy：0.976409
# test - Pass: 5 Cost: 0.011521170369880564 Acc: 0.996375
# new BestPrecent: 0.99621875 thie Precent: 0.996375
# Save...model...Best_precent: 0.996375
#
# Pass：6, Batch：50, Cost：0.012363, Accuracy：0.995711
# Pass：6, Batch：100, Cost：0.015696, Accuracy：0.977022
# Pass：6, Batch：150, Cost：0.013268, Accuracy：0.976409
# Pass：6, Batch：200, Cost：0.012782, Accuracy：0.977328
# Pass：6, Batch：250, Cost：0.010529, Accuracy：0.976716
# Pass：6, Batch：300, Cost：0.009777, Accuracy：0.977635
# Pass：6, Batch：350, Cost：0.008232, Accuracy：0.977328
# Pass：6, Batch：400, Cost：0.010461, Accuracy：0.977022
# Pass：6, Batch：450, Cost：0.012252, Accuracy：0.976409
# Pass：6, Batch：500, Cost：0.010437, Accuracy：0.975184
# Pass：6, Batch：550, Cost：0.013265, Accuracy：0.974877
# Pass：6, Batch：600, Cost：0.009027, Accuracy：0.975490
# Pass：6, Batch：650, Cost：0.011496, Accuracy：0.976409
# Pass：6, Batch：700, Cost：0.014379, Accuracy：0.976103
# Pass：6, Batch：750, Cost：0.011645, Accuracy：0.976409
# Pass：6, Batch：800, Cost：0.013043, Accuracy：0.976409
# Pass：6, Batch：850, Cost：0.014578, Accuracy：0.975797
# Pass：6, Batch：900, Cost：0.011283, Accuracy：0.976103
# Pass：6, Batch：950, Cost：0.011933, Accuracy：0.977022
# Pass：6, Batch：1000, Cost：0.008933, Accuracy：0.977022
# Pass：6, Batch：1050, Cost：0.013224, Accuracy：0.976409
# Pass：6, Batch：1100, Cost：0.016518, Accuracy：0.975490
# Pass：6, Batch：1150, Cost：0.012984, Accuracy：0.975797
# Pass：6, Batch：1200, Cost：0.018631, Accuracy：0.973958
# Pass：6, Batch：1250, Cost：0.011523, Accuracy：0.976409
# Pass：6, Batch：1300, Cost：0.009273, Accuracy：0.976409
# Pass：6, Batch：1350, Cost：0.010602, Accuracy：0.976103
# Pass：6, Batch：1400, Cost：0.020239, Accuracy：0.974265
# Pass：6, Batch：1450, Cost：0.015513, Accuracy：0.975797
# test - Pass: 6 Cost: 0.01184324292674258 Acc: 0.996125
# new BestPrecent: 0.996375 thie Precent: 0.996125
#
# Pass：7, Batch：50, Cost：0.016252, Accuracy：0.995711
# Pass：7, Batch：100, Cost：0.014888, Accuracy：0.976103
# Pass：7, Batch：150, Cost：0.011647, Accuracy：0.975797
# Pass：7, Batch：200, Cost：0.013239, Accuracy：0.977328
# Pass：7, Batch：250, Cost：0.014074, Accuracy：0.976409
# Pass：7, Batch：300, Cost：0.012421, Accuracy：0.975490
# Pass：7, Batch：350, Cost：0.016122, Accuracy：0.976103
# Pass：7, Batch：400, Cost：0.014315, Accuracy：0.976103
# Pass：7, Batch：450, Cost：0.015794, Accuracy：0.974571
# Pass：7, Batch：500, Cost：0.015693, Accuracy：0.975184
# Pass：7, Batch：550, Cost：0.012737, Accuracy：0.976103
# Pass：7, Batch：600, Cost：0.012599, Accuracy：0.976716
# Pass：7, Batch：650, Cost：0.010618, Accuracy：0.976409
# Pass：7, Batch：700, Cost：0.009300, Accuracy：0.977022
# Pass：7, Batch：750, Cost：0.012256, Accuracy：0.976409
# Pass：7, Batch：800, Cost：0.011012, Accuracy：0.977328
# Pass：7, Batch：850, Cost：0.012331, Accuracy：0.976716
# Pass：7, Batch：900, Cost：0.012910, Accuracy：0.976103
# Pass：7, Batch：950, Cost：0.016498, Accuracy：0.976716
# Pass：7, Batch：1000, Cost：0.008962, Accuracy：0.977328
# Pass：7, Batch：1050, Cost：0.012080, Accuracy：0.975797
# Pass：7, Batch：1100, Cost：0.012139, Accuracy：0.976103
# Pass：7, Batch：1150, Cost：0.015058, Accuracy：0.975797
# Pass：7, Batch：1200, Cost：0.008350, Accuracy：0.978248
# Pass：7, Batch：1250, Cost：0.007714, Accuracy：0.977941
# Pass：7, Batch：1300, Cost：0.012520, Accuracy：0.977328
# Pass：7, Batch：1350, Cost：0.010416, Accuracy：0.976716
# Pass：7, Batch：1400, Cost：0.015970, Accuracy：0.975490
# Pass：7, Batch：1450, Cost：0.018480, Accuracy：0.973652
# test - Pass: 7 Cost: 0.010818492124097247 Acc: 0.9965208333333333
# new BestPrecent: 0.996375 thie Precent: 0.9965208333333333
# Save...model...Best_precent: 0.9965208333333333
#
# Pass：8, Batch：50, Cost：0.015728, Accuracy：0.995711
# Pass：8, Batch：100, Cost：0.009819, Accuracy：0.976716
# Pass：8, Batch：150, Cost：0.012220, Accuracy：0.977022
# Pass：8, Batch：200, Cost：0.018644, Accuracy：0.976103
# Pass：8, Batch：250, Cost：0.012722, Accuracy：0.976409
# Pass：8, Batch：300, Cost：0.014222, Accuracy：0.975490
# Pass：8, Batch：350, Cost：0.009931, Accuracy：0.976103
# Pass：8, Batch：400, Cost：0.011771, Accuracy：0.976716
# Pass：8, Batch：450, Cost：0.007569, Accuracy：0.976409
# Pass：8, Batch：500, Cost：0.008526, Accuracy：0.977635
# Pass：8, Batch：550, Cost：0.007364, Accuracy：0.978248
# Pass：8, Batch：600, Cost：0.007135, Accuracy：0.979167
# Pass：8, Batch：650, Cost：0.012258, Accuracy：0.977022
# Pass：8, Batch：700, Cost：0.006693, Accuracy：0.977328
# Pass：8, Batch：750, Cost：0.014176, Accuracy：0.975490
# Pass：8, Batch：800, Cost：0.009785, Accuracy：0.977328
# Pass：8, Batch：850, Cost：0.010653, Accuracy：0.977022
# Pass：8, Batch：900, Cost：0.013180, Accuracy：0.976103
# Pass：8, Batch：950, Cost：0.016171, Accuracy：0.976103
# Pass：8, Batch：1000, Cost：0.010889, Accuracy：0.975490
# Pass：8, Batch：1050, Cost：0.014645, Accuracy：0.975184
# Pass：8, Batch：1100, Cost：0.010668, Accuracy：0.976409
# Pass：8, Batch：1150, Cost：0.013903, Accuracy：0.976716
# Pass：8, Batch：1200, Cost：0.011331, Accuracy：0.977022
# Pass：8, Batch：1250, Cost：0.006040, Accuracy：0.977941
# Pass：8, Batch：1300, Cost：0.011075, Accuracy：0.976409
# Pass：8, Batch：1350, Cost：0.009359, Accuracy：0.977635
# Pass：8, Batch：1400, Cost：0.008507, Accuracy：0.977328
# Pass：8, Batch：1450, Cost：0.014624, Accuracy：0.975490
# test - Pass: 8 Cost: 0.011880949746380792 Acc: 0.99603125
# new BestPrecent: 0.9965208333333333 thie Precent: 0.99603125
#
# Pass：9, Batch：50, Cost：0.009932, Accuracy：0.995711
# Pass：9, Batch：100, Cost：0.021875, Accuracy：0.973652
# Pass：9, Batch：150, Cost：0.011216, Accuracy：0.977022
# Pass：9, Batch：200, Cost：0.009900, Accuracy：0.977022
# Pass：9, Batch：250, Cost：0.010215, Accuracy：0.976716
# Pass：9, Batch：300, Cost：0.011765, Accuracy：0.976716
# Pass：9, Batch：350, Cost：0.012092, Accuracy：0.976716
# Pass：9, Batch：400, Cost：0.009149, Accuracy：0.977022
# Pass：9, Batch：450, Cost：0.012273, Accuracy：0.976409
# Pass：9, Batch：500, Cost：0.009435, Accuracy：0.977635
# Pass：9, Batch：550, Cost：0.010354, Accuracy：0.977635
# Pass：9, Batch：600, Cost：0.009508, Accuracy：0.977328
# Pass：9, Batch：650, Cost：0.010125, Accuracy：0.976409
# Pass：9, Batch：700, Cost：0.013038, Accuracy：0.974877
# Pass：9, Batch：750, Cost：0.012665, Accuracy：0.977022
# Pass：9, Batch：800, Cost：0.012892, Accuracy：0.976716
# Pass：9, Batch：850, Cost：0.007118, Accuracy：0.978248
# Pass：9, Batch：900, Cost：0.010596, Accuracy：0.977022
# Pass：9, Batch：950, Cost：0.009100, Accuracy：0.978248
# Pass：9, Batch：1000, Cost：0.009802, Accuracy：0.977328
# Pass：9, Batch：1050, Cost：0.012791, Accuracy：0.976716
# Pass：9, Batch：1100, Cost：0.009870, Accuracy：0.976716
# Pass：9, Batch：1150, Cost：0.011172, Accuracy：0.977941
# Pass：9, Batch：1200, Cost：0.009677, Accuracy：0.977328
# Pass：9, Batch：1250, Cost：0.008134, Accuracy：0.977328
# Pass：9, Batch：1300, Cost：0.014687, Accuracy：0.975797
# Pass：9, Batch：1350, Cost：0.015395, Accuracy：0.976103
# Pass：9, Batch：1400, Cost：0.012226, Accuracy：0.975797
# Pass：9, Batch：1450, Cost：0.009455, Accuracy：0.977022
# test - Pass: 9 Cost: 0.010115053088490337 Acc: 0.99675
# new BestPrecent: 0.9965208333333333 thie Precent: 0.99675
# Save...model...Best_precent: 0.99675
#
# Pass：10, Batch：50, Cost：0.014040, Accuracy：0.995404
# Pass：10, Batch：100, Cost：0.007117, Accuracy：0.977941
# Pass：10, Batch：150, Cost：0.009851, Accuracy：0.977328
# Pass：10, Batch：200, Cost：0.012185, Accuracy：0.976716
# Pass：10, Batch：250, Cost：0.017039, Accuracy：0.975490
# Pass：10, Batch：300, Cost：0.011954, Accuracy：0.975797
# Pass：10, Batch：350, Cost：0.011291, Accuracy：0.976409
# Pass：10, Batch：400, Cost：0.010452, Accuracy：0.976409
# Pass：10, Batch：450, Cost：0.012328, Accuracy：0.977328
# Pass：10, Batch：500, Cost：0.011454, Accuracy：0.977022
# Pass：10, Batch：550, Cost：0.011541, Accuracy：0.976716
# Pass：10, Batch：600, Cost：0.009552, Accuracy：0.977328
# Pass：10, Batch：650, Cost：0.008113, Accuracy：0.978248
# Pass：10, Batch：700, Cost：0.010040, Accuracy：0.977328
# Pass：10, Batch：750, Cost：0.010551, Accuracy：0.977022
# Pass：10, Batch：800, Cost：0.011297, Accuracy：0.977022
# Pass：10, Batch：850, Cost：0.011269, Accuracy：0.974571
# Pass：10, Batch：900, Cost：0.014129, Accuracy：0.975184
# Pass：10, Batch：950, Cost：0.010383, Accuracy：0.977022
# Pass：10, Batch：1000, Cost：0.007519, Accuracy：0.977635
# Pass：10, Batch：1050, Cost：0.010890, Accuracy：0.977635
# Pass：10, Batch：1100, Cost：0.012764, Accuracy：0.976103
# Pass：10, Batch：1150, Cost：0.016260, Accuracy：0.974571
# Pass：10, Batch：1200, Cost：0.011281, Accuracy：0.976409
# Pass：10, Batch：1250, Cost：0.009446, Accuracy：0.977328
# Pass：10, Batch：1300, Cost：0.013900, Accuracy：0.975490
# Pass：10, Batch：1350, Cost：0.014137, Accuracy：0.977328
# Pass：10, Batch：1400, Cost：0.009057, Accuracy：0.978860
# Pass：10, Batch：1450, Cost：0.013282, Accuracy：0.976409
# test - Pass: 10 Cost: 0.01008153343294301 Acc: 0.9967708333333334
# new BestPrecent: 0.99675 thie Precent: 0.9967708333333334
# Save...model...Best_precent: 0.9967708333333334
#
# Pass：11, Batch：50, Cost：0.014836, Accuracy：0.995404
# Pass：11, Batch：100, Cost：0.012471, Accuracy：0.977022
# Pass：11, Batch：150, Cost：0.006926, Accuracy：0.978554
# Pass：11, Batch：200, Cost：0.009380, Accuracy：0.977022
# Pass：11, Batch：250, Cost：0.014079, Accuracy：0.976409
# Pass：11, Batch：300, Cost：0.014964, Accuracy：0.974571
# Pass：11, Batch：350, Cost：0.010793, Accuracy：0.976409
# Pass：11, Batch：400, Cost：0.010755, Accuracy：0.975184
# Pass：11, Batch：450, Cost：0.013567, Accuracy：0.976409
# Pass：11, Batch：500, Cost：0.010913, Accuracy：0.977328
# Pass：11, Batch：550, Cost：0.010606, Accuracy：0.976409
# Pass：11, Batch：600, Cost：0.008210, Accuracy：0.976716
# Pass：11, Batch：650, Cost：0.014016, Accuracy：0.974571
# Pass：11, Batch：700, Cost：0.021229, Accuracy：0.973958
# Pass：11, Batch：750, Cost：0.009085, Accuracy：0.977941
# Pass：11, Batch：800, Cost：0.015595, Accuracy：0.973958
# Pass：11, Batch：850, Cost：0.014574, Accuracy：0.976103
# Pass：11, Batch：900, Cost：0.007834, Accuracy：0.977941
# Pass：11, Batch：950, Cost：0.007610, Accuracy：0.977328
# Pass：11, Batch：1000, Cost：0.010806, Accuracy：0.976103
# Pass：11, Batch：1050, Cost：0.008207, Accuracy：0.978248
# Pass：11, Batch：1100, Cost：0.007979, Accuracy：0.978248
# Pass：11, Batch：1150, Cost：0.011597, Accuracy：0.976716
# Pass：11, Batch：1200, Cost：0.011202, Accuracy：0.978860
# Pass：11, Batch：1250, Cost：0.006683, Accuracy：0.978248
# Pass：11, Batch：1300, Cost：0.010677, Accuracy：0.975797
# Pass：11, Batch：1350, Cost：0.006916, Accuracy：0.978554
# Pass：11, Batch：1400, Cost：0.009102, Accuracy：0.977635
# Pass：11, Batch：1450, Cost：0.015357, Accuracy：0.974877
# test - Pass: 11 Cost: 0.009796151558858886 Acc: 0.9968541666666667
# new BestPrecent: 0.9967708333333334 thie Precent: 0.9968541666666667
# Save...model...Best_precent: 0.9968541666666667
#
# Pass：12, Batch：50, Cost：0.011068, Accuracy：0.996324
# Pass：12, Batch：100, Cost：0.011438, Accuracy：0.976716
# Pass：12, Batch：150, Cost：0.011147, Accuracy：0.975797
# Pass：12, Batch：200, Cost：0.007224, Accuracy：0.977941
# Pass：12, Batch：250, Cost：0.015550, Accuracy：0.974265
# Pass：12, Batch：300, Cost：0.016464, Accuracy：0.975184
# Pass：12, Batch：350, Cost：0.015129, Accuracy：0.975490
# Pass：12, Batch：400, Cost：0.014615, Accuracy：0.975797
# Pass：12, Batch：450, Cost：0.011662, Accuracy：0.977022
# Pass：12, Batch：500, Cost：0.005941, Accuracy：0.977941
# Pass：12, Batch：550, Cost：0.012622, Accuracy：0.976716
# Pass：12, Batch：600, Cost：0.014013, Accuracy：0.977022
# Pass：12, Batch：650, Cost：0.008077, Accuracy：0.977941
# Pass：12, Batch：700, Cost：0.008747, Accuracy：0.978554
# Pass：12, Batch：750, Cost：0.012596, Accuracy：0.976103
# Pass：12, Batch：800, Cost：0.013732, Accuracy：0.976103
# Pass：12, Batch：850, Cost：0.017136, Accuracy：0.974265
# Pass：12, Batch：900, Cost：0.013910, Accuracy：0.976716
# Pass：12, Batch：950, Cost：0.009328, Accuracy：0.977328
# Pass：12, Batch：1000, Cost：0.015851, Accuracy：0.975797
# Pass：12, Batch：1050, Cost：0.009455, Accuracy：0.976409
# Pass：12, Batch：1100, Cost：0.009277, Accuracy：0.976103
# Pass：12, Batch：1150, Cost：0.009882, Accuracy：0.977022
# Pass：12, Batch：1200, Cost：0.014997, Accuracy：0.975490
# Pass：12, Batch：1250, Cost：0.009286, Accuracy：0.977022
# Pass：12, Batch：1300, Cost：0.015399, Accuracy：0.975490
# Pass：12, Batch：1350, Cost：0.010606, Accuracy：0.977328
# Pass：12, Batch：1400, Cost：0.009292, Accuracy：0.976409
# Pass：12, Batch：1450, Cost：0.014211, Accuracy：0.976103
# test - Pass: 12 Cost: 0.009177549908724056 Acc: 0.9972083333333334
# new BestPrecent: 0.9968541666666667 thie Precent: 0.9972083333333334
# Save...model...Best_precent: 0.9972083333333334
#
# Pass：13, Batch：50, Cost：0.011092, Accuracy：0.996936
# Pass：13, Batch：100, Cost：0.011918, Accuracy：0.976716
# Pass：13, Batch：150, Cost：0.012169, Accuracy：0.976103
# Pass：13, Batch：200, Cost：0.008979, Accuracy：0.977635
# Pass：13, Batch：250, Cost：0.014923, Accuracy：0.975797
# Pass：13, Batch：300, Cost：0.008963, Accuracy：0.976716
# Pass：13, Batch：350, Cost：0.010144, Accuracy：0.976409
# Pass：13, Batch：400, Cost：0.009866, Accuracy：0.977635
# Pass：13, Batch：450, Cost：0.014299, Accuracy：0.976103
# Pass：13, Batch：500, Cost：0.010178, Accuracy：0.976716
# Pass：13, Batch：550, Cost：0.008103, Accuracy：0.977635
# Pass：13, Batch：600, Cost：0.008527, Accuracy：0.977941
# Pass：13, Batch：650, Cost：0.005662, Accuracy：0.978860
# Pass：13, Batch：700, Cost：0.009046, Accuracy：0.976716
# Pass：13, Batch：750, Cost：0.007850, Accuracy：0.977941
# Pass：13, Batch：800, Cost：0.008204, Accuracy：0.977635
# Pass：13, Batch：850, Cost：0.008472, Accuracy：0.977328
# Pass：13, Batch：900, Cost：0.007225, Accuracy：0.977635
# Pass：13, Batch：950, Cost：0.009057, Accuracy：0.977022
# Pass：13, Batch：1000, Cost：0.013919, Accuracy：0.976103
# Pass：13, Batch：1050, Cost：0.017200, Accuracy：0.977022
# Pass：13, Batch：1100, Cost：0.004570, Accuracy：0.979473
# Pass：13, Batch：1150, Cost：0.008766, Accuracy：0.977635
# Pass：13, Batch：1200, Cost：0.013634, Accuracy：0.975184
# Pass：13, Batch：1250, Cost：0.011581, Accuracy：0.975490
# Pass：13, Batch：1300, Cost：0.012098, Accuracy：0.977022
# Pass：13, Batch：1350, Cost：0.012054, Accuracy：0.976716
# Pass：13, Batch：1400, Cost：0.008207, Accuracy：0.977635
# Pass：13, Batch：1450, Cost：0.008986, Accuracy：0.977941
# test - Pass: 13 Cost: 0.00926589501398242 Acc: 0.9970833333333333
# new BestPrecent: 0.9972083333333334 thie Precent: 0.9970833333333333
#
# Pass：14, Batch：50, Cost：0.009308, Accuracy：0.996936
# Pass：14, Batch：100, Cost：0.007162, Accuracy：0.978248
# Pass：14, Batch：150, Cost：0.007809, Accuracy：0.976716
# Pass：14, Batch：200, Cost：0.010883, Accuracy：0.976716
# Pass：14, Batch：250, Cost：0.012157, Accuracy：0.977328
# Pass：14, Batch：300, Cost：0.010469, Accuracy：0.976716
# Pass：14, Batch：350, Cost：0.013803, Accuracy：0.975797
# Pass：14, Batch：400, Cost：0.007719, Accuracy：0.977941
# Pass：14, Batch：450, Cost：0.011753, Accuracy：0.976103
# Pass：14, Batch：500, Cost：0.009862, Accuracy：0.977022
# Pass：14, Batch：550, Cost：0.011748, Accuracy：0.975490
# Pass：14, Batch：600, Cost：0.011327, Accuracy：0.977635
# Pass：14, Batch：650, Cost：0.015634, Accuracy：0.976409
# Pass：14, Batch：700, Cost：0.012877, Accuracy：0.975797
# Pass：14, Batch：750, Cost：0.014332, Accuracy：0.976716
# Pass：14, Batch：800, Cost：0.008232, Accuracy：0.977022
# Pass：14, Batch：850, Cost：0.006610, Accuracy：0.977941
# Pass：14, Batch：900, Cost：0.007269, Accuracy：0.977022
# Pass：14, Batch：950, Cost：0.009975, Accuracy：0.976103
# Pass：14, Batch：1000, Cost：0.006493, Accuracy：0.977941
# Pass：14, Batch：1050, Cost：0.004079, Accuracy：0.979473
# Pass：14, Batch：1100, Cost：0.008792, Accuracy：0.977941
# Pass：14, Batch：1150, Cost：0.008260, Accuracy：0.977022
# Pass：14, Batch：1200, Cost：0.013352, Accuracy：0.975490
# Pass：14, Batch：1250, Cost：0.015952, Accuracy：0.976103
# Pass：14, Batch：1300, Cost：0.013375, Accuracy：0.977022
# Pass：14, Batch：1350, Cost：0.010967, Accuracy：0.974877
# Pass：14, Batch：1400, Cost：0.006865, Accuracy：0.978248
# Pass：14, Batch：1450, Cost：0.013779, Accuracy：0.976409
# test - Pass: 14 Cost: 0.009127890834385956 Acc: 0.9968854166666666
# new BestPrecent: 0.9972083333333334 thie Precent: 0.9968854166666666
#
# Pass：15, Batch：50, Cost：0.009172, Accuracy：0.998468
# Pass：15, Batch：100, Cost：0.007994, Accuracy：0.977022
# Pass：15, Batch：150, Cost：0.013944, Accuracy：0.975184
# Pass：15, Batch：200, Cost：0.008793, Accuracy：0.977328
# Pass：15, Batch：250, Cost：0.012605, Accuracy：0.975490
# Pass：15, Batch：300, Cost：0.010222, Accuracy：0.977635
# Pass：15, Batch：350, Cost：0.008799, Accuracy：0.977022
# Pass：15, Batch：400, Cost：0.014680, Accuracy：0.975797
# Pass：15, Batch：450, Cost：0.009371, Accuracy：0.977941
# Pass：15, Batch：500, Cost：0.008160, Accuracy：0.977328
# Pass：15, Batch：550, Cost：0.005501, Accuracy：0.978860
# Pass：15, Batch：600, Cost：0.010133, Accuracy：0.977022
# Pass：15, Batch：650, Cost：0.009964, Accuracy：0.976103
# Pass：15, Batch：700, Cost：0.013883, Accuracy：0.977328
# Pass：15, Batch：750, Cost：0.006978, Accuracy：0.978248
# Pass：15, Batch：800, Cost：0.008783, Accuracy：0.977635
# Pass：15, Batch：850, Cost：0.007394, Accuracy：0.977941
# Pass：15, Batch：900, Cost：0.010156, Accuracy：0.978248
# Pass：15, Batch：950, Cost：0.008863, Accuracy：0.977022
# Pass：15, Batch：1000, Cost：0.011676, Accuracy：0.975797
# Pass：15, Batch：1050, Cost：0.007795, Accuracy：0.977941
# Pass：15, Batch：1100, Cost：0.010501, Accuracy：0.977022
# Pass：15, Batch：1150, Cost：0.009851, Accuracy：0.976409
# Pass：15, Batch：1200, Cost：0.006058, Accuracy：0.977941
# Pass：15, Batch：1250, Cost：0.007529, Accuracy：0.977328
# Pass：15, Batch：1300, Cost：0.012754, Accuracy：0.975797
# Pass：15, Batch：1350, Cost：0.013313, Accuracy：0.976716
# Pass：15, Batch：1400, Cost：0.015092, Accuracy：0.975797
# Pass：15, Batch：1450, Cost：0.007922, Accuracy：0.977941
# test - Pass: 15 Cost: 0.009492955838495012 Acc: 0.99696875
# new BestPrecent: 0.9972083333333334 thie Precent: 0.99696875
#
# Pass：16, Batch：50, Cost：0.012488, Accuracy：0.996017
# Pass：16, Batch：100, Cost：0.007957, Accuracy：0.977635
# Pass：16, Batch：150, Cost：0.012131, Accuracy：0.976716
# Pass：16, Batch：200, Cost：0.010010, Accuracy：0.977635
# Pass：16, Batch：250, Cost：0.008628, Accuracy：0.977635
# Pass：16, Batch：300, Cost：0.006570, Accuracy：0.977941
# Pass：16, Batch：350, Cost：0.011843, Accuracy：0.975797
# Pass：16, Batch：400, Cost：0.012009, Accuracy：0.977635
# Pass：16, Batch：450, Cost：0.013918, Accuracy：0.976716
# Pass：16, Batch：500, Cost：0.006891, Accuracy：0.977941
# Pass：16, Batch：550, Cost：0.007436, Accuracy：0.977328
# Pass：16, Batch：600, Cost：0.011297, Accuracy：0.976409
# Pass：16, Batch：650, Cost：0.011116, Accuracy：0.977022
# Pass：16, Batch：700, Cost：0.009678, Accuracy：0.977635
# Pass：16, Batch：750, Cost：0.007520, Accuracy：0.977328
# Pass：16, Batch：800, Cost：0.011728, Accuracy：0.976103
# Pass：16, Batch：850, Cost：0.006044, Accuracy：0.978860
# Pass：16, Batch：900, Cost：0.009348, Accuracy：0.977635
# Pass：16, Batch：950, Cost：0.008988, Accuracy：0.977328
# Pass：16, Batch：1000, Cost：0.007984, Accuracy：0.978248
# Pass：16, Batch：1050, Cost：0.007445, Accuracy：0.978248
# Pass：16, Batch：1100, Cost：0.010386, Accuracy：0.978554
# Pass：16, Batch：1150, Cost：0.008657, Accuracy：0.977635
# Pass：16, Batch：1200, Cost：0.010077, Accuracy：0.977022
# Pass：16, Batch：1250, Cost：0.006578, Accuracy：0.977941
# Pass：16, Batch：1300, Cost：0.008871, Accuracy：0.977022
# Pass：16, Batch：1350, Cost：0.011779, Accuracy：0.977328
# Pass：16, Batch：1400, Cost：0.012155, Accuracy：0.976103
# Pass：16, Batch：1450, Cost：0.008130, Accuracy：0.977941
# test - Pass: 16 Cost: 0.008472322322725328 Acc: 0.9972604166666666
# new BestPrecent: 0.9972083333333334 thie Precent: 0.9972604166666666
# Save...model...Best_precent: 0.9972604166666666
#
# Pass：17, Batch：50, Cost：0.012610, Accuracy：0.996017
# Pass：17, Batch：100, Cost：0.011437, Accuracy：0.977022
# Pass：17, Batch：150, Cost：0.011368, Accuracy：0.977635
# Pass：17, Batch：200, Cost：0.016605, Accuracy：0.975797
# Pass：17, Batch：250, Cost：0.011211, Accuracy：0.977022
# Pass：17, Batch：300, Cost：0.007048, Accuracy：0.977941
# Pass：17, Batch：350, Cost：0.008593, Accuracy：0.978248
# Pass：17, Batch：400, Cost：0.012513, Accuracy：0.977022
# Pass：17, Batch：450, Cost：0.013323, Accuracy：0.976409
# Pass：17, Batch：500, Cost：0.008521, Accuracy：0.976716
# Pass：17, Batch：550, Cost：0.007936, Accuracy：0.977328
# Pass：17, Batch：600, Cost：0.012586, Accuracy：0.976103
# Pass：17, Batch：650, Cost：0.006978, Accuracy：0.978860
# Pass：17, Batch：700, Cost：0.013186, Accuracy：0.975797
# Pass：17, Batch：750, Cost：0.005631, Accuracy：0.978248
# Pass：17, Batch：800, Cost：0.011220, Accuracy：0.976409
# Pass：17, Batch：850, Cost：0.010403, Accuracy：0.975490
# Pass：17, Batch：900, Cost：0.014776, Accuracy：0.974877
# Pass：17, Batch：950, Cost：0.011278, Accuracy：0.977022
# Pass：17, Batch：1000, Cost：0.008184, Accuracy：0.977022
# Pass：17, Batch：1050, Cost：0.006931, Accuracy：0.977635
# Pass：17, Batch：1100, Cost：0.008104, Accuracy：0.977328
# Pass：17, Batch：1150, Cost：0.010024, Accuracy：0.977941
# Pass：17, Batch：1200, Cost：0.010909, Accuracy：0.977635
# Pass：17, Batch：1250, Cost：0.007814, Accuracy：0.977022
# Pass：17, Batch：1300, Cost：0.010282, Accuracy：0.976103
# Pass：17, Batch：1350, Cost：0.008799, Accuracy：0.977941
# Pass：17, Batch：1400, Cost：0.005990, Accuracy：0.979167
# Pass：17, Batch：1450, Cost：0.005213, Accuracy：0.978860
# test - Pass: 17 Cost: 0.00906214384154373 Acc: 0.9972083333333334
# new BestPrecent: 0.9972604166666666 thie Precent: 0.9972083333333334
#
# Pass：18, Batch：50, Cost：0.010753, Accuracy：0.996936
# Pass：18, Batch：100, Cost：0.017067, Accuracy：0.975797
# Pass：18, Batch：150, Cost：0.013778, Accuracy：0.976409
# Pass：18, Batch：200, Cost：0.008639, Accuracy：0.977635
# Pass：18, Batch：250, Cost：0.013912, Accuracy：0.976716
# Pass：18, Batch：300, Cost：0.012733, Accuracy：0.976103
# Pass：18, Batch：350, Cost：0.013763, Accuracy：0.976103
# Pass：18, Batch：400, Cost：0.006713, Accuracy：0.978554
# Pass：18, Batch：450, Cost：0.010345, Accuracy：0.977635
# Pass：18, Batch：500, Cost：0.009638, Accuracy：0.977635
# Pass：18, Batch：550, Cost：0.007127, Accuracy：0.977022
# Pass：18, Batch：600, Cost：0.008566, Accuracy：0.978248
# Pass：18, Batch：650, Cost：0.011376, Accuracy：0.976716
# Pass：18, Batch：700, Cost：0.010258, Accuracy：0.976409
# Pass：18, Batch：750, Cost：0.007946, Accuracy：0.977635
# Pass：18, Batch：800, Cost：0.016249, Accuracy：0.975797
# Pass：18, Batch：850, Cost：0.011597, Accuracy：0.977941
# Pass：18, Batch：900, Cost：0.006383, Accuracy：0.978860
# Pass：18, Batch：950, Cost：0.006056, Accuracy：0.978554
# Pass：18, Batch：1000, Cost：0.008010, Accuracy：0.977328
# Pass：18, Batch：1050, Cost：0.013454, Accuracy：0.975490
# Pass：18, Batch：1100, Cost：0.011468, Accuracy：0.977328
# Pass：18, Batch：1150, Cost：0.006350, Accuracy：0.978248
# Pass：18, Batch：1200, Cost：0.019587, Accuracy：0.975184
# Pass：18, Batch：1250, Cost：0.008061, Accuracy：0.977022
# Pass：18, Batch：1300, Cost：0.007220, Accuracy：0.978248
# Pass：18, Batch：1350, Cost：0.008410, Accuracy：0.977022
# Pass：18, Batch：1400, Cost：0.008074, Accuracy：0.977635
# Pass：18, Batch：1450, Cost：0.018698, Accuracy：0.974877
# test - Pass: 18 Cost: 0.009163783843367128 Acc: 0.9973645833333333
# new BestPrecent: 0.9972604166666666 thie Precent: 0.9973645833333333
# Save...model...Best_precent: 0.9973645833333333
#
# Pass：19, Batch：50, Cost：0.012536, Accuracy：0.997549
# Pass：19, Batch：100, Cost：0.009404, Accuracy：0.976103
# Pass：19, Batch：150, Cost：0.010021, Accuracy：0.976716
# Pass：19, Batch：200, Cost：0.009659, Accuracy：0.977022
# Pass：19, Batch：250, Cost：0.007682, Accuracy：0.977635
# Pass：19, Batch：300, Cost：0.009874, Accuracy：0.977941
# Pass：19, Batch：350, Cost：0.006676, Accuracy：0.977941
# Pass：19, Batch：400, Cost：0.009103, Accuracy：0.976103
# Pass：19, Batch：450, Cost：0.014494, Accuracy：0.974877
# Pass：19, Batch：500, Cost：0.008468, Accuracy：0.977635
# Pass：19, Batch：550, Cost：0.011072, Accuracy：0.977941
# Pass：19, Batch：600, Cost：0.008160, Accuracy：0.977328
# Pass：19, Batch：650, Cost：0.010934, Accuracy：0.977328
# Pass：19, Batch：700, Cost：0.015270, Accuracy：0.977022
# Pass：19, Batch：750, Cost：0.013092, Accuracy：0.975797
# Pass：19, Batch：800, Cost：0.005716, Accuracy：0.978248
# Pass：19, Batch：850, Cost：0.009864, Accuracy：0.976716
# Pass：19, Batch：900, Cost：0.013554, Accuracy：0.977022
# Pass：19, Batch：950, Cost：0.007414, Accuracy：0.978248
# Pass：19, Batch：1000, Cost：0.012378, Accuracy：0.976409
# Pass：19, Batch：1050, Cost：0.011799, Accuracy：0.976409
# Pass：19, Batch：1100, Cost：0.005926, Accuracy：0.978860
# Pass：19, Batch：1150, Cost：0.008144, Accuracy：0.978248
# Pass：19, Batch：1200, Cost：0.009808, Accuracy：0.977328
# Pass：19, Batch：1250, Cost：0.007133, Accuracy：0.978248
# Pass：19, Batch：1300, Cost：0.012105, Accuracy：0.977635
# Pass：19, Batch：1350, Cost：0.012161, Accuracy：0.976409
# Pass：19, Batch：1400, Cost：0.005751, Accuracy：0.978860
# Pass：19, Batch：1450, Cost：0.007516, Accuracy：0.977328
# test - Pass: 19 Cost: 0.009907077069331232 Acc: 0.9969166666666667
# new BestPrecent: 0.9973645833333333 thie Precent: 0.9969166666666667
#
# Pass：20, Batch：50, Cost：0.006886, Accuracy：0.997243
# Pass：20, Batch：100, Cost：0.009848, Accuracy：0.975797
# Pass：20, Batch：150, Cost：0.005250, Accuracy：0.979167
# Pass：20, Batch：200, Cost：0.011001, Accuracy：0.976716
# Pass：20, Batch：250, Cost：0.015566, Accuracy：0.975490
# Pass：20, Batch：300, Cost：0.009735, Accuracy：0.977328
# Pass：20, Batch：350, Cost：0.010733, Accuracy：0.977635
# Pass：20, Batch：400, Cost：0.008786, Accuracy：0.977941
# Pass：20, Batch：450, Cost：0.007676, Accuracy：0.977635
# Pass：20, Batch：500, Cost：0.005656, Accuracy：0.978248
# Pass：20, Batch：550, Cost：0.018749, Accuracy：0.975490
# Pass：20, Batch：600, Cost：0.012101, Accuracy：0.977328
# Pass：20, Batch：650, Cost：0.012751, Accuracy：0.977328
# Pass：20, Batch：700, Cost：0.012906, Accuracy：0.976103
# Pass：20, Batch：750, Cost：0.009279, Accuracy：0.978248
# Pass：20, Batch：800, Cost：0.009982, Accuracy：0.977328
# Pass：20, Batch：850, Cost：0.005876, Accuracy：0.979473
# Pass：20, Batch：900, Cost：0.013348, Accuracy：0.975797
# Pass：20, Batch：950, Cost：0.012925, Accuracy：0.976409
# Pass：20, Batch：1000, Cost：0.007373, Accuracy：0.977635
# Pass：20, Batch：1050, Cost：0.014954, Accuracy：0.975490
# Pass：20, Batch：1100, Cost：0.007714, Accuracy：0.977635
# Pass：20, Batch：1150, Cost：0.008869, Accuracy：0.976716
# Pass：20, Batch：1200, Cost：0.007035, Accuracy：0.978860
# Pass：20, Batch：1250, Cost：0.008330, Accuracy：0.977941
# Pass：20, Batch：1300, Cost：0.008772, Accuracy：0.977635
# Pass：20, Batch：1350, Cost：0.012577, Accuracy：0.976716
# Pass：20, Batch：1400, Cost：0.010118, Accuracy：0.977941
# Pass：20, Batch：1450, Cost：0.006383, Accuracy：0.978860
# test - Pass: 20 Cost: 0.00806721305622826 Acc: 0.9974791666666667
# new BestPrecent: 0.9973645833333333 thie Precent: 0.9974791666666667
# Save...model...Best_precent: 0.9974791666666667
#
# Pass：21, Batch：50, Cost：0.005865, Accuracy：0.998468
# Pass：21, Batch：100, Cost：0.010795, Accuracy：0.977328
# Pass：21, Batch：150, Cost：0.008042, Accuracy：0.977328
# Pass：21, Batch：200, Cost：0.008572, Accuracy：0.977328
# Pass：21, Batch：250, Cost：0.008789, Accuracy：0.977941
# Pass：21, Batch：300, Cost：0.011396, Accuracy：0.977022
# Pass：21, Batch：350, Cost：0.011189, Accuracy：0.977328
# Pass：21, Batch：400, Cost：0.009798, Accuracy：0.977328
# Pass：21, Batch：450, Cost：0.013969, Accuracy：0.975797
# Pass：21, Batch：500, Cost：0.008434, Accuracy：0.977635
# Pass：21, Batch：550, Cost：0.012181, Accuracy：0.977328
# Pass：21, Batch：600, Cost：0.011805, Accuracy：0.977022
# Pass：21, Batch：650, Cost：0.012024, Accuracy：0.976103
# Pass：21, Batch：700, Cost：0.012163, Accuracy：0.976103
# Pass：21, Batch：750, Cost：0.010600, Accuracy：0.977328
# Pass：21, Batch：800, Cost：0.011684, Accuracy：0.976716
# Pass：21, Batch：850, Cost：0.010854, Accuracy：0.975797
# Pass：21, Batch：900, Cost：0.009301, Accuracy：0.977941
# Pass：21, Batch：950, Cost：0.011020, Accuracy：0.977022
# Pass：21, Batch：1000, Cost：0.013680, Accuracy：0.975797
# Pass：21, Batch：1050, Cost：0.011165, Accuracy：0.977022
# Pass：21, Batch：1100, Cost：0.008953, Accuracy：0.977328
# Pass：21, Batch：1150, Cost：0.007742, Accuracy：0.978248
# Pass：21, Batch：1200, Cost：0.011577, Accuracy：0.976716
# Pass：21, Batch：1250, Cost：0.008968, Accuracy：0.978248
# Pass：21, Batch：1300, Cost：0.011848, Accuracy：0.975797
# Pass：21, Batch：1350, Cost：0.019250, Accuracy：0.976103
# Pass：21, Batch：1400, Cost：0.008299, Accuracy：0.977022
# Pass：21, Batch：1450, Cost：0.007898, Accuracy：0.978248
# test - Pass: 21 Cost: 0.008654378873910901 Acc: 0.9972604166666666
# new BestPrecent: 0.9974791666666667 thie Precent: 0.9972604166666666
#
# Pass：22, Batch：50, Cost：0.009550, Accuracy：0.997855
# Pass：22, Batch：100, Cost：0.010969, Accuracy：0.977328
# Pass：22, Batch：150, Cost：0.010914, Accuracy：0.975490
# Pass：22, Batch：200, Cost：0.011179, Accuracy：0.977022
# Pass：22, Batch：250, Cost：0.013306, Accuracy：0.976409
# Pass：22, Batch：300, Cost：0.010033, Accuracy：0.976716
# Pass：22, Batch：350, Cost：0.011653, Accuracy：0.976716
# Pass：22, Batch：400, Cost：0.011463, Accuracy：0.977022
# Pass：22, Batch：450, Cost：0.010799, Accuracy：0.976716
# Pass：22, Batch：500, Cost：0.014268, Accuracy：0.975797
# Pass：22, Batch：550, Cost：0.009158, Accuracy：0.976409
# Pass：22, Batch：600, Cost：0.011840, Accuracy：0.977941
# Pass：22, Batch：650, Cost：0.007317, Accuracy：0.977941
# Pass：22, Batch：700, Cost：0.009210, Accuracy：0.977328
# Pass：22, Batch：750, Cost：0.009358, Accuracy：0.977022
# Pass：22, Batch：800, Cost：0.008260, Accuracy：0.977022
# Pass：22, Batch：850, Cost：0.007248, Accuracy：0.977635
# Pass：22, Batch：900, Cost：0.009892, Accuracy：0.976716
# Pass：22, Batch：950, Cost：0.008925, Accuracy：0.977941
# Pass：22, Batch：1000, Cost：0.006606, Accuracy：0.977941
# Pass：22, Batch：1050, Cost：0.007155, Accuracy：0.977635
# Pass：22, Batch：1100, Cost：0.008994, Accuracy：0.977022
# Pass：22, Batch：1150, Cost：0.009904, Accuracy：0.976716
# Pass：22, Batch：1200, Cost：0.005796, Accuracy：0.978554
# Pass：22, Batch：1250, Cost：0.008462, Accuracy：0.977941
# Pass：22, Batch：1300, Cost：0.011605, Accuracy：0.977328
# Pass：22, Batch：1350, Cost：0.010584, Accuracy：0.976409
# Pass：22, Batch：1400, Cost：0.010131, Accuracy：0.978248
# Pass：22, Batch：1450, Cost：0.011585, Accuracy：0.976409
# test - Pass: 22 Cost: 0.008858142108709824 Acc: 0.9968854166666666
# new BestPrecent: 0.9974791666666667 thie Precent: 0.9968854166666666
#
# Pass：23, Batch：50, Cost：0.007564, Accuracy：0.997549
# Pass：23, Batch：100, Cost：0.018908, Accuracy：0.974877
# Pass：23, Batch：150, Cost：0.007429, Accuracy：0.977328
# Pass：23, Batch：200, Cost：0.014095, Accuracy：0.976716
# Pass：23, Batch：250, Cost：0.007670, Accuracy：0.978554
# Pass：23, Batch：300, Cost：0.008126, Accuracy：0.978554
# Pass：23, Batch：350, Cost：0.012970, Accuracy：0.976409
# Pass：23, Batch：400, Cost：0.008631, Accuracy：0.977328
# Pass：23, Batch：450, Cost：0.011154, Accuracy：0.977328
# Pass：23, Batch：500, Cost：0.011746, Accuracy：0.977635
# Pass：23, Batch：550, Cost：0.007954, Accuracy：0.977328
# Pass：23, Batch：600, Cost：0.009493, Accuracy：0.977022
# Pass：23, Batch：650, Cost：0.009488, Accuracy：0.977635
# Pass：23, Batch：700, Cost：0.011742, Accuracy：0.975797
# Pass：23, Batch：750, Cost：0.006854, Accuracy：0.977635
# Pass：23, Batch：800, Cost：0.008324, Accuracy：0.977941
# Pass：23, Batch：850, Cost：0.009589, Accuracy：0.976409
# Pass：23, Batch：900, Cost：0.009657, Accuracy：0.978248
# Pass：23, Batch：950, Cost：0.007642, Accuracy：0.978248
# Pass：23, Batch：1000, Cost：0.008219, Accuracy：0.977328
# Pass：23, Batch：1050, Cost：0.009414, Accuracy：0.977328
# Pass：23, Batch：1100, Cost：0.015445, Accuracy：0.974877
# Pass：23, Batch：1150, Cost：0.006281, Accuracy：0.977941
# Pass：23, Batch：1200, Cost：0.009139, Accuracy：0.976716
# Pass：23, Batch：1250, Cost：0.008523, Accuracy：0.978554
# Pass：23, Batch：1300, Cost：0.010590, Accuracy：0.976716
# Pass：23, Batch：1350, Cost：0.008434, Accuracy：0.977328
# Pass：23, Batch：1400, Cost：0.008391, Accuracy：0.977635
# Pass：23, Batch：1450, Cost：0.010896, Accuracy：0.977941
# test - Pass: 23 Cost: 0.008110814441288918 Acc: 0.997375
# new BestPrecent: 0.9974791666666667 thie Precent: 0.997375
#
# Pass：24, Batch：50, Cost：0.007766, Accuracy：0.997549
# Pass：24, Batch：100, Cost：0.008457, Accuracy：0.977635
# Pass：24, Batch：150, Cost：0.009462, Accuracy：0.977328
# Pass：24, Batch：200, Cost：0.011442, Accuracy：0.977635
# Pass：24, Batch：250, Cost：0.008287, Accuracy：0.977941
# Pass：24, Batch：300, Cost：0.009527, Accuracy：0.977022
# Pass：24, Batch：350, Cost：0.011461, Accuracy：0.976716
# Pass：24, Batch：400, Cost：0.010645, Accuracy：0.977328
# Pass：24, Batch：450, Cost：0.009112, Accuracy：0.977328
# Pass：24, Batch：500, Cost：0.009400, Accuracy：0.978248
# Pass：24, Batch：550, Cost：0.005854, Accuracy：0.977941
# Pass：24, Batch：600, Cost：0.006014, Accuracy：0.978860
# Pass：24, Batch：650, Cost：0.011930, Accuracy：0.976409
# Pass：24, Batch：700, Cost：0.006303, Accuracy：0.978248
# Pass：24, Batch：750, Cost：0.008561, Accuracy：0.977328
# Pass：24, Batch：800, Cost：0.012562, Accuracy：0.976409
# Pass：24, Batch：850, Cost：0.010296, Accuracy：0.977328
# Pass：24, Batch：900, Cost：0.012730, Accuracy：0.976716
# Pass：24, Batch：950, Cost：0.009555, Accuracy：0.976409
# Pass：24, Batch：1000, Cost：0.014588, Accuracy：0.976103
# Pass：24, Batch：1050, Cost：0.009527, Accuracy：0.976103
# Pass：24, Batch：1100, Cost：0.007573, Accuracy：0.978554
# Pass：24, Batch：1150, Cost：0.011170, Accuracy：0.976716
# Pass：24, Batch：1200, Cost：0.010267, Accuracy：0.977328
# Pass：24, Batch：1250, Cost：0.007640, Accuracy：0.977328
# Pass：24, Batch：1300, Cost：0.007656, Accuracy：0.978554
# Pass：24, Batch：1350, Cost：0.013289, Accuracy：0.977022
# Pass：24, Batch：1400, Cost：0.010304, Accuracy：0.975797
# Pass：24, Batch：1450, Cost：0.010541, Accuracy：0.976103
# test - Pass: 24 Cost: 0.00829992678128474 Acc: 0.997375
# new BestPrecent: 0.9974791666666667 thie Precent: 0.997375
#
# Pass：25, Batch：50, Cost：0.013516, Accuracy：0.995711
# Pass：25, Batch：100, Cost：0.007503, Accuracy：0.978248
# Pass：25, Batch：150, Cost：0.006869, Accuracy：0.977941
# Pass：25, Batch：200, Cost：0.007960, Accuracy：0.978248
# Pass：25, Batch：250, Cost：0.005080, Accuracy：0.978860
# Pass：25, Batch：300, Cost：0.011699, Accuracy：0.977022
# Pass：25, Batch：350, Cost：0.007562, Accuracy：0.977941
# Pass：25, Batch：400, Cost：0.010221, Accuracy：0.977328
# Pass：25, Batch：450, Cost：0.008662, Accuracy：0.977328
# Pass：25, Batch：500, Cost：0.012986, Accuracy：0.976103
# Pass：25, Batch：550, Cost：0.012373, Accuracy：0.977941
# Pass：25, Batch：600, Cost：0.012062, Accuracy：0.976716
# Pass：25, Batch：650, Cost：0.008145, Accuracy：0.977328
# Pass：25, Batch：700, Cost：0.012747, Accuracy：0.975797
# Pass：25, Batch：750, Cost：0.008816, Accuracy：0.977635
# Pass：25, Batch：800, Cost：0.009305, Accuracy：0.977022
# Pass：25, Batch：850, Cost：0.007748, Accuracy：0.977635
# Pass：25, Batch：900, Cost：0.012223, Accuracy：0.977022
# Pass：25, Batch：950, Cost：0.015194, Accuracy：0.975184
# Pass：25, Batch：1000, Cost：0.012523, Accuracy：0.976716
# Pass：25, Batch：1050, Cost：0.011648, Accuracy：0.976716
# Pass：25, Batch：1100, Cost：0.010503, Accuracy：0.977328
# Pass：25, Batch：1150, Cost：0.011026, Accuracy：0.977328
# Pass：25, Batch：1200, Cost：0.009240, Accuracy：0.978248
# Pass：25, Batch：1250, Cost：0.007688, Accuracy：0.977635
# Pass：25, Batch：1300, Cost：0.005444, Accuracy：0.978248
# Pass：25, Batch：1350, Cost：0.005321, Accuracy：0.978860
# Pass：25, Batch：1400, Cost：0.008407, Accuracy：0.977022
# Pass：25, Batch：1450, Cost：0.010591, Accuracy：0.976716
# test - Pass: 25 Cost: 0.008640835111481162 Acc: 0.99715625
# new BestPrecent: 0.9974791666666667 thie Precent: 0.99715625
#
# Pass：26, Batch：50, Cost：0.007249, Accuracy：0.998468
# Pass：26, Batch：100, Cost：0.009736, Accuracy：0.977328
# Pass：26, Batch：150, Cost：0.006282, Accuracy：0.977941
# Pass：26, Batch：200, Cost：0.007399, Accuracy：0.977635
# Pass：26, Batch：250, Cost：0.011080, Accuracy：0.977022
# Pass：26, Batch：300, Cost：0.008824, Accuracy：0.977941
# Pass：26, Batch：350, Cost：0.011521, Accuracy：0.977328
# Pass：26, Batch：400, Cost：0.011804, Accuracy：0.976103
# Pass：26, Batch：450, Cost：0.006004, Accuracy：0.977941
# Pass：26, Batch：500, Cost：0.011432, Accuracy：0.975490
# Pass：26, Batch：550, Cost：0.009547, Accuracy：0.977328
# Pass：26, Batch：600, Cost：0.009189, Accuracy：0.977328
# Pass：26, Batch：650, Cost：0.008481, Accuracy：0.976716
# Pass：26, Batch：700, Cost：0.006850, Accuracy：0.977328
# Pass：26, Batch：750, Cost：0.009871, Accuracy：0.977328
# Pass：26, Batch：800, Cost：0.010292, Accuracy：0.976716
# Pass：26, Batch：850, Cost：0.014209, Accuracy：0.976103
# Pass：26, Batch：900, Cost：0.007025, Accuracy：0.977635
# Pass：26, Batch：950, Cost：0.007790, Accuracy：0.977941
# Pass：26, Batch：1000, Cost：0.014347, Accuracy：0.976409
# Pass：26, Batch：1050, Cost：0.009999, Accuracy：0.977635
# Pass：26, Batch：1100, Cost：0.017216, Accuracy：0.975490
# Pass：26, Batch：1150, Cost：0.006849, Accuracy：0.978554
# Pass：26, Batch：1200, Cost：0.011281, Accuracy：0.977328
# Pass：26, Batch：1250, Cost：0.009977, Accuracy：0.978248
# Pass：26, Batch：1300, Cost：0.007823, Accuracy：0.977941
# Pass：26, Batch：1350, Cost：0.009878, Accuracy：0.977328
# Pass：26, Batch：1400, Cost：0.007601, Accuracy：0.977635
# Pass：26, Batch：1450, Cost：0.008826, Accuracy：0.977635
# test - Pass: 26 Cost: 0.008256751713140451 Acc: 0.99740625
# new BestPrecent: 0.9974791666666667 thie Precent: 0.99740625
#
# Pass：27, Batch：50, Cost：0.009725, Accuracy：0.996630
# Pass：27, Batch：100, Cost：0.008717, Accuracy：0.977941
# Pass：27, Batch：150, Cost：0.008420, Accuracy：0.977328
# Pass：27, Batch：200, Cost：0.006076, Accuracy：0.978248
# Pass：27, Batch：250, Cost：0.014642, Accuracy：0.976716
# Pass：27, Batch：300, Cost：0.013755, Accuracy：0.975490
# Pass：27, Batch：350, Cost：0.011548, Accuracy：0.975184
# Pass：27, Batch：400, Cost：0.009755, Accuracy：0.977328
# Pass：27, Batch：450, Cost：0.005675, Accuracy：0.977941
# Pass：27, Batch：500, Cost：0.005938, Accuracy：0.979167
# Pass：27, Batch：550, Cost：0.015316, Accuracy：0.976409
# Pass：27, Batch：600, Cost：0.010043, Accuracy：0.978248
# Pass：27, Batch：650, Cost：0.010796, Accuracy：0.977328
# Pass：27, Batch：700, Cost：0.009744, Accuracy：0.976716
# Pass：27, Batch：750, Cost：0.012995, Accuracy：0.976103
# Pass：27, Batch：800, Cost：0.008941, Accuracy：0.977635
# Pass：27, Batch：850, Cost：0.012101, Accuracy：0.976409
# Pass：27, Batch：900, Cost：0.006946, Accuracy：0.978248
# Pass：27, Batch：950, Cost：0.008579, Accuracy：0.977635
# Pass：27, Batch：1000, Cost：0.016022, Accuracy：0.973039
# Pass：27, Batch：1050, Cost：0.012519, Accuracy：0.975797
# Pass：27, Batch：1100, Cost：0.006799, Accuracy：0.977941
# Pass：27, Batch：1150, Cost：0.009186, Accuracy：0.977635
# Pass：27, Batch：1200, Cost：0.008838, Accuracy：0.976716
# Pass：27, Batch：1250, Cost：0.011022, Accuracy：0.976409
# Pass：27, Batch：1300, Cost：0.008912, Accuracy：0.977941
# Pass：27, Batch：1350, Cost：0.009909, Accuracy：0.977328
# Pass：27, Batch：1400, Cost：0.010917, Accuracy：0.976409
# Pass：27, Batch：1450, Cost：0.009464, Accuracy：0.977635
# test - Pass: 27 Cost: 0.008333670028616324 Acc: 0.9972604166666666
# new BestPrecent: 0.9974791666666667 thie Precent: 0.9972604166666666
#
# Pass：28, Batch：50, Cost：0.010236, Accuracy：0.996324
# Pass：28, Batch：100, Cost：0.015193, Accuracy：0.975490
# Pass：28, Batch：150, Cost：0.011297, Accuracy：0.976409
# Pass：28, Batch：200, Cost：0.011091, Accuracy：0.976716
# Pass：28, Batch：250, Cost：0.009393, Accuracy：0.977328
# Pass：28, Batch：300, Cost：0.009060, Accuracy：0.978248
# Pass：28, Batch：350, Cost：0.008417, Accuracy：0.978248
# Pass：28, Batch：400, Cost：0.008718, Accuracy：0.977022
# Pass：28, Batch：450, Cost：0.010463, Accuracy：0.975490
# Pass：28, Batch：500, Cost：0.008186, Accuracy：0.977635
# Pass：28, Batch：550, Cost：0.008383, Accuracy：0.977328
# Pass：28, Batch：600, Cost：0.009516, Accuracy：0.978248
# Pass：28, Batch：650, Cost：0.008887, Accuracy：0.977328
# Pass：28, Batch：700, Cost：0.012104, Accuracy：0.976103
# Pass：28, Batch：750, Cost：0.007512, Accuracy：0.977635
# Pass：28, Batch：800, Cost：0.011694, Accuracy：0.976716
# Pass：28, Batch：850, Cost：0.011552, Accuracy：0.976409
# Pass：28, Batch：900, Cost：0.009789, Accuracy：0.976103
# Pass：28, Batch：950, Cost：0.009578, Accuracy：0.977328
# Pass：28, Batch：1000, Cost：0.012426, Accuracy：0.977328
# Pass：28, Batch：1050, Cost：0.012316, Accuracy：0.976103
# Pass：28, Batch：1100, Cost：0.007128, Accuracy：0.977941
# Pass：28, Batch：1150, Cost：0.010916, Accuracy：0.976716
# Pass：28, Batch：1200, Cost：0.008015, Accuracy：0.977022
# Pass：28, Batch：1250, Cost：0.007707, Accuracy：0.978554
# Pass：28, Batch：1300, Cost：0.012247, Accuracy：0.976409
# Pass：28, Batch：1350, Cost：0.005077, Accuracy：0.978860
# Pass：28, Batch：1400, Cost：0.009593, Accuracy：0.977328
# Pass：28, Batch：1450, Cost：0.007346, Accuracy：0.978554
# test - Pass: 28 Cost: 0.007412608098828059 Acc: 0.99759375
# new BestPrecent: 0.9974791666666667 thie Precent: 0.99759375
# Save...model...Best_precent: 0.99759375
#
# Pass：29, Batch：50, Cost：0.008575, Accuracy：0.996936
# Pass：29, Batch：100, Cost：0.011782, Accuracy：0.977328
# Pass：29, Batch：150, Cost：0.006501, Accuracy：0.977941
# Pass：29, Batch：200, Cost：0.012098, Accuracy：0.976103
# Pass：29, Batch：250, Cost：0.008141, Accuracy：0.977635
# Pass：29, Batch：300, Cost：0.010827, Accuracy：0.975184
# Pass：29, Batch：350, Cost：0.010628, Accuracy：0.977635
# Pass：29, Batch：400, Cost：0.010152, Accuracy：0.976716
# Pass：29, Batch：450, Cost：0.011357, Accuracy：0.977328
# Pass：29, Batch：500, Cost：0.006780, Accuracy：0.977328
# Pass：29, Batch：550, Cost：0.010978, Accuracy：0.977635
# Pass：29, Batch：600, Cost：0.005294, Accuracy：0.978554
# Pass：29, Batch：650, Cost：0.007534, Accuracy：0.977022
# Pass：29, Batch：700, Cost：0.013591, Accuracy：0.975797
# Pass：29, Batch：750, Cost：0.006238, Accuracy：0.978860
# Pass：29, Batch：800, Cost：0.007376, Accuracy：0.977941
# Pass：29, Batch：850, Cost：0.006916, Accuracy：0.978860
# Pass：29, Batch：900, Cost：0.011911, Accuracy：0.976409
# Pass：29, Batch：950, Cost：0.009920, Accuracy：0.976409
# Pass：29, Batch：1000, Cost：0.007907, Accuracy：0.976409
# Pass：29, Batch：1050, Cost：0.009480, Accuracy：0.977328
# Pass：29, Batch：1100, Cost：0.012210, Accuracy：0.976409
# Pass：29, Batch：1150, Cost：0.011770, Accuracy：0.976409
# Pass：29, Batch：1200, Cost：0.011845, Accuracy：0.977328
# Pass：29, Batch：1250, Cost：0.019473, Accuracy：0.975184
# Pass：29, Batch：1300, Cost：0.011581, Accuracy：0.975490
# Pass：29, Batch：1350, Cost：0.012878, Accuracy：0.976103
# Pass：29, Batch：1400, Cost：0.015458, Accuracy：0.975490
# Pass：29, Batch：1450, Cost：0.008106, Accuracy：0.977635
# test - Pass: 29 Cost: 0.007867450526209723 Acc: 0.99734375
# new BestPrecent: 0.99759375 thie Precent: 0.99734375
#
# Pass：30, Batch：50, Cost：0.007849, Accuracy：0.996936
# Pass：30, Batch：100, Cost：0.006476, Accuracy：0.978248
# Pass：30, Batch：150, Cost：0.006770, Accuracy：0.978248
# Pass：30, Batch：200, Cost：0.013227, Accuracy：0.976103
# Pass：30, Batch：250, Cost：0.013197, Accuracy：0.975490
# Pass：30, Batch：300, Cost：0.008855, Accuracy：0.976716
# Pass：30, Batch：350, Cost：0.008474, Accuracy：0.978248
# Pass：30, Batch：400, Cost：0.011794, Accuracy：0.975797
# Pass：30, Batch：450, Cost：0.009305, Accuracy：0.977022
# Pass：30, Batch：500, Cost：0.007454, Accuracy：0.977022
# Pass：30, Batch：550, Cost：0.006933, Accuracy：0.977941
# Pass：30, Batch：600, Cost：0.008502, Accuracy：0.977941
# Pass：30, Batch：650, Cost：0.008978, Accuracy：0.977941
# Pass：30, Batch：700, Cost：0.010455, Accuracy：0.976409
# Pass：30, Batch：750, Cost：0.010306, Accuracy：0.976409
# Pass：30, Batch：800, Cost：0.006122, Accuracy：0.978554
# Pass：30, Batch：850, Cost：0.007010, Accuracy：0.977022
# Pass：30, Batch：900, Cost：0.014201, Accuracy：0.975490
# Pass：30, Batch：950, Cost：0.007066, Accuracy：0.977941
# Pass：30, Batch：1000, Cost：0.012891, Accuracy：0.975490
# Pass：30, Batch：1050, Cost：0.006478, Accuracy：0.978860
# Pass：30, Batch：1100, Cost：0.012793, Accuracy：0.977635
# Pass：30, Batch：1150, Cost：0.009588, Accuracy：0.977022
# Pass：30, Batch：1200, Cost：0.008918, Accuracy：0.977328
# Pass：30, Batch：1250, Cost：0.010175, Accuracy：0.977635
# Pass：30, Batch：1300, Cost：0.008308, Accuracy：0.977635
# Pass：30, Batch：1350, Cost：0.008546, Accuracy：0.977635
# Pass：30, Batch：1400, Cost：0.006321, Accuracy：0.978248
# Pass：30, Batch：1450, Cost：0.008240, Accuracy：0.977328
# test - Pass: 30 Cost: 0.008365304403249563 Acc: 0.9973333333333333
# new BestPrecent: 0.99759375 thie Precent: 0.9973333333333333
#
# Pass：31, Batch：50, Cost：0.010904, Accuracy：0.996017
# Pass：31, Batch：100, Cost：0.008802, Accuracy：0.977941
# Pass：31, Batch：150, Cost：0.009724, Accuracy：0.976716
# Pass：31, Batch：200, Cost：0.010454, Accuracy：0.977022
# Pass：31, Batch：250, Cost：0.008720, Accuracy：0.978248
# Pass：31, Batch：300, Cost：0.010894, Accuracy：0.976409
# Pass：31, Batch：350, Cost：0.011772, Accuracy：0.976103
# Pass：31, Batch：400, Cost：0.008391, Accuracy：0.978860
# Pass：31, Batch：450, Cost：0.006666, Accuracy：0.978248
# Pass：31, Batch：500, Cost：0.011485, Accuracy：0.977328
# Pass：31, Batch：550, Cost：0.006519, Accuracy：0.977941
# Pass：31, Batch：600, Cost：0.010371, Accuracy：0.977328
# Pass：31, Batch：650, Cost：0.011609, Accuracy：0.977635
# Pass：31, Batch：700, Cost：0.008313, Accuracy：0.978860
# Pass：31, Batch：750, Cost：0.013623, Accuracy：0.976409
# Pass：31, Batch：800, Cost：0.011314, Accuracy：0.977328
# Pass：31, Batch：850, Cost：0.007032, Accuracy：0.977635
# Pass：31, Batch：900, Cost：0.008706, Accuracy：0.977941
# Pass：31, Batch：950, Cost：0.006438, Accuracy：0.978554
# Pass：31, Batch：1000, Cost：0.011744, Accuracy：0.976103
# Pass：31, Batch：1050, Cost：0.014824, Accuracy：0.975184
# Pass：31, Batch：1100, Cost：0.006694, Accuracy：0.977941
# Pass：31, Batch：1150, Cost：0.009795, Accuracy：0.978248
# Pass：31, Batch：1200, Cost：0.013152, Accuracy：0.977022
# Pass：31, Batch：1250, Cost：0.011113, Accuracy：0.977635
# Pass：31, Batch：1300, Cost：0.015924, Accuracy：0.975184
# Pass：31, Batch：1350, Cost：0.009358, Accuracy：0.977635
# Pass：31, Batch：1400, Cost：0.009357, Accuracy：0.977635
# Pass：31, Batch：1450, Cost：0.010007, Accuracy：0.977022
# test - Pass: 31 Cost: 0.008716304875301527 Acc: 0.99725
# new BestPrecent: 0.99759375 thie Precent: 0.99725
#
# Pass：32, Batch：50, Cost：0.010579, Accuracy：0.996936
# Pass：32, Batch：100, Cost：0.016172, Accuracy：0.975797
# Pass：32, Batch：150, Cost：0.007440, Accuracy：0.977022
# Pass：32, Batch：200, Cost：0.009631, Accuracy：0.977022
# Pass：32, Batch：250, Cost：0.009994, Accuracy：0.975490
# Pass：32, Batch：300, Cost：0.013517, Accuracy：0.977022
# Pass：32, Batch：350, Cost：0.004208, Accuracy：0.978860
# Pass：32, Batch：400, Cost：0.006363, Accuracy：0.978248
# Pass：32, Batch：450, Cost：0.010529, Accuracy：0.977022
# Pass：32, Batch：500, Cost：0.008389, Accuracy：0.977941
# Pass：32, Batch：550, Cost：0.007275, Accuracy：0.977328
# Pass：32, Batch：600, Cost：0.012218, Accuracy：0.975490
# Pass：32, Batch：650, Cost：0.008503, Accuracy：0.977941
# Pass：32, Batch：700, Cost：0.007664, Accuracy：0.977941
# Pass：32, Batch：750, Cost：0.007709, Accuracy：0.978860
# Pass：32, Batch：800, Cost：0.018438, Accuracy：0.976103
# Pass：32, Batch：850, Cost：0.006877, Accuracy：0.978248
# Pass：32, Batch：900, Cost：0.006887, Accuracy：0.978248
# Pass：32, Batch：950, Cost：0.009124, Accuracy：0.977022
# Pass：32, Batch：1000, Cost：0.007604, Accuracy：0.977022
# Pass：32, Batch：1050, Cost：0.007068, Accuracy：0.978248
# Pass：32, Batch：1100, Cost：0.013649, Accuracy：0.975184
# Pass：32, Batch：1150, Cost：0.007691, Accuracy：0.977022
# Pass：32, Batch：1200, Cost：0.009076, Accuracy：0.978248
# Pass：32, Batch：1250, Cost：0.006831, Accuracy：0.977941
# Pass：32, Batch：1300, Cost：0.012104, Accuracy：0.977328
# Pass：32, Batch：1350, Cost：0.013496, Accuracy：0.976409
# Pass：32, Batch：1400, Cost：0.011528, Accuracy：0.977022
# Pass：32, Batch：1450, Cost：0.010866, Accuracy：0.977022
# test - Pass: 32 Cost: 0.00842338869610588 Acc: 0.997375
# new BestPrecent: 0.99759375 thie Precent: 0.997375
#
# Pass：33, Batch：50, Cost：0.006652, Accuracy：0.998162
# Pass：33, Batch：100, Cost：0.008924, Accuracy：0.977635
# Pass：33, Batch：150, Cost：0.007308, Accuracy：0.978248
# Pass：33, Batch：200, Cost：0.008836, Accuracy：0.977328
# Pass：33, Batch：250, Cost：0.006025, Accuracy：0.978554
# Pass：33, Batch：300, Cost：0.014473, Accuracy：0.975490
# Pass：33, Batch：350, Cost：0.010312, Accuracy：0.976716
# Pass：33, Batch：400, Cost：0.012526, Accuracy：0.976409
# Pass：33, Batch：450, Cost：0.009266, Accuracy：0.976716
# Pass：33, Batch：500, Cost：0.014650, Accuracy：0.976716
# Pass：33, Batch：550, Cost：0.010646, Accuracy：0.977635
# Pass：33, Batch：600, Cost：0.006275, Accuracy：0.977635
# Pass：33, Batch：650, Cost：0.007048, Accuracy：0.978860
# Pass：33, Batch：700, Cost：0.012166, Accuracy：0.976103
# Pass：33, Batch：750, Cost：0.008215, Accuracy：0.977635
# Pass：33, Batch：800, Cost：0.008710, Accuracy：0.976409
# Pass：33, Batch：850, Cost：0.010037, Accuracy：0.976409
# Pass：33, Batch：900, Cost：0.011448, Accuracy：0.976103
# Pass：33, Batch：950, Cost：0.008460, Accuracy：0.977635
# Pass：33, Batch：1000, Cost：0.010901, Accuracy：0.978554
# Pass：33, Batch：1050, Cost：0.012733, Accuracy：0.975797
# Pass：33, Batch：1100, Cost：0.012539, Accuracy：0.976716
# Pass：33, Batch：1150, Cost：0.008501, Accuracy：0.977941
# Pass：33, Batch：1200, Cost：0.008898, Accuracy：0.976103
# Pass：33, Batch：1250, Cost：0.009851, Accuracy：0.977328
# Pass：33, Batch：1300, Cost：0.009692, Accuracy：0.977941
# Pass：33, Batch：1350, Cost：0.009625, Accuracy：0.977328
# Pass：33, Batch：1400, Cost：0.008423, Accuracy：0.978554
# Pass：33, Batch：1450, Cost：0.008733, Accuracy：0.977328
# test - Pass: 33 Cost: 0.008414777922722957 Acc: 0.9972291666666667
# new BestPrecent: 0.99759375 thie Precent: 0.9972291666666667
#
# Pass：34, Batch：50, Cost：0.008100, Accuracy：0.996936
# Pass：34, Batch：100, Cost：0.006821, Accuracy：0.977941
# Pass：34, Batch：150, Cost：0.010143, Accuracy：0.976409
# Pass：34, Batch：200, Cost：0.010367, Accuracy：0.976409
# Pass：34, Batch：250, Cost：0.014956, Accuracy：0.976409
# Pass：34, Batch：300, Cost：0.006860, Accuracy：0.977635
# Pass：34, Batch：350, Cost：0.009855, Accuracy：0.977941
# Pass：34, Batch：400, Cost：0.013916, Accuracy：0.975797
# Pass：34, Batch：450, Cost：0.014219, Accuracy：0.975797
# Pass：34, Batch：500, Cost：0.005293, Accuracy：0.978554
# Pass：34, Batch：550, Cost：0.011253, Accuracy：0.976409
# Pass：34, Batch：600, Cost：0.005897, Accuracy：0.978554
# Pass：34, Batch：650, Cost：0.011441, Accuracy：0.975490
# Pass：34, Batch：700, Cost：0.005523, Accuracy：0.978554
# Pass：34, Batch：750, Cost：0.010124, Accuracy：0.977635
# Pass：34, Batch：800, Cost：0.009378, Accuracy：0.976409
# Pass：34, Batch：850, Cost：0.005702, Accuracy：0.978860
# Pass：34, Batch：900, Cost：0.017922, Accuracy：0.975184
# Pass：34, Batch：950, Cost：0.011873, Accuracy：0.976409
# Pass：34, Batch：1000, Cost：0.008070, Accuracy：0.977022
# Pass：34, Batch：1050, Cost：0.009075, Accuracy：0.977328
# Pass：34, Batch：1100, Cost：0.009850, Accuracy：0.977022
# Pass：34, Batch：1150, Cost：0.008140, Accuracy：0.978554
# Pass：34, Batch：1200, Cost：0.008642, Accuracy：0.977022
# Pass：34, Batch：1250, Cost：0.011477, Accuracy：0.976716
# Pass：34, Batch：1300, Cost：0.007291, Accuracy：0.978554
# Pass：34, Batch：1350, Cost：0.006886, Accuracy：0.978248
# Pass：34, Batch：1400, Cost：0.008937, Accuracy：0.977022
# Pass：34, Batch：1450, Cost：0.013331, Accuracy：0.976103
# test - Pass: 34 Cost: 0.008692424514389738 Acc: 0.99715625
# new BestPrecent: 0.99759375 thie Precent: 0.99715625
#
# Pass：35, Batch：50, Cost：0.013431, Accuracy：0.997243
# Pass：35, Batch：100, Cost：0.009604, Accuracy：0.975797
# Pass：35, Batch：150, Cost：0.009106, Accuracy：0.976716
# Pass：35, Batch：200, Cost：0.008179, Accuracy：0.977635
# Pass：35, Batch：250, Cost：0.009358, Accuracy：0.977328
# Pass：35, Batch：300, Cost：0.011344, Accuracy：0.976409
# Pass：35, Batch：350, Cost：0.009004, Accuracy：0.977022
# Pass：35, Batch：400, Cost：0.012903, Accuracy：0.977022
# Pass：35, Batch：450, Cost：0.010570, Accuracy：0.976716
# Pass：35, Batch：500, Cost：0.006531, Accuracy：0.977022
# Pass：35, Batch：550, Cost：0.008670, Accuracy：0.977941
# Pass：35, Batch：600, Cost：0.011504, Accuracy：0.977328
# Pass：35, Batch：650, Cost：0.007705, Accuracy：0.977941
# Pass：35, Batch：700, Cost：0.007380, Accuracy：0.978248
# Pass：35, Batch：750, Cost：0.012213, Accuracy：0.976716
# Pass：35, Batch：800, Cost：0.009709, Accuracy：0.976716
# Pass：35, Batch：850, Cost：0.011424, Accuracy：0.976716
# Pass：35, Batch：900, Cost：0.003687, Accuracy：0.979779
# Pass：35, Batch：950, Cost：0.008915, Accuracy：0.977022
# Pass：35, Batch：1000, Cost：0.008132, Accuracy：0.977635
# Pass：35, Batch：1050, Cost：0.008388, Accuracy：0.977022
# Pass：35, Batch：1100, Cost：0.005596, Accuracy：0.978554
# Pass：35, Batch：1150, Cost：0.011640, Accuracy：0.975797
# Pass：35, Batch：1200, Cost：0.010531, Accuracy：0.977635
# Pass：35, Batch：1250, Cost：0.009762, Accuracy：0.978248
# Pass：35, Batch：1300, Cost：0.009812, Accuracy：0.976716
# Pass：35, Batch：1350, Cost：0.008987, Accuracy：0.976716
# Pass：35, Batch：1400, Cost：0.010950, Accuracy：0.976409
# Pass：35, Batch：1450, Cost：0.011688, Accuracy：0.976409
# test - Pass: 35 Cost: 0.00812560792012664 Acc: 0.9974895833333334
# new BestPrecent: 0.99759375 thie Precent: 0.9974895833333334
#
# Pass：36, Batch：50, Cost：0.013496, Accuracy：0.995404
# Pass：36, Batch：100, Cost：0.005452, Accuracy：0.977941
# Pass：36, Batch：150, Cost：0.011719, Accuracy：0.975797
# Pass：36, Batch：200, Cost：0.007719, Accuracy：0.977022
# Pass：36, Batch：250, Cost：0.008498, Accuracy：0.977941
# Pass：36, Batch：300, Cost：0.010762, Accuracy：0.977022
# Pass：36, Batch：350, Cost：0.007275, Accuracy：0.978554
# Pass：36, Batch：400, Cost：0.008756, Accuracy：0.976716
# Pass：36, Batch：450, Cost：0.012797, Accuracy：0.976409
# Pass：36, Batch：500, Cost：0.011965, Accuracy：0.976103
# Pass：36, Batch：550, Cost：0.009874, Accuracy：0.977022
# Pass：36, Batch：600, Cost：0.012531, Accuracy：0.977328
# Pass：36, Batch：650, Cost：0.010103, Accuracy：0.977328
# Pass：36, Batch：700, Cost：0.019808, Accuracy：0.975490
# Pass：36, Batch：750, Cost：0.010094, Accuracy：0.977635
# Pass：36, Batch：800, Cost：0.007351, Accuracy：0.976716
# Pass：36, Batch：850, Cost：0.009162, Accuracy：0.977022
# Pass：36, Batch：900, Cost：0.013449, Accuracy：0.976103
# Pass：36, Batch：950, Cost：0.007946, Accuracy：0.977635
# Pass：36, Batch：1000, Cost：0.009983, Accuracy：0.977022
# Pass：36, Batch：1050, Cost：0.009165, Accuracy：0.978248
# Pass：36, Batch：1100, Cost：0.007911, Accuracy：0.977635

# %%
save_model(save_model_name)

# %%
load_model(save_model_name)

# %%
save_inference(save_model_name)

# %%
test_image = test_list[19][20]
plt.figure()
plt.imshow(test_image)
test_image = np.array(test_image).astype('float32').reshape(1,1,64,64)/255
result = exe.run(program = test_program,feed = {'image':test_image,'label':np.array([[1]]).astype('int64')},fetch_list = [net])
print(np.argmax(result))
