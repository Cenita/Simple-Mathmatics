# %%
import paddle as paddle
import paddle.fluid as fluid
import numpy as np
import matplotlib.pyplot as plt
import sys
import cv2
import os
import random
import math
import PIL.Image as Image
from paddle.fluid.initializer import MSRA
from paddle.fluid.param_attr import ParamAttr
from visualdl import LogWriter

# %%
data_shape = [64,64]
class AlexNet():
    def __init__(self):
        pass

    def net(self, input, class_dim=1000):
        stdv = 1.0 / math.sqrt(input.shape[1] * 5 * 5)
        conv1 = fluid.layers.conv2d(
            input=input,
            num_filters=64,
            filter_size=5,
            stride=1,
            padding=2,
            groups=1,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))
        pool1 = fluid.layers.pool2d(
            input=conv1,
            pool_size=3,
            pool_stride=2,
            pool_padding=0,
            pool_type='max')

        stdv = 1.0 / math.sqrt(pool1.shape[1] * 5 * 5)
        conv2 = fluid.layers.conv2d(
            input=pool1,
            num_filters=192,
            filter_size=5,
            stride=1,
            padding=2,
            groups=1,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))
        pool2 = fluid.layers.pool2d(
            input=conv2,
            pool_size=3,
            pool_stride=2,
            pool_padding=0,
            pool_type='max')

        stdv = 1.0 / math.sqrt(pool2.shape[1] * 3 * 3)
        conv3 = fluid.layers.conv2d(
            input=pool2,
            num_filters=384,
            filter_size=3,
            stride=1,
            padding=1,
            groups=1,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))

        stdv = 1.0 / math.sqrt(conv3.shape[1] * 3 * 3)
        conv4 = fluid.layers.conv2d(
            input=conv3,
            num_filters=256,
            filter_size=3,
            stride=1,
            padding=1,
            groups=1,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))

        stdv = 1.0 / math.sqrt(conv4.shape[1] * 3 * 3)
        conv5 = fluid.layers.conv2d(
            input=conv4,
            num_filters=256,
            filter_size=3,
            stride=1,
            padding=1,
            groups=1,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))
        pool5 = fluid.layers.pool2d(
            input=conv5,
            pool_size=3,
            pool_stride=2,
            pool_padding=0,
            pool_type='max')
        print(pool5)
        drop6 = fluid.layers.dropout(x=pool5, dropout_prob=0.5)

        stdv = 1.0 / math.sqrt(drop6.shape[1] * drop6.shape[2] *
                               drop6.shape[3] * 1.0)
        fc6 = fluid.layers.fc(
            input=drop6,
            size=256,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))

        drop7 = fluid.layers.dropout(x=fc6, dropout_prob=0.5)

        stdv = 1.0 / math.sqrt(drop7.shape[1] * 1.0)
        fc7 = fluid.layers.fc(
            input=drop7,
            size=128,
            act='relu',
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)))

        stdv = 1.0 / math.sqrt(fc7.shape[1] * 1.0)
        out = fluid.layers.fc(
            input=fc7,
            size=class_dim,
            bias_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),
            param_attr=fluid.param_attr.ParamAttr(
                initializer=fluid.initializer.Uniform(-stdv, stdv)),act='softmax')
        return out

# %%
class ResNet():
    def __init__(self, layers=50):
        self.layers = layers

    def net(self, input, class_dim=1000):
        layers = self.layers
        if layers == 18:
            depth = [2, 2, 2, 2]
        if layers == 50:
            depth = [3, 4, 6, 3]
        elif layers == 101:
            depth = [3, 4, 23, 3]
        elif layers == 152:
            depth = [3, 8, 36, 3]
        num_filters = [64, 128, 256, 512]
        conv = self.conv_bn_layer(
            input=input, num_filters=64, filter_size=7, stride=2, act='relu')
        conv = fluid.layers.pool2d(
            input=conv,
            pool_size=3,
            pool_stride=2,
            pool_padding=1,
            pool_type='max')
        for block in range(len(depth)):
            for i in range(depth[block]):
                conv = self.bottleneck_block(
                    input=conv,
                    num_filters=num_filters[block],
                    stride=2 if i == 0 and block != 0 else 1)
        pool = fluid.layers.pool2d(
            input=conv, pool_size=7, pool_type='avg', global_pooling=True)
        stdv = 1.0 / math.sqrt(pool.shape[1] * 1.0)
        out = fluid.layers.fc(input=pool,
                              act = 'softmax',
                              size=class_dim,
                              param_attr=fluid.param_attr.ParamAttr(
                                  initializer=fluid.initializer.Uniform(-stdv,
                                                                        stdv)))
        return out
    def conv_bn_layer(self,
                      input,
                      num_filters,
                      filter_size,
                      stride=1,
                      groups=1,
                      act=None):
        conv = fluid.layers.conv2d(
            input=input,
            num_filters=num_filters,
            filter_size=filter_size,
            stride=stride,
            padding=(filter_size - 1) // 2,
            groups=groups,
            act=None,
            bias_attr=False)
        return fluid.layers.batch_norm(input=conv, act=act)

    def shortcut(self, input, ch_out, stride):
        ch_in = input.shape[1]
        if ch_in != ch_out or stride != 1:
            return self.conv_bn_layer(input, ch_out, 1, stride)
        else:
            return input

    def bottleneck_block(self, input, num_filters, stride):
        conv0 = self.conv_bn_layer(
            input=input, num_filters=num_filters, filter_size=1, act='relu')
        conv1 = self.conv_bn_layer(
            input=conv0,
            num_filters=num_filters,
            filter_size=3,
            stride=stride,
            act='relu')
        conv2 = self.conv_bn_layer(
            input=conv1, num_filters=num_filters * 4, filter_size=1, act=None)
        short = self.shortcut(input, num_filters * 4, stride)
        return fluid.layers.elementwise_add(x=short, y=conv2, act='relu')


def ResNet50():
    model = ResNet(layers=18)
    return model

# %%
yuzhi = 1
def addGaussianNoise(image): 
    G_Noiseimg = np.array(image)
    G_NoiseNum=random.randint(1,5)
    for i in range(G_NoiseNum): 
        temp_x = np.random.randint(0,image.shape[0])
        temp_y = np.random.randint(0,image.shape[0])
        temp_x_size = np.random.randint(1,5)
        temp_y_size = np.random.randint(1,5)
        temp_x_end = min(image.shape[0],temp_x+temp_x_size)
        temp_y_end = min(image.shape[0],temp_y+temp_y_size)
        for x in range(temp_x,temp_x_end):
            for y in range(temp_y,temp_y_end):
                G_Noiseimg[x][y] = 255
    return G_Noiseimg
def for_iterater_reader(t_list):
    def reader():
        for i in range(0,4000):
            for label in range(0,27):
              #  try:
                    #img = cv2.resize(img,(data_shape[0],data_shape[1]))
                    #img = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
                    #img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
                    tmp_ran = train_list[label]
                    ran_int = random.randint(0,len(tmp_ran)-1)#取随机的一个数
                    img = np.array(tmp_ran[ran_int]).reshape(64,64)
                    r_sofang = random.randint(6,12)/10
                    shape = int(r_sofang*data_shape[0])
                    img = Image.fromarray(img).resize((shape,shape))
                    img = np.array(img)
                    _, img = cv2.threshold(img, 10, 255,cv2.THRESH_BINARY)
                    r_x = random.randint(-5,5)
                    r_y = random.randint(-5,5)
                    r_rota = random.randint(-5,5)
                    r_yh = random.randint(1,3)
                    img = Image.fromarray(img)
                    img = img.rotate(r_rota)
                    tmpimg = Image.new('L',(data_shape[0],data_shape[0]))
                    tmpimg.paste(img,(r_x,r_y))
                    element1 = cv2.getStructuringElement(cv2.MORPH_RECT, (r_yh, r_yh))
                    tmpimg = cv2.dilate(np.array(tmpimg), element1, iterations = 1)
                    tmpimg = addGaussianNoise(tmpimg)
                    #img = cv2.blur(img,(20,20))#羽化
                    #ret, binary = cv2.threshold(img, 50, 255,cv2.THRESH_BINARY)
                    #element1 = cv2.getStructuringElement(cv2.MORPH_RECT, (10,10))#拓展
                    #img = cv2.erode(binary, element1, iterations = 1)
                    img = np.array(tmpimg)
                    ######################################################
                    img = img.reshape(1,data_shape[0],data_shape[1]).astype('float32')
                    img = (img)/255 
                    yield label,img
            #    except Exception:
             #       print(label)
    return reader

def for_test_reader(t_list):
    def reader():
        for class_index in t_list:
            image = np.array(class_index[1]).reshape(64,64)
            image = Image.fromarray(image).resize((data_shape[0],data_shape[0]))
            image = np.array(image).reshape(1,data_shape[0],data_shape[0]).astype('float32')
            image = (image) / 255.0
            yield class_index[0],image
    return reader

# %%
#1.设置地方
place = fluid.CUDAPlace(0)
#2.设置数据和设置标签
label = fluid.layers.data(name = 'label',shape=[1],dtype='int64')
image = fluid.layers.data(name = 'image',shape=[1,data_shape[0],data_shape[1]],dtype='float32')
#3.设置网络和Feeder
feeder = fluid.DataFeeder(place = place , feed_list = [label,image])
net = ResNet50().net(image,27)
#4.设置损失函数和正确率
cost = fluid.layers.cross_entropy(input = net , label = label)
avg_cost = fluid.layers.mean(cost)
acc = fluid.layers.accuracy(input = net , label =label)
#.定义测试程序
test_program = fluid.default_main_program().clone(for_test=True)
#5.设置优化
optimizer = fluid.optimizer.Adam(learning_rate=0.000001)
optimizer.minimize(avg_cost)
#6.定义Executor
exe = fluid.Executor(place = place)
exe.run(fluid.default_startup_program())
# Out:
# []

# %%
import shutil
import os
def save_inference(pass_id):
     # 保存预测模型
    save_path = 'models/infer_model/'+str(pass_id)+"/"
    # 删除旧的模型文件
    shutil.rmtree(save_path, ignore_errors=True)
    # 创建保持模型文件目录
    os.makedirs(save_path)
    # 保存预测模型
    fluid.io.save_inference_model(save_path, feeded_var_names=[image.name], target_vars=[net], executor=exe)

def save_model(pass_id):
    # 保存参数模型
    save_path = 'models/params_model/'+str(pass_id)+"/"
    # 删除旧的模型文件
    shutil.rmtree(save_path, ignore_errors=True)
    # 创建保持模型文件目录
    os.makedirs(save_path)
    # 保存参数模型
    fluid.io.save_params(executor=exe, dirname=save_path)

def load_model(pass_id):
    # 加载之前训练过的参数模型
    save_path = 'models/params_model/'+str(pass_id)
    if os.path.exists(save_path):
        print('使用参数模型作为预训练模型')
        fluid.io.load_params(executor=exe, dirname=save_path)

# %%
def produce_path_label(path):
    train_list = np.load(path)
    return train_list

def produce_test(path):
    train_list = []
    train_data = open(path).readlines()
    for i in train_data:
        items = i.split(',')
        class_index = int(items[0])
        img = np.array(items[1:]).astype('uint8')
        train_list.append([class_index,img])
    return train_list

train_list = produce_path_label('data/train_list.npy')
test_list = produce_path_label('data/test_list.npy')
true_test_list = produce_test('true_test_list.txt')

# %%
#8.数据分批
train_Reader = paddle.batch(reader=paddle.reader.shuffle(for_iterater_reader(train_list),buf_size = 128*128),batch_size=64)
test_Reader = paddle.batch(reader=paddle.reader.shuffle(for_iterater_reader(test_list),buf_size = 128*128),batch_size=64)
true_test_Reader = paddle.batch(reader=paddle.reader.shuffle(for_test_reader(true_test_list),buf_size = 128*128),batch_size=64)

# %%
print("加载完毕")
# Out:
# 加载完毕

# %%
#9.训练
step = 0
best_model_precent = 0
error_cout = 20
save_model_name = 3

# %%
load_model(save_model_name)
# Out:
# 使用参数模型作为预训练模型

# %%
 def train():
    for pass_id in range(20000):
        sum_cost=0
        sum_acc=0
        global best_model_precent
        for batch_id , data in enumerate(train_Reader()):
            train_cost, train_acc = exe.run(program = fluid.default_main_program(),
                                           feed = feeder.feed(data),
                                            fetch_list = [avg_cost,acc]
                                           )
            sum_cost = sum_cost + train_cost[0]
            sum_acc = sum_acc + train_acc[0]
            if batch_id % 50 == 0 and batch_id != 0:
                print('Pass：%d, Batch：%d, Cost：%f, Accuracy：%f' % (pass_id , batch_id , sum_cost/51, sum_acc/51))
                sum_cost = 0
                sum_acc = 0
        
        test_sum_cost=0
        test_sum_acc=0
        test_cout = 0
        for batch_id , data in enumerate(test_Reader()):
            train_cost, train_acc = exe.run(program = test_program,
                                           feed = feeder.feed(data),
                                            fetch_list = [avg_cost,acc]
                                           )
            test_sum_cost = test_sum_cost + train_cost[0]
            test_sum_acc = test_sum_acc + train_acc[0]
            test_cout+=1
        print("test - Pass:",pass_id,"Cost:",test_sum_cost/test_cout,"Acc:",test_sum_acc/test_cout)
        total_model_precent = (test_sum_acc/test_cout)
        print("new BestPrecent:",best_model_precent,"thie Precent:",total_model_precent)
        if total_model_precent > best_model_precent:
            best_model_precent = total_model_precent
            save_model(save_model_name)
            print("Save...model...Best_precent:",best_model_precent)
        print()
train()
# Out:
# Pass：0, Batch：50, Cost：0.066582, Accuracy：0.979473
# Pass：0, Batch：100, Cost：0.061310, Accuracy：0.961397
# Pass：0, Batch：150, Cost：0.061061, Accuracy：0.961397
# Pass：0, Batch：200, Cost：0.062718, Accuracy：0.961397
# Pass：0, Batch：250, Cost：0.060174, Accuracy：0.962316
# Pass：0, Batch：300, Cost：0.059215, Accuracy：0.961397
# Pass：0, Batch：350, Cost：0.051817, Accuracy：0.965074
# Pass：0, Batch：400, Cost：0.041980, Accuracy：0.967218
# Pass：0, Batch：450, Cost：0.060392, Accuracy：0.961703
# Pass：0, Batch：500, Cost：0.053027, Accuracy：0.963542
# Pass：0, Batch：550, Cost：0.051508, Accuracy：0.963848
# Pass：0, Batch：600, Cost：0.048350, Accuracy：0.965993
# Pass：0, Batch：650, Cost：0.061562, Accuracy：0.961091
# Pass：0, Batch：700, Cost：0.047737, Accuracy：0.964767
# Pass：0, Batch：750, Cost：0.045583, Accuracy：0.964767
# Pass：0, Batch：800, Cost：0.040926, Accuracy：0.968750
# Pass：0, Batch：850, Cost：0.043985, Accuracy：0.965074
# Pass：0, Batch：900, Cost：0.051233, Accuracy：0.964461
# Pass：0, Batch：950, Cost：0.037417, Accuracy：0.968444
# Pass：0, Batch：1000, Cost：0.034864, Accuracy：0.969975
# Pass：0, Batch：1050, Cost：0.047439, Accuracy：0.966912
# Pass：0, Batch：1100, Cost：0.053036, Accuracy：0.964154
# Pass：0, Batch：1150, Cost：0.046662, Accuracy：0.967831
# Pass：0, Batch：1200, Cost：0.045967, Accuracy：0.965993
# Pass：0, Batch：1250, Cost：0.050179, Accuracy：0.962623
# Pass：0, Batch：1300, Cost：0.041359, Accuracy：0.964767
# Pass：0, Batch：1350, Cost：0.039955, Accuracy：0.966605
# Pass：0, Batch：1400, Cost：0.042645, Accuracy：0.965074
# Pass：0, Batch：1450, Cost：0.048440, Accuracy：0.964767
# Pass：0, Batch：1500, Cost：0.037658, Accuracy：0.968444
# Pass：0, Batch：1550, Cost：0.051258, Accuracy：0.962623
# Pass：0, Batch：1600, Cost：0.046849, Accuracy：0.964461
# Pass：0, Batch：1650, Cost：0.048726, Accuracy：0.966605
# test - Pass: 0 Cost: 0.03927672465294749 Acc: 0.9874574200236966
# new BestPrecent: 0 thie Precent: 0.9874574200236966
# Save...model...Best_precent: 0.9874574200236966
#
# Pass：1, Batch：50, Cost：0.049280, Accuracy：0.984069
# Pass：1, Batch：100, Cost：0.042037, Accuracy：0.965993
# Pass：1, Batch：150, Cost：0.047434, Accuracy：0.965380
# Pass：1, Batch：200, Cost：0.048865, Accuracy：0.965074
# Pass：1, Batch：250, Cost：0.042055, Accuracy：0.965993
# Pass：1, Batch：300, Cost：0.053908, Accuracy：0.963848
# Pass：1, Batch：350, Cost：0.042006, Accuracy：0.969056
# Pass：1, Batch：400, Cost：0.045962, Accuracy：0.965380
# Pass：1, Batch：450, Cost：0.035331, Accuracy：0.970895
# Pass：1, Batch：500, Cost：0.040615, Accuracy：0.966912
# Pass：1, Batch：550, Cost：0.049460, Accuracy：0.964154
# Pass：1, Batch：600, Cost：0.041441, Accuracy：0.967525
# Pass：1, Batch：650, Cost：0.048015, Accuracy：0.964154
# Pass：1, Batch：700, Cost：0.036166, Accuracy：0.969056
# Pass：1, Batch：750, Cost：0.037292, Accuracy：0.968137
# Pass：1, Batch：800, Cost：0.047940, Accuracy：0.966299
# Pass：1, Batch：850, Cost：0.039520, Accuracy：0.966912
# Pass：1, Batch：900, Cost：0.041223, Accuracy：0.966605
# Pass：1, Batch：950, Cost：0.031077, Accuracy：0.970588
# Pass：1, Batch：1000, Cost：0.045383, Accuracy：0.964154
# Pass：1, Batch：1050, Cost：0.045408, Accuracy：0.968750
# Pass：1, Batch：1100, Cost：0.035410, Accuracy：0.966912
# Pass：1, Batch：1150, Cost：0.042263, Accuracy：0.967525
# Pass：1, Batch：1200, Cost：0.038720, Accuracy：0.968444
# Pass：1, Batch：1250, Cost：0.048620, Accuracy：0.966605
# Pass：1, Batch：1300, Cost：0.031968, Accuracy：0.970588
# Pass：1, Batch：1350, Cost：0.032193, Accuracy：0.970588
# Pass：1, Batch：1400, Cost：0.038726, Accuracy：0.968444
# Pass：1, Batch：1450, Cost：0.042656, Accuracy：0.965993
# Pass：1, Batch：1500, Cost：0.043719, Accuracy：0.966912
# Pass：1, Batch：1550, Cost：0.042298, Accuracy：0.967218
# Pass：1, Batch：1600, Cost：0.035159, Accuracy：0.967525
# Pass：1, Batch：1650, Cost：0.033022, Accuracy：0.969975
# test - Pass: 1 Cost: 0.03526673097927863 Acc: 0.988827384478673
# new BestPrecent: 0.9874574200236966 thie Precent: 0.988827384478673
# Save...model...Best_precent: 0.988827384478673
#
# Pass：2, Batch：50, Cost：0.044735, Accuracy：0.984681
# Pass：2, Batch：100, Cost：0.047408, Accuracy：0.966299
# Pass：2, Batch：150, Cost：0.044905, Accuracy：0.965380
# Pass：2, Batch：200, Cost：0.040421, Accuracy：0.968137
# Pass：2, Batch：250, Cost：0.036625, Accuracy：0.966912
# Pass：2, Batch：300, Cost：0.032945, Accuracy：0.969975
# Pass：2, Batch：350, Cost：0.035338, Accuracy：0.969975
# Pass：2, Batch：400, Cost：0.055993, Accuracy：0.965074
# Pass：2, Batch：450, Cost：0.045986, Accuracy：0.965380
# Pass：2, Batch：500, Cost：0.041978, Accuracy：0.967525
# Pass：2, Batch：550, Cost：0.039802, Accuracy：0.967831
# Pass：2, Batch：600, Cost：0.036240, Accuracy：0.969056
# Pass：2, Batch：650, Cost：0.046338, Accuracy：0.965380
# Pass：2, Batch：700, Cost：0.041515, Accuracy：0.965686
# Pass：2, Batch：750, Cost：0.034359, Accuracy：0.969056
# Pass：2, Batch：800, Cost：0.040660, Accuracy：0.966605
# Pass：2, Batch：850, Cost：0.033275, Accuracy：0.969669
# Pass：2, Batch：900, Cost：0.037478, Accuracy：0.967525
# Pass：2, Batch：950, Cost：0.040578, Accuracy：0.967831
# Pass：2, Batch：1000, Cost：0.038093, Accuracy：0.968137
# Pass：2, Batch：1050, Cost：0.033849, Accuracy：0.968444
# Pass：2, Batch：1100, Cost：0.036123, Accuracy：0.968444
# Pass：2, Batch：1150, Cost：0.033028, Accuracy：0.969669
# Pass：2, Batch：1200, Cost：0.030717, Accuracy：0.971201
# Pass：2, Batch：1250, Cost：0.044672, Accuracy：0.965074
# Pass：2, Batch：1300, Cost：0.030800, Accuracy：0.968444
# Pass：2, Batch：1350, Cost：0.041019, Accuracy：0.966605
# Pass：2, Batch：1400, Cost：0.035089, Accuracy：0.969363
# Pass：2, Batch：1450, Cost：0.042501, Accuracy：0.968137
# Pass：2, Batch：1500, Cost：0.042344, Accuracy：0.969056
# Pass：2, Batch：1550, Cost：0.033716, Accuracy：0.970895
# Pass：2, Batch：1600, Cost：0.038853, Accuracy：0.968444
# Pass：2, Batch：1650, Cost：0.058834, Accuracy：0.960784
# test - Pass: 2 Cost: 0.032124061490235556 Acc: 0.9899289099526066
# new BestPrecent: 0.988827384478673 thie Precent: 0.9899289099526066
# Save...model...Best_precent: 0.9899289099526066
#
# Pass：3, Batch：50, Cost：0.028975, Accuracy：0.989583
# Pass：3, Batch：100, Cost：0.037856, Accuracy：0.969363
# Pass：3, Batch：150, Cost：0.034113, Accuracy：0.969056
# Pass：3, Batch：200, Cost：0.036660, Accuracy：0.967218
# Pass：3, Batch：250, Cost：0.039217, Accuracy：0.967525
# Pass：3, Batch：300, Cost：0.033372, Accuracy：0.968750
# Pass：3, Batch：350, Cost：0.036049, Accuracy：0.968750
# Pass：3, Batch：400, Cost：0.035388, Accuracy：0.968137
# Pass：3, Batch：450, Cost：0.033513, Accuracy：0.968750
# Pass：3, Batch：500, Cost：0.047830, Accuracy：0.965993
# Pass：3, Batch：550, Cost：0.027219, Accuracy：0.972426
# Pass：3, Batch：600, Cost：0.042343, Accuracy：0.966605
# Pass：3, Batch：650, Cost：0.035669, Accuracy：0.969975
# Pass：3, Batch：700, Cost：0.033017, Accuracy：0.969669
# Pass：3, Batch：750, Cost：0.040143, Accuracy：0.966605
# Pass：3, Batch：800, Cost：0.032220, Accuracy：0.968750
# Pass：3, Batch：850, Cost：0.034390, Accuracy：0.968444
# Pass：3, Batch：900, Cost：0.036808, Accuracy：0.969056
# Pass：3, Batch：950, Cost：0.036525, Accuracy：0.966912
# Pass：3, Batch：1000, Cost：0.031583, Accuracy：0.969363
# Pass：3, Batch：1050, Cost：0.038760, Accuracy：0.968137
# Pass：3, Batch：1100, Cost：0.033990, Accuracy：0.969363
# Pass：3, Batch：1150, Cost：0.037940, Accuracy：0.968444
# Pass：3, Batch：1200, Cost：0.029312, Accuracy：0.971507
# Pass：3, Batch：1250, Cost：0.038031, Accuracy：0.967218
# Pass：3, Batch：1300, Cost：0.038307, Accuracy：0.967218
# Pass：3, Batch：1350, Cost：0.036135, Accuracy：0.969975
# Pass：3, Batch：1400, Cost：0.036410, Accuracy：0.969975
# Pass：3, Batch：1450, Cost：0.030316, Accuracy：0.971201
# Pass：3, Batch：1500, Cost：0.035845, Accuracy：0.969363
# Pass：3, Batch：1550, Cost：0.044636, Accuracy：0.964767
# Pass：3, Batch：1600, Cost：0.034069, Accuracy：0.970588
# Pass：3, Batch：1650, Cost：0.032286, Accuracy：0.969975
# test - Pass: 3 Cost: 0.030560079184677357 Acc: 0.9900955272511849
# new BestPrecent: 0.9899289099526066 thie Precent: 0.9900955272511849
# Save...model...Best_precent: 0.9900955272511849
#
# Pass：4, Batch：50, Cost：0.034742, Accuracy：0.986826
# Pass：4, Batch：100, Cost：0.041097, Accuracy：0.967525
# Pass：4, Batch：150, Cost：0.036687, Accuracy：0.967831
# Pass：4, Batch：200, Cost：0.041395, Accuracy：0.965993
# Pass：4, Batch：250, Cost：0.029416, Accuracy：0.969975
# Pass：4, Batch：300, Cost：0.036462, Accuracy：0.969056
# Pass：4, Batch：350, Cost：0.042902, Accuracy：0.965993
# Pass：4, Batch：400, Cost：0.039766, Accuracy：0.965993
# Pass：4, Batch：450, Cost：0.040304, Accuracy：0.966912
# Pass：4, Batch：500, Cost：0.030438, Accuracy：0.970588
# Pass：4, Batch：550, Cost：0.033025, Accuracy：0.969669
# Pass：4, Batch：600, Cost：0.027958, Accuracy：0.970282
# Pass：4, Batch：650, Cost：0.026042, Accuracy：0.972120
# Pass：4, Batch：700, Cost：0.029445, Accuracy：0.973039
# Pass：4, Batch：750, Cost：0.034569, Accuracy：0.968137
# Pass：4, Batch：800, Cost：0.039953, Accuracy：0.968750
# Pass：4, Batch：850, Cost：0.033243, Accuracy：0.968444
# Pass：4, Batch：900, Cost：0.025441, Accuracy：0.971507
# Pass：4, Batch：950, Cost：0.035645, Accuracy：0.968444
# Pass：4, Batch：1000, Cost：0.033374, Accuracy：0.969056
# Pass：4, Batch：1050, Cost：0.032861, Accuracy：0.971507
# Pass：4, Batch：1100, Cost：0.034339, Accuracy：0.971201
# Pass：4, Batch：1150, Cost：0.028825, Accuracy：0.971201
# Pass：4, Batch：1200, Cost：0.032265, Accuracy：0.969669
# Pass：4, Batch：1250, Cost：0.029510, Accuracy：0.969363
# Pass：4, Batch：1300, Cost：0.037373, Accuracy：0.968750
# Pass：4, Batch：1350, Cost：0.039301, Accuracy：0.965686
# Pass：4, Batch：1400, Cost：0.041811, Accuracy：0.966299
# Pass：4, Batch：1450, Cost：0.026924, Accuracy：0.973958
# Pass：4, Batch：1500, Cost：0.040327, Accuracy：0.965686
# Pass：4, Batch：1550, Cost：0.047151, Accuracy：0.964154
# Pass：4, Batch：1600, Cost：0.031529, Accuracy：0.969669
# Pass：4, Batch：1650, Cost：0.034143, Accuracy：0.969363
# test - Pass: 4 Cost: 0.0273889843862773 Acc: 0.9911507701421801
# new BestPrecent: 0.9900955272511849 thie Precent: 0.9911507701421801
# Save...model...Best_precent: 0.9911507701421801
#
# Pass：5, Batch：50, Cost：0.028088, Accuracy：0.990502
# Pass：5, Batch：100, Cost：0.031461, Accuracy：0.969669
# Pass：5, Batch：150, Cost：0.035959, Accuracy：0.969975
# Pass：5, Batch：200, Cost：0.035207, Accuracy：0.969669
# Pass：5, Batch：250, Cost：0.028977, Accuracy：0.970282
# Pass：5, Batch：300, Cost：0.039871, Accuracy：0.968750
# Pass：5, Batch：350, Cost：0.025584, Accuracy：0.971201
# Pass：5, Batch：400, Cost：0.030189, Accuracy：0.969363
# Pass：5, Batch：450, Cost：0.037827, Accuracy：0.967218
# Pass：5, Batch：500, Cost：0.034778, Accuracy：0.968444
# Pass：5, Batch：550, Cost：0.034612, Accuracy：0.967525
# Pass：5, Batch：600, Cost：0.039974, Accuracy：0.966912
# Pass：5, Batch：650, Cost：0.026342, Accuracy：0.971814
# Pass：5, Batch：700, Cost：0.030777, Accuracy：0.970282
# Pass：5, Batch：750, Cost：0.023800, Accuracy：0.973652
# Pass：5, Batch：800, Cost：0.027055, Accuracy：0.972120
# Pass：5, Batch：850, Cost：0.038321, Accuracy：0.967525
# Pass：5, Batch：900, Cost：0.033135, Accuracy：0.969363
# Pass：5, Batch：950, Cost：0.031005, Accuracy：0.972120
# Pass：5, Batch：1000, Cost：0.040899, Accuracy：0.967525
# Pass：5, Batch：1050, Cost：0.036010, Accuracy：0.970282
# Pass：5, Batch：1100, Cost：0.039190, Accuracy：0.967218
# Pass：5, Batch：1150, Cost：0.042907, Accuracy：0.965993
# Pass：5, Batch：1200, Cost：0.028856, Accuracy：0.970282
# Pass：5, Batch：1250, Cost：0.029768, Accuracy：0.971201
# Pass：5, Batch：1300, Cost：0.038748, Accuracy：0.969056
# Pass：5, Batch：1350, Cost：0.032248, Accuracy：0.972120
# Pass：5, Batch：1400, Cost：0.029916, Accuracy：0.970282
# Pass：5, Batch：1450, Cost：0.036560, Accuracy：0.969363
# Pass：5, Batch：1500, Cost：0.031030, Accuracy：0.972120
# Pass：5, Batch：1550, Cost：0.036314, Accuracy：0.969363
# Pass：5, Batch：1600, Cost：0.030011, Accuracy：0.969975
# Pass：5, Batch：1650, Cost：0.030107, Accuracy：0.971507
# test - Pass: 5 Cost: 0.026388488618994378 Acc: 0.9913173874407583
# new BestPrecent: 0.9911507701421801 thie Precent: 0.9913173874407583
# Save...model...Best_precent: 0.9913173874407583
#
# Pass：6, Batch：50, Cost：0.035634, Accuracy：0.989277
# Pass：6, Batch：100, Cost：0.027105, Accuracy：0.970588
# Pass：6, Batch：150, Cost：0.034644, Accuracy：0.970895
# Pass：6, Batch：200, Cost：0.029078, Accuracy：0.971507
# Pass：6, Batch：250, Cost：0.041218, Accuracy：0.967218
# Pass：6, Batch：300, Cost：0.035699, Accuracy：0.968137
# Pass：6, Batch：350, Cost：0.034316, Accuracy：0.969975
# Pass：6, Batch：400, Cost：0.027669, Accuracy：0.972733
# Pass：6, Batch：450, Cost：0.030712, Accuracy：0.972426
# Pass：6, Batch：500, Cost：0.031967, Accuracy：0.972120
# Pass：6, Batch：550, Cost：0.031441, Accuracy：0.971507
# Pass：6, Batch：600, Cost：0.038479, Accuracy：0.968137
# Pass：6, Batch：650, Cost：0.027293, Accuracy：0.972120
# Pass：6, Batch：700, Cost：0.032747, Accuracy：0.970895
# Pass：6, Batch：750, Cost：0.032669, Accuracy：0.971814
# Pass：6, Batch：800, Cost：0.037227, Accuracy：0.969056
# Pass：6, Batch：850, Cost：0.031176, Accuracy：0.968444
# Pass：6, Batch：900, Cost：0.032998, Accuracy：0.970895
# Pass：6, Batch：950, Cost：0.029123, Accuracy：0.970282
# Pass：6, Batch：1000, Cost：0.026991, Accuracy：0.970588
# Pass：6, Batch：1050, Cost：0.032402, Accuracy：0.969669
# Pass：6, Batch：1100, Cost：0.035038, Accuracy：0.969056
# Pass：6, Batch：1150, Cost：0.030433, Accuracy：0.970282
# Pass：6, Batch：1200, Cost：0.030917, Accuracy：0.972426
# Pass：6, Batch：1250, Cost：0.027521, Accuracy：0.971507
# Pass：6, Batch：1300, Cost：0.034587, Accuracy：0.969056
# Pass：6, Batch：1350, Cost：0.030038, Accuracy：0.971201
# Pass：6, Batch：1400, Cost：0.026225, Accuracy：0.971814
# Pass：6, Batch：1450, Cost：0.031104, Accuracy：0.969363
# Pass：6, Batch：1500, Cost：0.036705, Accuracy：0.969056
# Pass：6, Batch：1550, Cost：0.031439, Accuracy：0.971201
# Pass：6, Batch：1600, Cost：0.028889, Accuracy：0.971201
# Pass：6, Batch：1650, Cost：0.040844, Accuracy：0.968444
# test - Pass: 6 Cost: 0.02515360675373537 Acc: 0.9921412174170616
# new BestPrecent: 0.9913173874407583 thie Precent: 0.9921412174170616
# Save...model...Best_precent: 0.9921412174170616
#
# Pass：7, Batch：50, Cost：0.026050, Accuracy：0.994485
# Pass：7, Batch：100, Cost：0.026256, Accuracy：0.973039
# Pass：7, Batch：150, Cost：0.027131, Accuracy：0.972120
# Pass：7, Batch：200, Cost：0.035659, Accuracy：0.967831
# Pass：7, Batch：250, Cost：0.037066, Accuracy：0.968750
# Pass：7, Batch：300, Cost：0.026667, Accuracy：0.970895
# Pass：7, Batch：350, Cost：0.035394, Accuracy：0.969363
# Pass：7, Batch：400, Cost：0.029242, Accuracy：0.971814
# Pass：7, Batch：450, Cost：0.038231, Accuracy：0.967218
# Pass：7, Batch：500, Cost：0.031736, Accuracy：0.969363
# Pass：7, Batch：550, Cost：0.033703, Accuracy：0.969363
# Pass：7, Batch：600, Cost：0.024264, Accuracy：0.971507
# Pass：7, Batch：650, Cost：0.038126, Accuracy：0.967525
# Pass：7, Batch：700, Cost：0.026825, Accuracy：0.972733
# Pass：7, Batch：750, Cost：0.025119, Accuracy：0.973346
# Pass：7, Batch：800, Cost：0.025555, Accuracy：0.972120
# Pass：7, Batch：850, Cost：0.031344, Accuracy：0.969975
# Pass：7, Batch：900, Cost：0.021799, Accuracy：0.971814
# Pass：7, Batch：950, Cost：0.031793, Accuracy：0.969669
# Pass：7, Batch：1000, Cost：0.037612, Accuracy：0.969363
# Pass：7, Batch：1050, Cost：0.036867, Accuracy：0.967525
# Pass：7, Batch：1100, Cost：0.029483, Accuracy：0.972120
# Pass：7, Batch：1150, Cost：0.029446, Accuracy：0.971814
# Pass：7, Batch：1200, Cost：0.030379, Accuracy：0.970282
# Pass：7, Batch：1250, Cost：0.027246, Accuracy：0.969975
# Pass：7, Batch：1300, Cost：0.028397, Accuracy：0.969975
# Pass：7, Batch：1350, Cost：0.036463, Accuracy：0.971507
# Pass：7, Batch：1400, Cost：0.023078, Accuracy：0.973958
# Pass：7, Batch：1450, Cost：0.033788, Accuracy：0.970588
# Pass：7, Batch：1500, Cost：0.020631, Accuracy：0.973652
# Pass：7, Batch：1550, Cost：0.027652, Accuracy：0.971201
# Pass：7, Batch：1600, Cost：0.037067, Accuracy：0.967218
# Pass：7, Batch：1650, Cost：0.023688, Accuracy：0.972120
# test - Pass: 7 Cost: 0.025007841205043704 Acc: 0.9923448607819905
# new BestPrecent: 0.9921412174170616 thie Precent: 0.9923448607819905
# Save...model...Best_precent: 0.9923448607819905
#
# Pass：8, Batch：50, Cost：0.034385, Accuracy：0.989890
# Pass：8, Batch：100, Cost：0.031865, Accuracy：0.971507
# Pass：8, Batch：150, Cost：0.034023, Accuracy：0.969669
# Pass：8, Batch：200, Cost：0.036553, Accuracy：0.969975
# Pass：8, Batch：250, Cost：0.029779, Accuracy：0.968750
# Pass：8, Batch：300, Cost：0.035365, Accuracy：0.969056
# Pass：8, Batch：350, Cost：0.027453, Accuracy：0.971814
# Pass：8, Batch：400, Cost：0.029128, Accuracy：0.971507
# Pass：8, Batch：450, Cost：0.025628, Accuracy：0.971814
# Pass：8, Batch：500, Cost：0.027323, Accuracy：0.972733
# Pass：8, Batch：550, Cost：0.027745, Accuracy：0.970588
# Pass：8, Batch：600, Cost：0.022346, Accuracy：0.974265
# Pass：8, Batch：650, Cost：0.033697, Accuracy：0.970282
# Pass：8, Batch：700, Cost：0.022856, Accuracy：0.973958
# Pass：8, Batch：750, Cost：0.021545, Accuracy：0.973652
# Pass：8, Batch：800, Cost：0.026914, Accuracy：0.970588
# Pass：8, Batch：850, Cost：0.031766, Accuracy：0.970282
# Pass：8, Batch：900, Cost：0.035788, Accuracy：0.969669
# Pass：8, Batch：950, Cost：0.029657, Accuracy：0.969056
# Pass：8, Batch：1000, Cost：0.027485, Accuracy：0.971201
# Pass：8, Batch：1050, Cost：0.036322, Accuracy：0.968137
# Pass：8, Batch：1100, Cost：0.025513, Accuracy：0.971507
# Pass：8, Batch：1150, Cost：0.027264, Accuracy：0.970588
# Pass：8, Batch：1200, Cost：0.034954, Accuracy：0.969975
# Pass：8, Batch：1250, Cost：0.022660, Accuracy：0.972733
# Pass：8, Batch：1300, Cost：0.027544, Accuracy：0.972733
# Pass：8, Batch：1350, Cost：0.031423, Accuracy：0.971507
# Pass：8, Batch：1400, Cost：0.033009, Accuracy：0.971201
# Pass：8, Batch：1450, Cost：0.030013, Accuracy：0.968444
# Pass：8, Batch：1500, Cost：0.026451, Accuracy：0.971201
# Pass：8, Batch：1550, Cost：0.029204, Accuracy：0.972120
# Pass：8, Batch：1600, Cost：0.027670, Accuracy：0.972120
# Pass：8, Batch：1650, Cost：0.030146, Accuracy：0.970895
# test - Pass: 8 Cost: 0.025153651403563078 Acc: 0.9918264958530806
# new BestPrecent: 0.9923448607819905 thie Precent: 0.9918264958530806
#
# Pass：9, Batch：50, Cost：0.024056, Accuracy：0.992953
# Pass：9, Batch：100, Cost：0.023712, Accuracy：0.971814
# Pass：9, Batch：150, Cost：0.030632, Accuracy：0.968750
# Pass：9, Batch：200, Cost：0.028216, Accuracy：0.970588
# Pass：9, Batch：250, Cost：0.024501, Accuracy：0.973039
# Pass：9, Batch：300, Cost：0.025073, Accuracy：0.974571
# Pass：9, Batch：350, Cost：0.030097, Accuracy：0.972120
# Pass：9, Batch：400, Cost：0.020636, Accuracy：0.974265
# Pass：9, Batch：450, Cost：0.023975, Accuracy：0.972120
# Pass：9, Batch：500, Cost：0.024899, Accuracy：0.971814
# Pass：9, Batch：550, Cost：0.031775, Accuracy：0.969056
# Pass：9, Batch：600, Cost：0.028317, Accuracy：0.970895
# Pass：9, Batch：650, Cost：0.021337, Accuracy：0.971201
# Pass：9, Batch：700, Cost：0.024560, Accuracy：0.973652
# Pass：9, Batch：750, Cost：0.028689, Accuracy：0.969975
# Pass：9, Batch：800, Cost：0.026782, Accuracy：0.971507
# Pass：9, Batch：850, Cost：0.029996, Accuracy：0.968750
# Pass：9, Batch：900, Cost：0.019253, Accuracy：0.973652
# Pass：9, Batch：950, Cost：0.025214, Accuracy：0.972426
# Pass：9, Batch：1000, Cost：0.031649, Accuracy：0.971507
# Pass：9, Batch：1050, Cost：0.029153, Accuracy：0.970895
# Pass：9, Batch：1100, Cost：0.026652, Accuracy：0.972120
# Pass：9, Batch：1150, Cost：0.025428, Accuracy：0.973652
# Pass：9, Batch：1200, Cost：0.029747, Accuracy：0.970895
# Pass：9, Batch：1250, Cost：0.031290, Accuracy：0.969363
# Pass：9, Batch：1300, Cost：0.029202, Accuracy：0.972120
# Pass：9, Batch：1350, Cost：0.033012, Accuracy：0.971201
# Pass：9, Batch：1400, Cost：0.029656, Accuracy：0.970895
# Pass：9, Batch：1450, Cost：0.028281, Accuracy：0.971814
# Pass：9, Batch：1500, Cost：0.025227, Accuracy：0.972733
# Pass：9, Batch：1550, Cost：0.027767, Accuracy：0.972120
# Pass：9, Batch：1600, Cost：0.033302, Accuracy：0.969669
# Pass：9, Batch：1650, Cost：0.020418, Accuracy：0.973346
# test - Pass: 9 Cost: 0.02286883666360697 Acc: 0.9923448607819905
# new BestPrecent: 0.9923448607819905 thie Precent: 0.9923448607819905
#
# Pass：10, Batch：50, Cost：0.029600, Accuracy：0.990196
# Pass：10, Batch：100, Cost：0.024206, Accuracy：0.973958
# Pass：10, Batch：150, Cost：0.025113, Accuracy：0.971507
# Pass：10, Batch：200, Cost：0.033108, Accuracy：0.970282
# Pass：10, Batch：250, Cost：0.026775, Accuracy：0.971814
# Pass：10, Batch：300, Cost：0.029573, Accuracy：0.971201
# Pass：10, Batch：350, Cost：0.024898, Accuracy：0.971201
# Pass：10, Batch：400, Cost：0.026801, Accuracy：0.970282
# Pass：10, Batch：450, Cost：0.024992, Accuracy：0.973346
# Pass：10, Batch：500, Cost：0.028381, Accuracy：0.971507
# Pass：10, Batch：550, Cost：0.028321, Accuracy：0.972426
# Pass：10, Batch：600, Cost：0.023933, Accuracy：0.973652
# Pass：10, Batch：650, Cost：0.030265, Accuracy：0.970282
# Pass：10, Batch：700, Cost：0.035228, Accuracy：0.970282
# Pass：10, Batch：750, Cost：0.025697, Accuracy：0.970588
# Pass：10, Batch：800, Cost：0.021256, Accuracy：0.972426
# Pass：10, Batch：850, Cost：0.026910, Accuracy：0.973346
# Pass：10, Batch：900, Cost：0.026894, Accuracy：0.971507
# Pass：10, Batch：950, Cost：0.033135, Accuracy：0.970895
# Pass：10, Batch：1000, Cost：0.025294, Accuracy：0.971814
# Pass：10, Batch：1050, Cost：0.026203, Accuracy：0.970895
# Pass：10, Batch：1100, Cost：0.028307, Accuracy：0.971814
# Pass：10, Batch：1150, Cost：0.025976, Accuracy：0.972426
# Pass：10, Batch：1200, Cost：0.021213, Accuracy：0.973039
# Pass：10, Batch：1250, Cost：0.022674, Accuracy：0.972733
# Pass：10, Batch：1300, Cost：0.038491, Accuracy：0.967831
# Pass：10, Batch：1350, Cost：0.020597, Accuracy：0.973958
# Pass：10, Batch：1400, Cost：0.022358, Accuracy：0.973346
# Pass：10, Batch：1450, Cost：0.028618, Accuracy：0.971814
# Pass：10, Batch：1500, Cost：0.025068, Accuracy：0.972733
# Pass：10, Batch：1550, Cost：0.026631, Accuracy：0.969975
# Pass：10, Batch：1600, Cost：0.028740, Accuracy：0.971201
# Pass：10, Batch：1650, Cost：0.020962, Accuracy：0.974571
# test - Pass: 10 Cost: 0.023028197536379198 Acc: 0.9923818868483413
# new BestPrecent: 0.9923448607819905 thie Precent: 0.9923818868483413
# Save...model...Best_precent: 0.9923818868483413
#
# Pass：11, Batch：50, Cost：0.030070, Accuracy：0.988971
# Pass：11, Batch：100, Cost：0.021610, Accuracy：0.974265
# Pass：11, Batch：150, Cost：0.013881, Accuracy：0.976716
# Pass：11, Batch：200, Cost：0.031629, Accuracy：0.971201
# Pass：11, Batch：250, Cost：0.024852, Accuracy：0.972733
# Pass：11, Batch：300, Cost：0.016288, Accuracy：0.976409
# Pass：11, Batch：350, Cost：0.025147, Accuracy：0.972120
# Pass：11, Batch：400, Cost：0.033975, Accuracy：0.968137
# Pass：11, Batch：450, Cost：0.022209, Accuracy：0.972426
# Pass：11, Batch：500, Cost：0.031424, Accuracy：0.970282
# Pass：11, Batch：550, Cost：0.029175, Accuracy：0.971201
# Pass：11, Batch：600, Cost：0.020675, Accuracy：0.973039
# Pass：11, Batch：650, Cost：0.023994, Accuracy：0.972426
# Pass：11, Batch：700, Cost：0.034785, Accuracy：0.967525
# Pass：11, Batch：750, Cost：0.029956, Accuracy：0.970588
# Pass：11, Batch：800, Cost：0.022401, Accuracy：0.971814
# Pass：11, Batch：850, Cost：0.027781, Accuracy：0.972120
# Pass：11, Batch：900, Cost：0.030325, Accuracy：0.971201
# Pass：11, Batch：950, Cost：0.030427, Accuracy：0.970895
# Pass：11, Batch：1000, Cost：0.022530, Accuracy：0.973346
# Pass：11, Batch：1050, Cost：0.024019, Accuracy：0.972426
# Pass：11, Batch：1100, Cost：0.027857, Accuracy：0.972426
# Pass：11, Batch：1150, Cost：0.025703, Accuracy：0.973039
# Pass：11, Batch：1200, Cost：0.028614, Accuracy：0.969975
# Pass：11, Batch：1250, Cost：0.030913, Accuracy：0.970282
# Pass：11, Batch：1300, Cost：0.037642, Accuracy：0.968750
# Pass：11, Batch：1350, Cost：0.024742, Accuracy：0.973039
# Pass：11, Batch：1400, Cost：0.033143, Accuracy：0.969669
# Pass：11, Batch：1450, Cost：0.024449, Accuracy：0.972120
# Pass：11, Batch：1500, Cost：0.025188, Accuracy：0.971814
# Pass：11, Batch：1550, Cost：0.024065, Accuracy：0.971507
# Pass：11, Batch：1600, Cost：0.024085, Accuracy：0.972733
# Pass：11, Batch：1650, Cost：0.023070, Accuracy：0.973346
# test - Pass: 11 Cost: 0.021839451723599915 Acc: 0.9931594342417062
# new BestPrecent: 0.9923818868483413 thie Precent: 0.9931594342417062
# Save...model...Best_precent: 0.9931594342417062
#
# Pass：12, Batch：50, Cost：0.023495, Accuracy：0.992647
# Pass：12, Batch：100, Cost：0.029422, Accuracy：0.971814
# Pass：12, Batch：150, Cost：0.020381, Accuracy：0.973958
# Pass：12, Batch：200, Cost：0.025262, Accuracy：0.969669
# Pass：12, Batch：250, Cost：0.028420, Accuracy：0.971814
# Pass：12, Batch：300, Cost：0.016535, Accuracy：0.975184
# Pass：12, Batch：350, Cost：0.026674, Accuracy：0.972120
# Pass：12, Batch：400, Cost：0.029742, Accuracy：0.970895
# Pass：12, Batch：450, Cost：0.019535, Accuracy：0.974265
# Pass：12, Batch：500, Cost：0.029781, Accuracy：0.971507
# Pass：12, Batch：550, Cost：0.018584, Accuracy：0.974571
# Pass：12, Batch：600, Cost：0.029232, Accuracy：0.972120
# Pass：12, Batch：650, Cost：0.022929, Accuracy：0.973039
# Pass：12, Batch：700, Cost：0.020821, Accuracy：0.973652
# Pass：12, Batch：750, Cost：0.019075, Accuracy：0.973652
# Pass：12, Batch：800, Cost：0.028046, Accuracy：0.972426
# Pass：12, Batch：850, Cost：0.017389, Accuracy：0.973652
# Pass：12, Batch：900, Cost：0.025108, Accuracy：0.972426
# Pass：12, Batch：950, Cost：0.026949, Accuracy：0.971201
# Pass：12, Batch：1000, Cost：0.026211, Accuracy：0.972120
# Pass：12, Batch：1050, Cost：0.031975, Accuracy：0.971201
# Pass：12, Batch：1100, Cost：0.023322, Accuracy：0.973958
# Pass：12, Batch：1150, Cost：0.023086, Accuracy：0.972733
# Pass：12, Batch：1200, Cost：0.019356, Accuracy：0.973652
# Pass：12, Batch：1250, Cost：0.026505, Accuracy：0.974265
# Pass：12, Batch：1300, Cost：0.029992, Accuracy：0.970282
# Pass：12, Batch：1350, Cost：0.027385, Accuracy：0.971201
# Pass：12, Batch：1400, Cost：0.024330, Accuracy：0.974571
# Pass：12, Batch：1450, Cost：0.030854, Accuracy：0.970588
# Pass：12, Batch：1500, Cost：0.023606, Accuracy：0.971507
# Pass：12, Batch：1550, Cost：0.035730, Accuracy：0.968750
# Pass：12, Batch：1600, Cost：0.015689, Accuracy：0.974877
# Pass：12, Batch：1650, Cost：0.029519, Accuracy：0.970588
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-11d3c79b2ab2> in <module>
#      35            print("Save...model...Best_precent:",best_model_precent)
#      36        print()
# ---> 37 train()
#
# <ipython-input-12-11d3c79b2ab2> in train()
#      19        test_sum_acc=0
#      20        test_cout = 0
# ---> 21        for batch_id , data in enumerate(test_Reader()):
#      22            train_cost, train_acc = exe.run(program = test_program,
#      23                                           feed = feeder.feed(data),
#
# d:\python3.6\lib\site-packages\paddle\batch.py in batch_reader()
#      33         r = reader()
#      34         b = []
# ---> 35         for instance in r:
#      36             b.append(instance)
#      37             if len(b) == batch_size:
#
# d:\python3.6\lib\site-packages\paddle\reader\decorator.py in data_reader()
#      75     def data_reader():
#      76         buf = []
# ---> 77         for e in reader():
#      78             buf.append(e)
#      79             if len(buf) >= buf_size:
#
# <ipython-input-4-2144c890ace6> in reader()
#      39                     tmpimg.paste(img,(r_x,r_y))
#      40                     element1 = cv2.getStructuringElement(cv2.MORPH_RECT, (r_yh, r_yh))
# ---> 41                     tmpimg = cv2.dilate(np.array(tmpimg), element1, iterations = 1)
#      42                     tmpimg = addGaussianNoise(tmpimg)
#      43                     #img = cv2.blur(img,(20,20))#羽化
#
# KeyboardInterrupt:

# %%
save_model(save_model_name)

# %%
load_model(save_model_name)

# %%
save_inference(save_model_name)

# %%
test_image = test_list[19][20]
plt.figure()
plt.imshow(test_image)
test_image = np.array(test_image).astype('float32').reshape(1,1,64,64)/255
result = exe.run(program = test_program,feed = {'image':test_image,'label':np.array([[1]]).astype('int64')},fetch_list = [net])
print(np.argmax(result))
