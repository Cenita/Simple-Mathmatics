# %%
import inferProgram
inferProgram.Acc(101).infer_image('test_image/cs/7.jpg')
# Out:
# < 0.99999905
# n 0.91414833
# 1 0.996238
# 0 0.99999416
# - 0.9999987
# - 0.9999976
# 0 0.9999987
# 1 0.9993494
# - 0.99954444
# n 0.9918229
# 2 0.9999511
# + 0.9999993
# n 0.9477107
# 1 0.97108895
# 2 0.9999918
# + 0.99999857
# n 0.5574481
# 2 0.99970156
# + 0.9999783
# 2 0.9999914
# 0 0.9999926
# < n
# n 0.7788461538461539
# < 1
# < 0
# 1 0
# < 0
# 0 0
# < 1
# - 1
# n 2
# + 1
# 1 2
# 2 n
# + 2
# + 2
# - 0
# 2 0
# ['<', [['1', [], [], [], [337, 59, 20, 78]], ['0', [], [], [], [359, 78, 37, 44]], ['0', [], [], [], [405, 76, 30, 47]]], [], [['n', [], [], [], [324, 266, 45, 65]], ['-', [], [], [['-', [], [], [], [389, 299, 38, 13]]], [387, 280, 34, 9]], ['1', [], [], [], [450, 267, 12, 69]]], [108, 104, 196, 208]]
# ['-', [['n', [['2', [], [], [], [661, 55, 35, 34]]], [], [], [602, 90, 52, 66]], ['+', [], [], [], [709, 83, 63, 63]], ['1', [], [], [], [787, 75, 15, 65]], ['2', [], [], [], [808, 74, 53, 68]], ['n', [], [], [], [875, 77, 47, 68]], ['+', [], [], [], [964, 53, 68, 80]], ['2', [], [], [], [1045, 50, 56, 68]], ['0', [], [], [], [1109, 64, 48, 54]]], [], [['n', [], [], [], [735, 251, 57, 77]], ['+', [], [], [], [832, 243, 71, 67]], ['2', [], [], [], [931, 229, 76, 75]]], [580, 166, 555, 31]]
# (True, '<^(100)~(n=1)((n^(2)+12n+20)/(n+2))')

# %%
import inferProgram
aaa = inferProgram.Unk(66)

# %%
re = aaa.infer_image('test_image/cs/5.jpg')[1][0]
print(re)
inferProgram.ToolBar.getDerivative().getResult(re)
# Out:
# y 0.99995196
# - 0.9999881
# - 0.9999931
# * 0.99997914
# 3 0.9999938
# ( 0.8912689
# n 0.9999982
# * 0.9986847
# + 0.9999361
# e 0.99999905
# * 0.9737428
# * 0.9995753
# 2 0.9996662
# + 0.9999739
# * 0.9946801
# + 0.99927014
# 1 0.996992
# ['y', [], [], [], [113, 50, 56, 113]]
# ['-', [['-', [], [], [], [218, 74, 37, 9]]], [], [], [217, 104, 43, 7]]
# ['*', [['3', [], [], [], [375, 19, 37, 53]]], [], [], [313, 57, 57, 68]]
# ['(', [], [], [], [440, 22, 30, 100]]
# ['n', [], [], [], [466, 72, 43, 43]]
# ['*', [], [], [], [529, 38, 53, 84]]
# ['+', [], [], [], [640, 39, 45, 81]]
# ['e', [['*', [], [], [], [795, 12, 41, 52]]], [], [], [739, 43, 47, 77]]
# ['*', [['2', [], [], [], [974, 2, 29, 41]]], [], [], [892, 31, 64, 76]]
# ['+', [], [], [], [1041, 33, 42, 65]]
# ['*', [], [], [], [1123, 15, 69, 88]]
# ['+', [], [], [], [1235, 23, 41, 70]]
# ['1', [], [], [], [1317, 8, 17, 103]]
# y 0.99996984
# - 0.99999166
# - 0.9999914
# ['y', [], [], [], [115, 2, 63, 111]]
# ['-', [], [], [['-', [], [], [], [249, 51, 36, 9]]], [248, 18, 42, 11]]
# y=x^(3)(nx+e^(x)x^(2)+x+1
# x**(3)*sympy.log(x)+sympy.E**(x)*x**(2)+x+1
# 'x^2*e^(x) + 3*x^2*log(x) + x^2 + 2*x*e^(x) + 1'

# %%
import inferProgram
Four = inferProgram.FourOperation(5)

# %%
Four.infer_image('test_image/cs/1.jpg')
# Out:
# 1 0.99584913
# 2 0.99999714
# 8 0.99999845
# - 0.99999857
# 2 0.99991333
# 0 0.9999995
# * 0.9999995
# ( 0.9999943
# 6 0.66414183
# 0 0.9999902
# 5 0.8798781
# - 0.99999976
# PI 0.9998801
# 2 0.9999919
# + 0.99879885
# 5 0.594404
# 1 0.9934823
# . 0.999995
# n 0.9999682
# - 0.9999999
# PI 0.999998
# 4 0.9998419
# ) 0.9999627
# 2 True False
# 8 True False
# 2 True False
# 0 True False
# * True False
# ( True False
# 6 True False
# 0 True False
# 5 True False
# hello
# - True True
# PI True True
# + True False
# 1 True False
# . True True
# n True False
# PI True True
# 4 True False
# ) True False
# ['1', [], [], [], [80, 116, 13, 109]]
# ['2', [], [], [], [112, 134, 53, 73]]
# ['8', [], [], [], [174, 102, 43, 102]]
# ['-', [], [], [], [240, 148, 42, 7]]
# ['2', [], [], [], [317, 107, 39, 78]]
# ['0', [], [], [], [366, 132, 34, 40]]
# ['*', [], [], [], [421, 121, 52, 62]]
# ['(', [], [], [], [491, 105, 40, 81]]
# ['6', [], [], [], [560, 124, 29, 53]]
# ['0', [], [], [], [600, 127, 36, 43]]
# ['5', [], [], [], [644, 128, 28, 42]]
# ['-', [['PI', [], [], [], [716, 57, 56, 60]]], [], [['2', [], [], [], [720, 147, 43, 36]]], [694, 126, 78, 13]]
# ['+', [], [], [], [802, 102, 45, 60]]
# ['5', [], [], [], [869, 109, 37, 49]]
# ['1', [['.', [], [], [], [929, 80, 9, 9]]], [], [], [916, 124, 11, 35]]
# ['n', [], [], [], [937, 113, 36, 59]]
# ['-', [['PI', [], [], [], [1012, 50, 63, 49]]], [], [['4', [], [], [], [1014, 128, 57, 77]]], [998, 117, 68, 8]]
# [')', [], [], [], [1088, 64, 37, 117]]
# ( 1 0 []
# cos 3 0 []
# sin 3 0 []
# (True, '128-20*(cos((PI)/(2))+sin((PI)/(4)))')

# %%
import inferProgram
Ma = inferProgram.Martix(37)

# %%
result = Ma.infer_image('test_image/组委会手写数据集/新建文件夹/矩阵运算20.png')[1]
print(inferProgram.ToolBar.getMartrix().getResult(result))
# Out:
# ( 0.9407512
# - 1.0
# 7 0.83798337
# 1 0.9997999
# 4 0.99982697
# 6 0.9999925
# ) 0.9999969
# + 0.99999774
# ( 0.9126395
# 9 0.98992574
# 3 0.9539117
# 5 0.9984479
# 7 0.9995567
# ) 0.9999981
# ['[', [], [], [], [381, 175, 137, 671]]
# [[['-1', '4'], ['7', '6']], [], [], [], [1619, 208, 152, 679]]
# [']', [], [], [], [1619, 208, 152, 679]]
# ['+', [], [], [], [1993, 239, 208, 164]]
# ['[', [], [], [], [2437, 112, 117, 741]]
# [[['3', '5'], ['9', '7']], [], [], [], [3600, 306, 178, 517]]
# [']', [], [], [], [3600, 306, 178, 517]]
# [[2 9][16 13]]

# %%
import inferProgram
result = inferProgram.Integral(151).infer_image('test_image/cs/9.jpg')[1]
print(result)
print(inferProgram.ToolBar.getIntegral().getResult(result))
# Out:
# # 1.0
# 0 0.9999839
# 2 0.9999976
# ( 0.9998685
# 2 0.9999988
# * 0.35734177
# 2 0.99998283
# + 0.9999976
# x 0.5290337
# 5 0.99714833
# 1 0.9998362
# 1 0.99812406
# * 0.9998903
# ) 0.99993193
# d 0.99965894
# * 0.98870635
# ['#', [['2', [], [], [], [292, 102, 80, 95]]], [], [['0', [], [], [], [262, 337, 64, 70]]], [100, 111, 193, 287]]
# ['(', [], [], [], [443, 187, 67, 155]]
# ['2', [], [], [], [554, 206, 89, 100]]
# ['*', [['2', [], [], [], [782, 143, 48, 48]]], [], [], [669, 181, 97, 154]]
# ['+', [], [], [], [852, 172, 97, 116]]
# ['x', [], [], [], [967, 147, 83, 141]]
# ['5', [], [], [], [1088, 174, 67, 104]]
# ['1', [], [], [], [1157, 212, 20, 72]]
# ['1', [], [], [], [1194, 181, 57, 99]]
# ['*', [], [], [], [1279, 143, 82, 128]]
# [')', [], [], [], [1400, 86, 55, 188]]
# ['d', [], [], [], [1504, 50, 92, 211]]
# ['*', [], [], [], [1615, 141, 67, 133]]
# #^(2)~(0)(2x^(2)+x511x)dx
# 65156: (2*x**(2)+x*sympy.sin(x))
# -2*cos(2) + sin(2) + 16/3

# %%
import inferProgram
aaa = inferProgram.Unk(66)
re = aaa.infer_image('test_image/cs/4.jpg')[1][0]
print(re)
# Out:
# 1 0.99291843
# 2 0.9995615
# 8 0.9998969
# - 0.99993026
# 2 0.9926803
# 0 0.99999857
# * 0.99999833
# ( 0.9999863
# ( 0.79838127
# 0 0.99999785
# 5 0.999798
# - 0.99987125
# 2 0.6209615
# 2 0.9999523
# + 0.9999404
# 5 0.9999591
# 1 0.98460686
# 9 0.23762472
# 1 0.7880703
# - 0.99987626
# 0 0.6963621
# 4 0.9998567
# ) 0.9999864
# ['1', [], [], [], [80, 68, 13, 109]]
# ['2', [], [], [], [111, 86, 55, 73]]
# ['8', [], [], [], [173, 54, 44, 102]]
# ['-', [], [], [], [239, 100, 43, 7]]
# ['2', [], [], [], [317, 59, 39, 78]]
# ['0', [], [], [], [366, 84, 34, 40]]
# ['*', [], [], [], [421, 73, 52, 62]]
# ['(', [], [], [], [491, 57, 40, 81]]
# ['(', [], [], [], [560, 76, 29, 53]]
# ['0', [], [], [], [599, 79, 37, 43]]
# ['5', [], [], [], [644, 79, 28, 43]]
# ['-', [['2', [], [], [], [716, 9, 56, 60]]], [], [['2', [], [], [], [720, 98, 43, 37]]], [694, 78, 78, 13]]
# ['+', [], [], [], [802, 54, 46, 60]]
# ['5', [], [], [], [868, 60, 38, 50]]
# ['1', [['9', [], [], [], [929, 32, 9, 9]]], [], [], [916, 76, 12, 35]]
# ['1', [], [], [], [937, 65, 36, 60]]
# ['-', [['0', [], [], [], [1012, 2, 63, 49]]], [], [['4', [], [], [], [1014, 80, 57, 77]]], [998, 69, 69, 8]]
# [')', [], [], [], [1088, 16, 37, 117]]
# 128-20x(cos((2)/(2))+51^(9)1((0)/(4)))

# %%
np.array([[3,2, 1], [1, 2, 3], [3, 3, 2]])*np.array([[1, 2, 3], [2, 2, 4], [3, 2, 1]])-np.array([[1, 2, 1], [1, 1, 2],[1, 3, 1]])
# Out:
# array([[ 2,  2,  2],
#        [ 1,  3, 10],
#        [ 8,  3,  1]])

# %%
try:
    pass
except Exception:
# Out:
# array([2, 4])

# %%
import math
# Out:
# 1.6094379124341003

# %%
import sympy
